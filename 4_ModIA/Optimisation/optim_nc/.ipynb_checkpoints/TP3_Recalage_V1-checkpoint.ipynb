# %% [markdown]
# TP- Recalage d'images
# =============

# %%
import numpy as np
from scipy import signal
from scipy import interpolate
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# /home/sara/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# Un problème fréquemment rencontré dans le domaine du traitement d’images est celui du recalage. On dispose de plusieurs images prises à des temps différents, ou par des appareils différents, et on aimerait les mettre en correspondence, c’est-à-dire trouver une déformation du plan, qui assure une correspondence point à point des objets sous-jacents. Donnons quelques exemples d’applications :
# * Traitements/retouches d’images. Par exemple, on peut vouloir construire un panoramique à partir d’images de petite taille. Il faut les recaler préalablement.
# * Evaluation des déplacements d’objets dans des séquences vidéos (e.g. trouver un défaut de fonctionnement d’un organe, caméras de surveillance, design de robots intelligents ou de systèmes de navigation automatiques ...)
# * Couplage d’informations. Par exemple, en imagerie médicale, on obtient une information plus riche en utilisant à la fois une radio et une angiographie. L’une apporte des informations structurelles, l’autre des informations fonctionnelles. Le couplage des deux images donne plus d’information au praticien.
# * Beaucoup d’autres applications...
#
# Dans ce TP, nous allons proposer un modèle de recalage assez élémentaire. Les idées constitutives se retrouvent cependant dans presque toutes les techniques récentes.

# %%
def get_images() :
    n=21
    sigma=0.3
    [X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,n), indexing='xy')
    Z=np.sqrt(X*X+Y*Y)
    im1=np.zeros((n,n))
    im1[Z<=.7]=1.
    im1[Z<=.3]=.5
    im1[Z<=.1]=.7
    im2=np.zeros((n,n));
    Z=np.sqrt((X-.3)**2+(Y+.2)**2)
    im2[Z<=.7]=1
    im2[Z<=.3]=.5
    im2[Z<=.1]=.7
    G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
    f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
    g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
    f=f/np.max(f)
    g=g/np.max(g)
    return f,g,im1,im2

# %%
f,g,im1,im2=get_images()
fig, axarr = plt.subplots(2, 2, figsize=(10,10))
axarr[0,0].imshow(im1)
axarr[0,0].set_title('Image im1')
axarr[1,0].imshow(f)
axarr[1,0].set_title('function f ( blurry version of im1)')
axarr[0,1].imshow(im2)
axarr[0,1].set_title('Image im2')
axarr[1,1].imshow(g)
axarr[1,1].set_title('function g ( blurry version of im2)')
plt.show()

# %% [markdown]
# # 1. Formalisation du problème
# ## 1.1 Formalisme continu
#
# On modélise les images en niveaux de gris comme des fonctions d’un ensemble borné $\Omega\subset \mathbb{R}$ (typiquement un carré) dans $\mathbb{R}$. La valeur de la fonction en chaque point représente l’intensité lumineuse de l’image.
#
# Soient $f$ et $g$ deux images. On a donc :
# $$
# f:\Omega\subset \mathbb{R}^2 \to \mathbb{R},  g:\Omega\subset \mathbb{R}^2 \to \mathbb{R}
# $$
# En supposant que les images $f$ et $g$ dépendent seulement d’une transformation géométrique qui conserve la luminosité, le problème de recalage peut être formulé comme suit:
#
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
# Problème $(P_1)$ : <br>
# Etant donnés $f$ et $g$ dans $H_1(\Omega)$ (les images ont une amplitude bornée et une énergie finie), trouver un champ de vecteurs $u = (u_1, u_2) \in H_1(\Omega)^2$ tel que:
# $$f(x + u(x)) = g(x), \forall x\in \Omega.$$
# </div>
#
# Le problème inverse est mal posé: tout d'abord, l'existence d'une solution n'est pas garantie, et dans le cas où il existe une solution, on n'a pas nécessairement unicité de cette solution. Par exemple, si $f$ et $g$ sont des fonctions constantes, n'importe quel déplacement $u$ est solution. Si $f$ est la constante $1$ et si $g$ est la constante $0$, il n'existe pas de solutions.
#
# Pour le résoudre, on se propose de le reformuler comme un problème d'optimisation:
#
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
# Problème $(P_2)$ : <br>
# On cherche une déformation $u$ du plan qui minimise:
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
# </div>
#
# Sans hypothèse supplémentaire, le problème $\displaystyle \min_{u \in H^1(\Omega)^2} E(u)$ n'est a priori pas convexe, toujours mal posé et même éventuellement non différentiable si $u$ et $f$ ne sont pas assez régulières. On pourrait facilement rendre $f$ différentiable (en ajoutant du flou (on dit aussi du "bruit") par exemple à l'image, ce qui revient à convoler $f$ avec une gaussienne) mais il faut également "forcer" $u$ à être différentiable. Pour cela on propose de régulariser le problème de façon à assurer la convexité du problème d'optimisation considéré ainsi que l'existence et l'unicité des solutions.
#
# Pour régulariser le problème inverse, nous allons faire une analogie avec l’élasticité linéaire. La fonction $u = (u_x,u_y)$ représente un champ de déformations. En notant $\partial x$ et $\partial y$ les opérateurs de dérivation partielle par rapport à chacun des axes du plan, on peut définir un potentiel élastique linéarisé :
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations  de  volume}}.
# $$
# En mécanique des structures, $\mu$ et $\lambda$ sont appelées constantes de Lamé. Le paramètre $\lambda$ n’a pas d’interprétation directe, tandis que le paramètre $\mu$ est appelé module de cisaillement.
#
# Le problème d'optimisation à résoudre dans ce TP est le suivant:
# <div style="background-color:rgba(0, 0, 255, 0.1); padding:15px;margin:5px">
#
# $$(P)\qquad \min_{u} E(u)+R(u).$$
# $$
# E(u)=\displaystyle\frac{1}{2}\int_\Omega (f(x+u(x))-g(x))^2 dx=\frac{1}{2}\|f\circ (id+u)-g\|^2.
# $$
# $$
# R(u)= \frac{\mu}{2}\int_{\Omega} \underbrace{ (\partial_x u_y + \partial_y u_x)^2(x,y) dxdy}_{R_1(u)=\textrm{cisaillement}} +\frac{\lambda+\mu}{2}\int_{\Omega} \underbrace{(\partial_x u_x + \partial_y u_y)^2(x,y) dxdy}_{R_2(u)=\textrm{variations  de  volume}}.
# $$
# </div>
#
# **Q1.** A l'aide d'un développement de Taylor, vérifier que le gradient de $E$ s'écrit:
#
# $$\nabla E(u) = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u)$$
#
# au sens où la différentielle de $E$ est définie par:
#
# $$dE(u)\cdot h= \displaystyle\int_\Omega \langle (f(x+u(x))-g(x))\nabla f(x+u(x)),h(x)\rangle dx.$$
#
# Puis par définition, on a $$ dE(u)\cdot h =\langle \nabla E(u),h\rangle \quad \forall h$$
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On a $\forall (u,h) \in (H_1(\Omega)^2)^2 : \\$
# $$
# \begin{align*}
# E(u+h)
# &= \frac{1}{2}\int_{\Omega} \left[ f(x+u(x)+h(x)) - g(x)\right]^2 \, dx \\
# &= \frac{1}{2} \int_{\Omega} \left[f(x+u(x)) + \langle \nabla f(x+u(x)), h(x) \rangle + o(\|h\|) - g(x) \right]^2 \, dx  &\text{car on suppose que } f \text{ est différentiable} \\
# &= \frac{1}{2} \int_{\Omega} \left( \left[f(x+u(x)) - g(x)\right]^2 + 2 \langle \nabla f(x+u(x)), h(x) \rangle \left( f(x+u(x)) - g(x) \right) + o(\|h\|) \right) \, dx \\
# &= E(u) + \int_{\Omega} \langle \left( f(x + u(x) - g(x) \right) \nabla f(x + u(x)), h(x) \rangle \, dx + o(\|h\|) \\
# &= E(u) + dE(u)\cdot h + o(\|h\|) \\
# &= E(u) + \langle \nabla E(u),h\rangle + o(\|h\|) \\
# \end{align*}
# $$
#
# D'où $\nabla E(u) = \displaystyle\int_\Omega  (f(x+u(x))-g(x))\nabla f(x+u(x)) dx = \left(f\circ (id+u) -g\right)\nabla f\circ (id+u).$
#
#
# </div>

# %% [markdown]
# # 2. Discrétisation
#
# Pour pouvoir résoudre numériquement le problème $(P)$ (dont les variables de l'optimisation sont des fonctions !), on propose de le discrétiser au préalable.
#
# Soit $1\le i \le n$ and $1\le j\le m$. Notons $(x_i,y_j)$ le point de la grille $(i,j)$ et $f_{i,j}$ la valeur de $f$ au point $(x_i,y_j)$. Le produit scalaire sur $V=\mathcal M_{n,m}(\mathbb{R})$ est défini par:
# $$\langle f,g\rangle_V=\sum_{i=1}^n\sum_{j=1}^m f_{i,j}g_{i,j},$$
#
# ## 2.1. Calcul du $E$ et de son gradient
# Pour pouvoir calculer $E$ et son gradient, on va avoir besoin d'évaluer $f\circ (Id+u)$ et $\nabla f\circ(id+u)$. Pour cela, vous aurez besoin de la fonction `interpol` ci-dessous.

# %%
def interpol(function,ux,uy) :
    # function that computes f \circ Id+u and interpolates it on a mesh
    nx,ny=f.shape
    ip=interpolate.RectBivariateSpline(np.arange(nx),np.arange(ny),function)
    [X,Y]=np.meshgrid(np.arange(nx),np.arange(ny), indexing='ij')
    X=X+ux
    Y=Y+uy
    return np.reshape(ip.ev(X.ravel(),Y.ravel()),(nx,ny))

# %% [markdown]
# Le code effectue une interpolation bidimensionnelle d'une fonction sur une grille. La fonction prend en entrée un tableau bidimensionnel et deux paramètres de décalage ux et uy. La fonction (RectBivariateSpline) crée un objet d'interpolation. Ensuite, elle déplace les coordonnées de la grille en ajoutant les décalages ux et uy. Pour finir, les valeurs interpolées sont évaluées aux nouvelles coordonnées, les remodelant en un tableau 2D avec la forme initiale de la fonction.
# En résumé, la fonction effectue une interpolation spatiale d'une fonction sur une grille, avec la possibilité de spécifier des décalages.

# %% [markdown]
# **Q2.** Lisez la documentation de la fonction `RectBivariateSpline` afin de comprendre ce que fait la fonction `interpol`.
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Votre réponse ici
# </div>
#
#
# ## 2.2. Calcul de $R$ et de son gradient
# On discrétise également les opérateurs de dérivation partielles par différences finies ; par exemple la dérivée partielle par rapport à $x$ est donnée par, pour tout $f\in V$ par
# $$\begin{cases}(\partial_x f)_{i,j}=f_{i+1,j}-f_{i,j} \text{ si } i<n \\
# (\partial_x f)_{n,j}=0 \end{cases}.$$
# On a ainsi $\partial_x f\in V$.
#
# On définit les opérateurs $\partial_x^T$ et $\partial_y^T$ comme les uniques opérateurs qui vérifient
#
# $$ \langle \partial_x^T f, g\rangle_V = \langle f,\partial_x  g\rangle_V \quad \forall f,g\in V$$
# $$ \langle \partial_y^T f, g\rangle_V = \langle f,\partial_y  g\rangle_V \quad \forall f,g\in V$$
#
# **Q2.** Donner les formules de discrétisation des opérateurs $\partial_y$, $\partial_x^\top$ et $\partial_y^\top$. Implémenter ces opérateurs ci-après. On donne un test de vérification.

# %% [markdown]
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour $\partial _y$ :
# $$\begin{cases}(\partial_y f)_{i,j}=f_{i,j+1}-f_{i,j} \text{ si } j<n \\
# (\partial_y f)_{i,n}=0 \end{cases} $$
#
# Pour $\partial _x ^T$ :
# $$\begin{align}
# \langle \partial _x u, v \rangle_V &= \sum_{i=1}^{n-1}\sum_{j=1}^{n}(u_{i+1,j}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{i+1,j}v_{ij}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n}\sum_{j=1}^{n}u_{ij}v_{i-1,j}-\sum_{i=1}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{i-1,j}-\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}v_{ij} - \sum_{j=1}^{n} u_{1j}v_{1j} + \sum_{j=1}^{n} u_{nj}v_{n-1,j}\\
# &=\sum_{i=2}^{n-1}\sum_{j=1}^{n}u_{ij}(v_{i-1,j}-v_{ij}) + \sum_{j=1}^{n} u_{nj}v_{n-1,j}-u_{1j}v_{1j}\\ \\ \\
# \end{align}$$
#
# Par identification :
# $$\partial _x ^T=\begin{cases}f_{i-1,j}-f_{ij} \text{ si } i\in[2;n-1] \\
#         f_{n-1,j} \text{ si } i=n \\
#         -f_{1j} \text{ si } i=1 \end{cases} $$
#
# Pour $\partial _y ^T$ :
# $$\begin{align}
# \langle \partial _y u, v \rangle_V &= \sum_{i=1}^{n}\sum_{j=1}^{n-1}(u_{i,j+1}-u_{ij})v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{i,j+1}v_{ij}-\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{ij}v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n}u_{ij}v_{i,j-1}-\sum_{i=1}^{n}\sum_{j=1}^{n-1}u_{ij}v_{ij}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}v_{i,j-1}-\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}v_{ij} - \sum_{i=1}^{n} u_{i1}v_{i1} + \sum_{i=1}^{n} u_{in}v_{i,n-1}\\
# &=\sum_{i=1}^{n}\sum_{j=2}^{n-1}u_{ij}(v_{i,j-1}-v_{ij}) + \sum_{i=1}^{n} u_{in}v_{i,n-1}-u_{i1}v_{i1}\\ \\ \\
# \end{align}$$
#
# Par identification:
# $$\partial _y ^T=\begin{cases}f_{i,j-1}-f_{ij} \text{ si } j\in[2;n-1] \\
#         f_{i,n-1} \text{ si } j=n \\
#         -f_{i1} \text{ si } j=1 \end{cases} $$
#
# </div>

# %%
def dx(im) :
    d=np.zeros(im.shape)
    d[:-1,:]=im[1:,:]-im[:-1,:]
    return d
def dy(im) :
    d=np.zeros(im.shape)
    d[:,:-1]=im[:,1:]-im[:,:-1]
    return d
def dyT(im) :
    d=np.zeros(im.shape)
    d[:,0]=-im[:,0]
    d[:,-1]=im[:,-2]
    d[:,1:-1]=im[:,0:-2]-im[:,1:-1]  
    return d  
def dxT(im) :
    d=np.zeros(im.shape)
    d[0,:]=-im[0,:]
    d[-1,:]=im[-2,:]
    d[1:-1,:]=im[0:-2,:]-im[1:-1,:]   
    return d

def scal(a,b) :
    assert a.shape==b.shape
    return np.sum(a*b)

np.random.seed(42)
im1=np.random.randn(12,15)
im2=np.random.randn(12,15)
print(scal(dx(im1),im2),'=',scal(im1,dxT(im2)))
# Out:
# -17.489408391382973 = -17.489408391382973

# %% [markdown]
# **Q3.**  On peut alors écrire :
# $$
# R(u)= \frac{\mu}{2}\underbrace{\sum_{i}(\partial_x u_y + \partial_y u_x)^2(i)}_{=R_1(u)} + \frac{\lambda+\mu}{2} \underbrace{\sum_i(\partial_x u_x + \partial_y u_y)^2(i)}_{=R_2(u)}.
# $$
# où:
# * $u_x\in V$ et $u_y\in V$ sont les discrétisations des composantes du champ de vecteurs $u$ sur la grille choisie
# * $\partial_x:V \rightarrow V$ et $\partial_y:V\rightarrow V$ représentent les opérateurs de différences finies.
#
# On peut ré-écrire $R(u)=\frac{\mu}{2}R_1(u)+ \frac{\lambda+\mu}{2} R_2(u)$ avec :
# $$
# R_1(u)=\langle A_1 u , A_1 u\rangle_V,\qquad R_2(u)=\langle A_2 u , A_2 u\rangle_V.
# $$
# Où $A_i$ est un opérateur de $V^2$ dans $V$.
# Donnez l'expression des matrices $A_1$ et $A_2$ en fonction des opérateurs $\partial_x$ et $\partial_y$.
#
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Pour $A_1$ :
# $$R_1(u) = \langle A_1 u , A_1 u\rangle_V = \|A_1u\|^2_V = \|A_1 \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}\|^2_V =  \|\partial_x u_y + \partial_y u_x \|^2_V = \|
# \begin{bmatrix}
#     dy \\
#     dx
# \end{bmatrix}^T \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}
#  \
#  \|^2_V$$
# D'où, $$A_1 = \begin{bmatrix}
#     dy &  dx
# \end{bmatrix}$$
#
# Pour $A_2$ :
# $$R_2(u) = \langle A_2 u , A_2 u\rangle_V = \|A_2u\|^2_V = \|A_2 \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}\|^2_V =  \|\partial_x u_x + \partial_y u_y \|^2_V = \|
# \begin{bmatrix}
#     dx \\
#     dy
# \end{bmatrix}^T \begin{bmatrix}
#   u_x\\
# u_y
# \end{bmatrix}
#  \
#  \|^2_V$$
# D'où, $$A_2 = \begin{bmatrix}
#     dx &  dy
# \end{bmatrix}$$
# </div>
#
#
# **Q3b.**
# Pour tout $u=(u_x,u_y)$ et $v=(v_x,v_y)$ dans $V^2$, on définit le produit scalaire dans $V^2$ par
# $$\langle u,v\rangle_{V^2}=\langle u_x,v_x\rangle_{V}+\langle u_y,v_y\rangle_{V}$$
#
# Montrer que $R(u)$ peut s'écrire sous la forme:
# $$R(u)=\frac{1}{2} \langle A\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right),\left(\begin{array}{c}
# u_x\\
# u_y
# \end{array}\right)\rangle_{V^2},$$
#
# Avec $$A=\mu A_1^TA_1 +(\lambda+\mu) A_2^TA_2$$ et $A_i^T$ un opérateur de $V^2$ dans $V$.
#
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# \[
# \begin{align*}
# R(u) &= \frac{\mu}{2}\langle A_1 u, A_1 u\rangle_{V^2} + \frac{\lambda + \mu}{2}\langle A_2 u, A_2 u\rangle_{V^2} \\
# &= \frac{\mu}{2}\left(\langle \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &\quad+ \frac{\lambda + \mu}{2}\left(\langle \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\mu \langle \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &\quad+ \frac{1}{2}\left((\lambda + \mu) \langle \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\langle \mu \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \mu \begin{bmatrix} dy & dx \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) \begin{bmatrix} dx & dy \end{bmatrix}^T \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\left(\langle \mu A_1^TA_1 \begin{bmatrix} u_x \\ u_y \end{bmatrix} + (\lambda + \mu) A_2^TA_2 \begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V} \right) \\
# &= \frac{1}{2}\langle A\begin{bmatrix} u_x \\ u_y \end{bmatrix}, \begin{bmatrix} u_x \\ u_y \end{bmatrix} \rangle_{V^2},
# \end{align*}
# \]
#
# où $$A = \mu A_1^TA_1 + (\lambda + \mu) A_2^TA_2$$
#
# </div>
#
# **Q4.** Donner l'expression du gradient de $R$.
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# Comme $R(u)=\frac{\mu}{2}R_1(u)+ \frac{\lambda+\mu}{2} R_2(u)$, on a $\nabla R(u) = \frac{\mu}{2} \nabla R_1(u) + \frac{\lambda+\mu}{2} \nabla R_2(u)$.
#
# Pour $\nabla R_1(u)$ :
#
# On a $\forall (u,h) \in V^2$ :
# $$
# \begin{align*}
# R_1(u+h)
# &= R_1(u) + 2 \langle A_1^T A_1 u,h\rangle + o(\|h\|) \\
# \end{align*}
# $$
# Ainsi :
#
# $$
# \begin{align}
# \nabla R_1(u) &= 2 A_1^T A_1 u \\
# &= 2 \begin{bmatrix}
# \partial_y^T \\
# \partial_x^T
# \end{bmatrix} \begin{bmatrix}
# \partial_y & \partial_x
# \end{bmatrix} \begin{bmatrix}
# u_x \\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}
# \partial_y^T \partial_y & \partial_y^T \partial_x \\
# \partial_x^T \partial_y & \partial_x^T \partial_x
# \end{bmatrix} \begin{bmatrix}
# u_x \\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}
# \partial_y^T \partial_y u_x + \partial_y^T \partial_x u_y \\
# \partial_x^T \partial_y u_x + \partial_x^T \partial_x u_y
# \end{bmatrix}
# \end{align}
# $$
#
# Pour $\nabla R_2(u)$ :
#
# On a $\forall (u,h) \in V^2$ :
# $$
# \begin{align*}
# R_2(u+h)
# &= R_2(u) + 2 \langle A_2^T A_2 u,h\rangle + o(\|h\|) \\
# \end{align*}
# $$
# Ainsi :
# $$\begin{align}
# \nabla R_2(u) &= 2 A_2^T A_2 u \\
# &= 2 \begin{bmatrix}
# \partial_x^T\\
# \partial_y^T
# \end{bmatrix} (\partial_x \text{ } \partial_y) \begin{bmatrix}
# u_x\\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}\partial_x^T\partial_x & \partial_x^T\partial_y \\ \partial_y^T\partial_x & \partial_y^T\partial_y \end{bmatrix} \begin{bmatrix}
# u_x\\
# u_y
# \end{bmatrix} \\
# &= 2 \begin{bmatrix}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{bmatrix}
# \end{align}$$
#
# Finalement, on a :
# $$ \nabla R(u) = \mu \begin{bmatrix}\partial_y^T\partial_yu_x + \partial_y^T\partial_xu_y\\ \partial_x^T\partial_yu_x +  \partial_x^T\partial_xu_y\end{bmatrix} + (\lambda +\mu) \begin{bmatrix}\partial_x^T\partial_x u_x + \partial_x^T\partial_y u_y\\ \partial_y^T\partial_x u_x +  \partial_y^T\partial_y u_y\end{bmatrix}
# $$
# </div>
#
# ## 2.3. Implémentation de la fonction objectif $E+R$
#
# Créez une fonction `objective_function` qui calcul $E(u)+R(u)$.
#
# Cette fonction prend en variable d'entrée
# * `f`,`g` et `ux` et `uy` qui sont nécessaires au calcul de $E(u)$
# * `ux`,`uy` ,`lamb` et `mu` qui sont nécessaires au calcul de $R(u)$. Ici `lamb` et `mu` sont deux variables réelles positives qui représentent $\lambda$ et $\mu$.
#
#
# Cette fonction doit rendre deux arguments :
# * `obj` qui est la valeur de $E(u)+R(u)$
# * `fu` qui est un tableau qui représente le résultat du calcul de $f\circ(Id +u)$. On rend ce tableau car il sera utile pour les prochains calculs.

# %%
def objective_function(f,g,ux,uy,lamb,mu) :
    #implementation de E(u)+R(u)
    fu=interpol(f, ux, uy)
    
    #Calcul de R
    R= mu/2 * np.linalg.norm(dx(uy)+dy(ux))**2 + (lamb+mu)/2 * np.linalg.norm(dx(ux)+dy(uy))**2
    
    #Calcul de E
    E=1/2*np.linalg.norm(fu-g)**2  
    
    obj = R+E
    return obj,fu

np.random.seed(12)
ux=np.random.randn(f.shape[0],f.shape[1])
uy=np.random.randn(f.shape[0],f.shape[1])
obj,fu=objective_function(2*f,3*g,ux,uy,10,5)
print(obj,fu.shape,np.linalg.norm(fu)) #18215.406074781582 (21, 21) 22.047265562734097
# Out:
# 18215.406074781582 (21, 21) 22.047265562734097

# %% [markdown]
# ## 2.4 Implémentation des gradients
# Créez une fonction `gradE` et `gradR` qui calcule $\nabla E(u)$ et $\nabla R(u)$. On garde les conventions de noms de variable de la section précédente et on notera `gradxE,gradyE` les deux composantes de  $\nabla E(u)$ et `gradxR,gradyR` les deux composantes de $\nabla R(u)$. Les variables `dfx` et `dfy`contiennent les dérivées selon `x` et `y` de `f`, elles seront initalisées par `dfx=dx(f)` et `dfy=dy(f)`

# %%
def gradE(dfx,dfy,g,fu,ux,uy) :
    gradxE=(fu-g)*(interpol(dfx,ux,uy))
    gradyE=(fu-g)*(interpol(dfy,ux,uy))
    return gradxE,gradyE

def gradR(lamb,mu,ux,uy) :
    gradxR = mu*dyT(dy(ux)) + (lamb+mu)*dxT(dx(ux)) + mu*dyT(dx(uy)) + (lamb+mu)*dxT(dy(uy))
    gradyR = mu*dxT(dy(ux)) + (mu+lamb)*dyT(dx(ux)) + mu*dxT(dx(uy)) + (lamb+mu)*dyT(dy(uy))
    return gradxR,gradyR

# %%
dfx=dx(f)
dfy=dy(f)  
np.random.seed(12)
ux=np.random.randn(f.shape[0],f.shape[1])
uy=np.random.randn(f.shape[0],f.shape[1])
obj,fu=objective_function(f,g,ux,uy,10,5)
gradxE,gradyE=gradE(dfx,dfy,g,fu,ux,uy)
print(gradxE.shape,gradyE.shape) #(21, 21) (21, 21)
print(np.linalg.norm(gradxE),np.linalg.norm(gradyE)) #0.6513993385167333 0.6040320505869908
gradxR,gradyR=gradR(10.,5.,ux,uy) 
print(gradxR.shape,gradyR.shape)  #(21, 21) (21, 21)
print(np.linalg.norm(gradxR),np.linalg.norm(gradyR)) #1180.7792368512296 1239.1880693357143
# Out:
# (21, 21) (21, 21)
# 0.6513993385167333 0.6040320505869909
# (21, 21) (21, 21)
# 1180.7792368512296 1239.1880693357143

# %% [markdown]
# # 3. Un algorithme de gradient
#
# Une itération de la méthode de descente de gradient est de la forme:
#
# $$
# u_{k+1}=u_k-s_k(\nabla E(u) + \nabla R(u))
# $$
#
# **Q5.** Compléter la fonction RecalageDG implémentant la descente de gradient et utilisant l'algorithme de recherche linéaire par rebroussement proposé ci-dessous.

# %%
def linesearch(ux,uy,step,descentx,descenty,obj_old,f,g,lamb,mu) :
    step=2*step
    tmpx=ux-step*descentx
    tmpy=uy-step*descenty
    obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    while obj >obj_old and step > 1.e-8:
        step=0.5*step
        tmpx=ux-step*descentx
        tmpy=uy-step*descenty
        obj,fu=objective_function(f,g,tmpx,tmpy,lamb,mu)
    return tmpx,tmpy,step


def RecalageDG(f,g,lamb,mu,nitermax,stepini) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    dfx = dx(f)
    dfy = dy(f)
    # raise ValueError('Compute dfx and dfy here')
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj) 
        gradiE = gradE(dfx,dfy,g,fu,ux,uy)
        gradiR = gradR(lamb,mu,ux,uy)
        # raise ValueError('Compute gradxE and gradyE here')
        # raise ValueError('Compute gradRx and gradRy here')
        # raise ValueError('Compute gradx and grady here')

        gradx = gradiE[0] + gradiR[0]
        grady = gradiE[1] + gradiR[1]
        
        ux,uy,step=linesearch(ux,uy,step,gradx,grady,obj,f,g,lamb,mu)
        step_list.append(step)
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step, 'lambda :', lamb, 'mu :', mu)
    return ux,uy,np.array(CF),np.array(step_list), niter

# %% [markdown]
# **Q5.** Ecrire un compte-rendu des expériences réalisées et des résultats obtenus. Commentez.

# %%
lamb=10
mu=20
nitermax=500

step0 = 0.01
ux,uy,CF,step=RecalageDG(f,g,lamb,mu,nitermax,step0)
# la premiere ligne est 
# iteration : 3  cost function : 19.08125492560699 step : 0.08
# Out:
# iteration : 3  cost function : 19.08125492560699 step : 0.08 lambda : 10 mu : 20
# iteration : 6  cost function : 19.04274372706119 step : 0.02 lambda : 10 mu : 20
# iteration : 9  cost function : 19.031367910404175 step : 0.01 lambda : 10 mu : 20
# iteration : 12  cost function : 19.02412383888724 step : 0.01 lambda : 10 mu : 20
# iteration : 15  cost function : 19.01806210880887 step : 0.01 lambda : 10 mu : 20
# iteration : 18  cost function : 19.01253459257596 step : 0.005 lambda : 10 mu : 20
# iteration : 21  cost function : 19.008553844127363 step : 0.005 lambda : 10 mu : 20
# iteration : 24  cost function : 19.003094849027036 step : 0.005 lambda : 10 mu : 20
# iteration : 27  cost function : 18.998331455413695 step : 0.005 lambda : 10 mu : 20
# iteration : 30  cost function : 18.993817208909224 step : 0.005 lambda : 10 mu : 20
# iteration : 33  cost function : 18.98942613970379 step : 0.005 lambda : 10 mu : 20
# iteration : 36  cost function : 18.985108875837884 step : 0.01 lambda : 10 mu : 20
# iteration : 39  cost function : 18.98193380064393 step : 0.005 lambda : 10 mu : 20
# iteration : 42  cost function : 18.977325922524685 step : 0.005 lambda : 10 mu : 20
# iteration : 45  cost function : 18.972843826776202 step : 0.005 lambda : 10 mu : 20
# iteration : 48  cost function : 18.968449166662687 step : 0.005 lambda : 10 mu : 20
# iteration : 51  cost function : 18.96411855651942 step : 0.005 lambda : 10 mu : 20
# iteration : 54  cost function : 18.95983736149077 step : 0.005 lambda : 10 mu : 20
# iteration : 57  cost function : 18.955596083666894 step : 0.005 lambda : 10 mu : 20
# iteration : 60  cost function : 18.951388393440915 step : 0.005 lambda : 10 mu : 20
# iteration : 63  cost function : 18.947209860284694 step : 0.005 lambda : 10 mu : 20
# iteration : 66  cost function : 18.943057295592574 step : 0.005 lambda : 10 mu : 20
# iteration : 69  cost function : 18.938928261804136 step : 0.005 lambda : 10 mu : 20
# iteration : 72  cost function : 18.934820860061198 step : 0.005 lambda : 10 mu : 20
# iteration : 75  cost function : 18.930733516401435 step : 0.005 lambda : 10 mu : 20
# iteration : 78  cost function : 18.926664925350405 step : 0.005 lambda : 10 mu : 20
# iteration : 81  cost function : 18.922613939873933 step : 0.005 lambda : 10 mu : 20
# iteration : 84  cost function : 18.91857956998594 step : 0.005 lambda : 10 mu : 20
# iteration : 87  cost function : 18.914560914210174 step : 0.005 lambda : 10 mu : 20
# iteration : 90  cost function : 18.91055717712617 step : 0.005 lambda : 10 mu : 20
# iteration : 93  cost function : 18.906567619263814 step : 0.005 lambda : 10 mu : 20
# iteration : 96  cost function : 18.902591580487112 step : 0.005 lambda : 10 mu : 20
# iteration : 99  cost function : 18.899894101344827 step : 0.005 lambda : 10 mu : 20
# iteration : 102  cost function : 18.8957089693087 step : 0.005 lambda : 10 mu : 20
# iteration : 105  cost function : 18.891557546987066 step : 0.005 lambda : 10 mu : 20
# iteration : 108  cost function : 18.88743731390891 step : 0.005 lambda : 10 mu : 20
# iteration : 111  cost function : 18.883345944010326 step : 0.005 lambda : 10 mu : 20
# iteration : 114  cost function : 18.87928135837361 step : 0.005 lambda : 10 mu : 20
# iteration : 117  cost function : 18.87524163026441 step : 0.005 lambda : 10 mu : 20
# iteration : 120  cost function : 18.87122503689638 step : 0.005 lambda : 10 mu : 20
# iteration : 123  cost function : 18.867229975793556 step : 0.005 lambda : 10 mu : 20
# iteration : 126  cost function : 18.863255014332086 step : 0.005 lambda : 10 mu : 20
# iteration : 129  cost function : 18.85929881540263 step : 0.005 lambda : 10 mu : 20
# iteration : 132  cost function : 18.855360184228275 step : 0.005 lambda : 10 mu : 20
# iteration : 135  cost function : 18.851438001924986 step : 0.005 lambda : 10 mu : 20
# iteration : 138  cost function : 18.847531269431908 step : 0.005 lambda : 10 mu : 20
# iteration : 141  cost function : 18.843639047906684 step : 0.005 lambda : 10 mu : 20
# iteration : 144  cost function : 18.839760499765575 step : 0.005 lambda : 10 mu : 20
# iteration : 147  cost function : 18.83589483505894 step : 0.005 lambda : 10 mu : 20
# iteration : 150  cost function : 18.832041349699008 step : 0.005 lambda : 10 mu : 20
# iteration : 153  cost function : 18.828199377103992 step : 0.005 lambda : 10 mu : 20
# iteration : 156  cost function : 18.824368323732774 step : 0.005 lambda : 10 mu : 20
# iteration : 159  cost function : 18.820547625392724 step : 0.005 lambda : 10 mu : 20
# iteration : 162  cost function : 18.816736780220754 step : 0.005 lambda : 10 mu : 20
# iteration : 165  cost function : 18.8129353091347 step : 0.005 lambda : 10 mu : 20
# iteration : 168  cost function : 18.809142786408767 step : 0.01 lambda : 10 mu : 20
# iteration : 171  cost function : 18.806415920417116 step : 0.005 lambda : 10 mu : 20
# iteration : 174  cost function : 18.80242967645001 step : 0.005 lambda : 10 mu : 20
# iteration : 177  cost function : 18.79847074716217 step : 0.005 lambda : 10 mu : 20
# iteration : 180  cost function : 18.79453704120644 step : 0.005 lambda : 10 mu : 20
# iteration : 183  cost function : 18.79062661534632 step : 0.005 lambda : 10 mu : 20
# iteration : 186  cost function : 18.786737736537987 step : 0.005 lambda : 10 mu : 20
# iteration : 189  cost function : 18.782868790308378 step : 0.005 lambda : 10 mu : 20
# iteration : 192  cost function : 18.779018317081064 step : 0.005 lambda : 10 mu : 20
# iteration : 195  cost function : 18.775184920900042 step : 0.005 lambda : 10 mu : 20
# iteration : 198  cost function : 18.77136754344816 step : 0.005 lambda : 10 mu : 20
# iteration : 201  cost function : 18.767564948704205 step : 0.005 lambda : 10 mu : 20
# iteration : 204  cost function : 18.76377625716318 step : 0.005 lambda : 10 mu : 20
# iteration : 207  cost function : 18.760000429467713 step : 0.005 lambda : 10 mu : 20
# iteration : 210  cost function : 18.756236742170803 step : 0.005 lambda : 10 mu : 20
# iteration : 213  cost function : 18.75248431948168 step : 0.005 lambda : 10 mu : 20
# iteration : 216  cost function : 18.748742566075222 step : 0.005 lambda : 10 mu : 20
# iteration : 219  cost function : 18.745010742330013 step : 0.005 lambda : 10 mu : 20
# iteration : 222  cost function : 18.741288358077217 step : 0.005 lambda : 10 mu : 20
# iteration : 225  cost function : 18.73757478717401 step : 0.005 lambda : 10 mu : 20
# iteration : 228  cost function : 18.73386962573169 step : 0.005 lambda : 10 mu : 20
# iteration : 231  cost function : 18.730172342283 step : 0.005 lambda : 10 mu : 20
# iteration : 234  cost function : 18.7264826037078 step : 0.005 lambda : 10 mu : 20
# iteration : 237  cost function : 18.722799957623913 step : 0.01 lambda : 10 mu : 20
# iteration : 240  cost function : 18.72019188852294 step : 0.005 lambda : 10 mu : 20
# iteration : 243  cost function : 18.716313787875784 step : 0.005 lambda : 10 mu : 20
# iteration : 246  cost function : 18.71246124515657 step : 0.005 lambda : 10 mu : 20
# iteration : 249  cost function : 18.70863202954588 step : 0.005 lambda : 10 mu : 20
# iteration : 252  cost function : 18.704824459577715 step : 0.005 lambda : 10 mu : 20
# iteration : 255  cost function : 18.70103667379766 step : 0.005 lambda : 10 mu : 20
# iteration : 258  cost function : 18.697267294763815 step : 0.005 lambda : 10 mu : 20
# iteration : 261  cost function : 18.693514767251177 step : 0.005 lambda : 10 mu : 20
# iteration : 264  cost function : 18.689777963397116 step : 0.005 lambda : 10 mu : 20
# iteration : 267  cost function : 18.68605558200882 step : 0.005 lambda : 10 mu : 20
# iteration : 270  cost function : 18.682346700020624 step : 0.005 lambda : 10 mu : 20
# iteration : 273  cost function : 18.678650227105376 step : 0.005 lambda : 10 mu : 20
# iteration : 276  cost function : 18.674965408168344 step : 0.005 lambda : 10 mu : 20
# iteration : 279  cost function : 18.671291328038365 step : 0.005 lambda : 10 mu : 20
# iteration : 282  cost function : 18.667627369316232 step : 0.005 lambda : 10 mu : 20
# iteration : 285  cost function : 18.663972762435474 step : 0.005 lambda : 10 mu : 20
# iteration : 288  cost function : 18.660327002809627 step : 0.005 lambda : 10 mu : 20
# iteration : 291  cost function : 18.65668944201258 step : 0.005 lambda : 10 mu : 20
# iteration : 294  cost function : 18.653059667826536 step : 0.005 lambda : 10 mu : 20
# iteration : 297  cost function : 18.649437132704207 step : 0.005 lambda : 10 mu : 20
# iteration : 300  cost function : 18.64582150000522 step : 0.005 lambda : 10 mu : 20
# iteration : 303  cost function : 18.642212306272743 step : 0.005 lambda : 10 mu : 20
# iteration : 306  cost function : 18.638609276658222 step : 0.005 lambda : 10 mu : 20
# iteration : 309  cost function : 18.636081125720096 step : 0.005 lambda : 10 mu : 20
# iteration : 312  cost function : 18.63228273291909 step : 0.005 lambda : 10 mu : 20
# iteration : 315  cost function : 18.628508576067027 step : 0.005 lambda : 10 mu : 20
# iteration : 318  cost function : 18.624756842767926 step : 0.005 lambda : 10 mu : 20
# iteration : 321  cost function : 18.62102553158656 step : 0.005 lambda : 10 mu : 20
# iteration : 324  cost function : 18.617313160513664 step : 0.005 lambda : 10 mu : 20
# iteration : 327  cost function : 18.613618059908873 step : 0.005 lambda : 10 mu : 20
# iteration : 330  cost function : 18.60993901886787 step : 0.005 lambda : 10 mu : 20
# iteration : 333  cost function : 18.606274642845097 step : 0.005 lambda : 10 mu : 20
# iteration : 336  cost function : 18.602623943284307 step : 0.005 lambda : 10 mu : 20
# iteration : 339  cost function : 18.59898575385332 step : 0.005 lambda : 10 mu : 20
# iteration : 342  cost function : 18.595359268253905 step : 0.005 lambda : 10 mu : 20
# iteration : 345  cost function : 18.591743509593144 step : 0.005 lambda : 10 mu : 20
# iteration : 348  cost function : 18.588137820876614 step : 0.005 lambda : 10 mu : 20
# iteration : 351  cost function : 18.5845413825717 step : 0.005 lambda : 10 mu : 20
# iteration : 354  cost function : 18.580953659907923 step : 0.005 lambda : 10 mu : 20
# iteration : 357  cost function : 18.57737396416397 step : 0.005 lambda : 10 mu : 20
# iteration : 360  cost function : 18.57380186054859 step : 0.005 lambda : 10 mu : 20
# iteration : 363  cost function : 18.57023676917109 step : 0.005 lambda : 10 mu : 20
# iteration : 366  cost function : 18.566678336953768 step : 0.005 lambda : 10 mu : 20
# iteration : 369  cost function : 18.563126074630482 step : 0.005 lambda : 10 mu : 20
# iteration : 372  cost function : 18.5595796958453 step : 0.005 lambda : 10 mu : 20
# iteration : 375  cost function : 18.556038786870044 step : 0.005 lambda : 10 mu : 20
# iteration : 378  cost function : 18.553568305093318 step : 0.005 lambda : 10 mu : 20
# iteration : 381  cost function : 18.549832820602138 step : 0.005 lambda : 10 mu : 20
# iteration : 384  cost function : 18.546120989716968 step : 0.005 lambda : 10 mu : 20
# iteration : 387  cost function : 18.542430646423732 step : 0.005 lambda : 10 mu : 20
# iteration : 390  cost function : 18.538760186221996 step : 0.005 lambda : 10 mu : 20
# iteration : 393  cost function : 18.535107803632254 step : 0.005 lambda : 10 mu : 20
# iteration : 396  cost function : 18.531472189211556 step : 0.005 lambda : 10 mu : 20
# iteration : 399  cost function : 18.527851836325045 step : 0.005 lambda : 10 mu : 20
# iteration : 402  cost function : 18.524245677466624 step : 0.005 lambda : 10 mu : 20
# iteration : 405  cost function : 18.520652453844555 step : 0.005 lambda : 10 mu : 20
# iteration : 408  cost function : 18.5170712962132 step : 0.005 lambda : 10 mu : 20
# iteration : 411  cost function : 18.513501151447368 step : 0.005 lambda : 10 mu : 20
# iteration : 414  cost function : 18.509941312661468 step : 0.005 lambda : 10 mu : 20
# iteration : 417  cost function : 18.50639089750773 step : 0.005 lambda : 10 mu : 20
# iteration : 420  cost function : 18.502849331961517 step : 0.005 lambda : 10 mu : 20
# iteration : 423  cost function : 18.49931587558215 step : 0.005 lambda : 10 mu : 20
# iteration : 426  cost function : 18.495790062975797 step : 0.005 lambda : 10 mu : 20
# iteration : 429  cost function : 18.492271271710173 step : 0.005 lambda : 10 mu : 20
# iteration : 432  cost function : 18.48875912512818 step : 0.005 lambda : 10 mu : 20
# iteration : 435  cost function : 18.485253099014887 step : 0.005 lambda : 10 mu : 20
# iteration : 438  cost function : 18.481752889123314 step : 0.005 lambda : 10 mu : 20
# iteration : 441  cost function : 18.478258053059342 step : 0.005 lambda : 10 mu : 20
# iteration : 444  cost function : 18.474768345594132 step : 0.005 lambda : 10 mu : 20
# iteration : 447  cost function : 18.4723412991964 step : 0.005 lambda : 10 mu : 20
# iteration : 450  cost function : 18.468658357070172 step : 0.005 lambda : 10 mu : 20
# iteration : 453  cost function : 18.464998271778413 step : 0.005 lambda : 10 mu : 20
# iteration : 456  cost function : 18.461359301832236 step : 0.005 lambda : 10 mu : 20
# iteration : 459  cost function : 18.457739487647103 step : 0.005 lambda : 10 mu : 20
# iteration : 462  cost function : 18.454137409044115 step : 0.005 lambda : 10 mu : 20
# iteration : 465  cost function : 18.45055143156227 step : 0.005 lambda : 10 mu : 20
# iteration : 468  cost function : 18.446980398451704 step : 0.005 lambda : 10 mu : 20
# iteration : 471  cost function : 18.4434229448529 step : 0.005 lambda : 10 mu : 20
# iteration : 474  cost function : 18.439878129855323 step : 0.005 lambda : 10 mu : 20
# iteration : 477  cost function : 18.43634481228886 step : 0.005 lambda : 10 mu : 20
# iteration : 480  cost function : 18.432822227965943 step : 0.005 lambda : 10 mu : 20
# iteration : 483  cost function : 18.42930942142915 step : 0.005 lambda : 10 mu : 20
# iteration : 486  cost function : 18.425805773073172 step : 0.005 lambda : 10 mu : 20
# iteration : 489  cost function : 18.42231048173011 step : 0.005 lambda : 10 mu : 20
# iteration : 492  cost function : 18.418823045977838 step : 0.005 lambda : 10 mu : 20
# iteration : 495  cost function : 18.415342792928172 step : 0.005 lambda : 10 mu : 20
# iteration : 498  cost function : 18.411869317668142 step : 0.005 lambda : 10 mu : 20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       3 nitermax=500
#       5 step0 = 0.01
# ----> 6 ux,uy,CF,step=RecalageDG(f,g,lamb,mu,nitermax,step0)
#       7 # la premiere ligne est
#       8 # iteration : 3  cost function : 19.08125492560699 step : 0.08
#
# ValueError: too many values to unpack (expected 4)

# %% [markdown]
# Pour trouver les lambda et mu optimaux, on va essayer différentes valeurs avec le code ci dessous. Puis nous allons choisir les valeurs correspondant à un nombre d'itérations minimales pour une petite valeur de cost function.

# %% [markdown]
# Nous commencer par encadrer "grossièrement" les valeurs de lambda et mu, puis nous précisons nos encadrements en fonction des résultats. Dans l'exemple ci dessous nous supposons lambda et mu entre 0 et 0.1.

# %%
niter0_ex = np.zeros((5,5))
lamb_ex = np.linspace(0,0.1,5)
mu_ex = np.linspace(0,0.1,5)
step0 = 0.01

for i in range(5) :
    for j in range(5) :
        ux,uy,CF,step,niter0_ex[i,j] = RecalageDG(f,g,lamb_ex[i],mu_ex[j],5000,step0)
# Out:
# iteration : 3  cost function : 19.06623882452692 step : 0.08 lambda : 0.0 mu : 0.0
# iteration : 6  cost function : 18.595258262417495 step : 0.64 lambda : 0.0 mu : 0.0
# iteration : 9  cost function : 15.126932772447313 step : 5.12 lambda : 0.0 mu : 0.0
# iteration : 12  cost function : 3.807501264583158 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 15  cost function : 1.6020648694221906 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 18  cost function : 1.3608530905382872 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 21  cost function : 1.2872979739761912 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 24  cost function : 1.2274776240596144 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 27  cost function : 1.1802092219987779 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 30  cost function : 1.1551267202011608 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 33  cost function : 1.1365278524891584 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 36  cost function : 1.12233150417942 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 39  cost function : 1.1118244832309705 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 42  cost function : 1.1004958632326534 step : 40.96 lambda : 0.0 mu : 0.0
# iteration :
step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 294  cost function : 1.010022835397498 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 297  cost function : 1.0099408705358361 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 300  cost function : 1.009862254670269 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 303  cost function : 1.009785483977728 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 306  cost function : 1.00971074301727 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 309  cost function : 1.0096370442830362 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 312  cost function : 1.0095643843019764 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 315  cost function : 1.0094922026216109 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 318  cost function : 1.0094206159755343 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 321  cost function : 1.0093689207616596 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 324  cost function : 1.0092918260574422 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 327  cost function : 1.0092161836589668 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 330  cost function : 1.0091440584640634 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 333  cost function : 1.0090741586593106 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 336  cost function : 1.009007720956138 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 339  cost function : 1.0089440344064222 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 342  cost function : 1.0088837671941804 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 345  cost function : 1.0088264291496498 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 348  cost function : 1.008772235950622 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 351  cost function : 1.0087207834630392 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 354  cost function : 1.008672079734866 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 357  cost function : 1.0086257761451447 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 360  cost function : 1.0085817656801812 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 363  cost function : 1.0085528774945929 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 366  cost function : 1.008508820416934 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 369  cost function : 1.0084666218514486 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 372  cost function : 1.0084268973807624 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 375  cost function : 1.0083886377262843 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 378  cost function : 1.0083521201782604 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 381  cost function : 1.008316722061161 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 384  cost function : 1.0082825496637504 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 387  cost function : 1.0082492115739508 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 390  cost function : 1.008216733207378 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 393  cost function : 1.0081848677405552 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 396  cost function : 1.008153609545417 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 399  cost function : 1.0081228065725747 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 402  cost function : 1.008092448478966 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 405  cost function : 1.0080692505340394 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 408  cost function : 1.0080369063384989 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 411  cost function : 1.0080051344039629 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 414  cost function : 1.00797430583949 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 417  cost function : 1.007943994811332 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 420  cost function : 1.0079144114333334 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 423  cost function : 1.007885319902217 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 426  cost function : 1.0078568414430606 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 429  cost function : 1.0078288459374407 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 432  cost function : 1.0078014023583657 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 435  cost function : 1.0077744364987071 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 438  cost function : 1.0077479838931613 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 441  cost function : 1.0077286777500603 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 444  cost function : 1.007700758958184 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 447  cost function : 1.0076735269916512 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 450  cost function : 1.007647286415798 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 453  cost function : 1.007621638488493 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 456  cost function : 1.0075967307837277 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 459  cost function : 1.0075723170635245 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 462  cost function : 1.0075484586276104 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 465  cost function : 1.0075249965549573 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 468  cost function : 1.0075019455330174 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 471  cost function : 1.007479197178571 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 474  cost function : 1.0074567414350193 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 477  cost function : 1.0074411589503978 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 480  cost function : 1.0074167998389307 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 483  cost function : 1.0073927967207714 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 486  cost function : 1.0073693919448095 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 489  cost function : 1.007346213466861 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 492  cost function : 1.0073233746232886 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 495  cost function : 1.007300645944278 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 498  cost function : 1.0072780721983146 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 501  cost function : 1.0072555075413652 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 504  cost function : 1.0072329616118365 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 507  cost function : 1.0072103377926536 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 510  cost function : 1.0071876276750658 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 513  cost function : 1.0071700033528128 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 516  cost function : 1.0071447311278305 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 519  cost function : 1.0071194536603136 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 522  cost function : 1.0070943855877985 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 525  cost function : 1.0070692020044316 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 528  cost function : 1.0070440050903584 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 531  cost function : 1.0070185958135314 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 534  cost function : 1.0069930162520198 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 537  cost function : 1.0069671404785705 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 540  cost function : 1.0069409789998482 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 543  cost function : 1.0069229134089863 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 546  cost function : 1.0068929593272444 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 549  cost function : 1.0068628335445025 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 552  cost function : 1.0068329044960838 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 555  cost function : 1.0068026940115615 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 558  cost function : 1.0067723897266707 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 561  cost function : 1.006741707288465 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 564  cost function : 1.0067107381906406 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 567  cost function : 1.0066793113356443 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 570  cost function : 1.0066474687924205 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 573  cost function : 1.0066151077179248 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 576  cost function : 1.0065906854029647 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 579  cost function : 1.0065535126598106 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 582  cost function : 1.0065167381759859 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 585  cost function : 1.006479675643822 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 588  cost function : 1.006442678137175 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 591  cost function : 1.0064053637817327 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 594  cost function : 1.0063679378246533 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 597  cost function : 1.0063301980231953 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 600  cost function : 1.0062922756546264 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 603  cost function : 1.0062540772844195 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 606  cost function : 1.0062157003151881 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 609  cost function : 1.006185564689459 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 612  cost function : 1.0061432608716496 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 615  cost function : 1.0061011751345101 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 618  cost function : 1.0060599210933057 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 621  cost function : 1.0060189623088938 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 624  cost function : 1.0059786676259115 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 627  cost function : 1.0059387695963147 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 630  cost function : 1.0058995178240906 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 633  cost function : 1.0058608030000236 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 636  cost function : 1.0058227998221492 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 639  cost function : 1.0057854795225158 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 642  cost function : 1.0057605731869157 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 645  cost function : 1.0057207878376744 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 648  cost function : 1.0056831067011838 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 651  cost function : 1.0056466750966917 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 654  cost function : 1.0056120107256297 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 657  cost function : 1.0055786331749395 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 660  cost function : 1.0055468282435422 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 663  cost function : 1.005516321011987 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 666  cost function : 1.0054872638338481 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 669  cost function : 1.0054594927440044 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 672  cost function : 1.0054330814242018 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 675  cost function : 1.00540792429484 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 678  cost function : 1.0053840479211467 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 681  cost function : 1.0053613787395892 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 684  cost function : 1.0053399157511889 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 687  cost function : 1.0053249734148693 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 690  cost function : 1.0053041280174217 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 693  cost function : 1.0052845563727266 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 696  cost function : 1.0052664319560707 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 699  cost function : 1.0052494445128757 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 702  cost function : 1.0052336631468017 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 705  cost function : 1.005218887437567 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 708  cost function : 1.0052051312484311 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 711  cost function : 1.0051922587386692 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 714  cost function : 1.005180255714555 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 717  cost function : 1.0051690253203447 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 720  cost function : 1.0051585402714194 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 723  cost function : 1.0051487281078952 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 726  cost function : 1.0051395566005197 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 729  cost function : 1.0051309692647805 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 732  cost function : 1.005122933260376 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 735  cost function : 1.005115403120993 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 738  cost function : 1.0051102503479143 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 741  cost function : 1.00510302418189 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 744  cost function : 1.0050963565835882 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 747  cost function : 1.0050901384351008 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 750  cost function : 1.005084368056471 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 753  cost function : 1.0050789728948581 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 756  cost function : 1.005073941783658 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 759  cost function : 1.0050692247292121 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 762  cost function : 1.0050648070574948 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 765  cost function : 1.0050606530563646 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 768  cost function : 1.0050567475301824 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 771  cost function : 1.005053064084743 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 774  cost function : 1.0050495884031203 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 777  cost function : 1.0050463003701509 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 780  cost function : 1.0050431870955818 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 783  cost function : 1.0050402328368575 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 786  cost function : 1.005038280554905 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 789  cost function : 1.0050353387231792 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 792  cost function : 1.0050325817327785 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 795  cost function : 1.0050299748016178 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 798  cost function : 1.0050275135312994 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 801  cost function : 1.005025174677749 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 804  cost function : 1.0050229524549932 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 807  cost function : 1.0050208308400248 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 810  cost function : 1.0050188039177388 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 813  cost function : 1.0050168602899912 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 816  cost function : 1.0050149944694793 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 819  cost function : 1.0050131980956865 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 822  cost function : 1.0050114663106204 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 825  cost function : 1.0050097928046104 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 828  cost function : 1.0050081733796523 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 831  cost function : 1.0050069937969714 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 834  cost function : 1.0050053268271133 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 837  cost function : 1.0050037250112567 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 840  cost function : 1.0050021862247194 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 843  cost function : 1.0050006991766085 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 846  cost function : 1.0049992612534087 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 849  cost function : 1.0049978648612723 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 852  cost function : 1.0049965074238523 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 855  cost function : 1.0049951836916757 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 858  cost function : 1.004993891340674 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 861  cost function : 1.0049926266384277 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 864  cost function : 1.0049913875766716 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 867  cost function : 1.0049901714268834 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 870  cost function : 1.0049892665694569 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 873  cost function : 1.0049879760027602 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 876  cost function : 1.0049867257578162 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 879  cost function : 1.0049855069227989 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 882  cost function : 1.0049843181220623 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 885  cost function : 1.0049831535737832 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 888  cost function : 1.004982011834243 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 891  cost function : 1.0049808890743417 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 894  cost function : 1.0049797839773686 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 897  cost function : 1.0049786939514205 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 900  cost function : 1.0049776178709329 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 903  cost function : 1.0049765539414166 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 906  cost function : 1.004975779644545 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 909  cost function : 1.0049746293378843 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 912  cost function : 1.0049735090012173 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 915  cost function : 1.0049724111295555 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 918  cost function : 1.004971334820902 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 921  cost function : 1.004970275306386 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 924  cost function : 1.0049692316128738 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 927  cost function : 1.00496820066863 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 930  cost function : 1.0049671815954293 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 933  cost function : 1.0049661723883068 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 936  cost function : 1.0049651723183284 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 939  cost function : 1.0049641800610798 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 942  cost function : 1.0049634417262063 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 945  cost function : 1.0049623639148986 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 948  cost function : 1.0049613110456577 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 951  cost function : 1.004960276641562 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 954  cost function : 1.0049592600167032 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 957  cost function : 1.0049582571163116 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 960  cost function : 1.0049572672153018 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 963  cost function : 1.0049562877612312 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 966  cost function : 1.004955318126265 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 969  cost function : 1.0049543567021897 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 972  cost function : 1.0049534030007692 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 975  cost function : 1.0049524560163414 step : 81.92 lambda : 0.0 mu : 0.0
# iteration : 978  cost function : 1.004951727854081 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 981  cost function : 1.0049507023562354 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 984  cost function : 1.0049496997536378 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 987  cost function : 1.0049487144027935 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 990  cost function : 1.004947745748063 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 993  cost function : 1.0049467903069258 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 996  cost function : 1.0049458475254465 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 999  cost function : 1.0049449152656142 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1002  cost function : 1.0049439930848254 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1005  cost function : 1.0049430796937022 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1008  cost function : 1.0049421747918115 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1011  cost function : 1.0049415617978306 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1014  cost function : 1.0049405738287769 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1017  cost function : 1.0049396091433536 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1020  cost function : 1.0049386675300063 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1023  cost function : 1.0049377441081495 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1026  cost function : 1.0049368384819448 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1029  cost function : 1.0049359477130144 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 1032  cost function : 1.004935071449105 step : 40.96 lambda : 0.0 mu : 0.0
# iteration : 
step : 1.28 lambda : 0.1 mu : 0.1
# iteration : 3666  cost function : 0.2651318837458176 step : 0.64 lambda : 0.1 mu : 0.1
# iteration : 3669  cost function : 0.2651316299363392 step : 0.64 lambda : 0.1 mu : 0.1
# iteration : 3672  cost function : 0.26513127055317365 step : 1.28 lambda : 0.1 mu : 0.1
# iteration : 3675  cost function : 0.26513112963532354 step : 0.32 lambda : 0.1 mu : 0.1
# iteration : 3678  cost function : 0.26513096636225003 step : 0.32 lambda : 0.1 mu : 0.1
# iteration : 3681  cost function : 0.26513093609623306 step : 0.16 lambda : 0.1 mu : 0.1
# iteration : 3684  cost function : 0.26513093529768716 step : 0.16 lambda : 0.1 mu : 0.1
# iteration : 3687  cost function : 0.26513093519727027 step : 1.52587890625e-07 lambda : 0.1 mu : 0.1
# iteration : 3690  cost function : 0.26513093519727027 step : 1.9073486328125e-08 lambda : 0.1 mu : 0.1

# %%
niter0_ex
# Out:
# array([[1171.,  788., 1679., 2269., 2571.],
#        [ 515., 1046., 2060., 2709., 2639.],
#        [1090., 1711., 2744., 2599., 3244.],
#        [1434., 2366., 3291., 2685., 3435.],
#        [1780., 2799., 2743., 3315., 3692.]])

# %% [markdown]
# Comme nous pouvons le voir avec la matrice ci dessus, le nombre d'itérations minimale (515) vaut pour lambda = 0.025 et mu = 0.0.

# %% [markdown]
# En continuant avec ce raisonnement, nous choississons les valeurs suivantes :
# - lambda = 0
# - mu = 0.0083
# Pour un nombre d'itération de 421 et une cost function d'environ 0.29.
#
# On notera qu'on pouvait avoir un nombre d'itération plus petit mais on aurait perdu en précision.

# %%
lamb=0.0
mu=0.0083
nitermax=500
step0 = 0.01
ux,uy,CF,step,niter =RecalageDG(f,g,lamb,mu,nitermax,step0)
# Out:
# iteration : 3  cost function : 0.1438107593083646 step : 0.08 lambda : 0.0 mu : 0.0083
# iteration : 6  cost function : 0.14380810074385666 step : 0.64 lambda : 0.0 mu : 0.0083
# iteration : 9  cost function : 0.14378685773730163 step : 5.12 lambda : 0.0 mu : 0.0083
# iteration : 12  cost function : 0.1436185283409062 step : 40.96 lambda : 0.0 mu : 0.0083
# iteration : 15  cost function : 0.1423666971168722 step : 327.68 lambda : 0.0 mu : 0.0083
# iteration : 18  cost function : 0.13582633775678107 step : 81.92 lambda : 0.0 mu : 0.0083
# iteration : 21  cost function : 0.13541580730156183 step : 81.92 lambda : 0.0 mu : 0.0083
# iteration : 24  cost function : 0.13519592773466785 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 27  cost function : 0.1350971406364225 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 30  cost function : 0.13504076573069357 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 33  cost function : 0.13493339384896902 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 36  cost function : 0.1348332629795226 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 39  cost function : 0.1347370782539073 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 42  cost function : 0.13464341140480668 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 45  cost function : 0.13455155142225614 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 48  cost function : 0.1344611076542203 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 51  cost function : 0.1343718487594326 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 54  cost function : 0.13428362941615213 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 57  cost function : 0.134196354151324 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 60  cost function : 0.1341099579599548 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 63  cost function : 0.1340243953107321 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 66  cost function : 0.13393963387149063 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 69  cost function : 0.13385565069954294 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 72  cost function : 0.13377242960153718 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 75  cost function : 0.13368995971410919 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 78  cost function : 0.1336082345731388 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 81  cost function : 0.13352725134240168 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 84  cost function : 0.13344701052823277 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 87  cost function : 0.13336751581689466 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration :
step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 348  cost function : 0.12787548051056624 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 351  cost function : 0.12782555296612633 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 354  cost function : 0.12777592292593745 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 357  cost function : 0.1277265999541816 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 360  cost function : 0.12767759544480192 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 363  cost function : 0.1276289229086262 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 366  cost function : 0.12758059831187268 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 369  cost function : 0.12753264046401502 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 372  cost function : 0.12748507147408064 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 375  cost function : 0.12743791727459264 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 378  cost function : 0.12739120823694758 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 381  cost function : 0.12734497987916862 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 384  cost function : 0.12729927369619198 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 387  cost function : 0.12725413811620478 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 390  cost function : 0.12720962962119012 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 393  cost function : 0.1271658140393613 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 396  cost function : 0.12710317352536366 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 399  cost function : 0.12705636518285618 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 402  cost function : 0.1270097903595365 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 405  cost function : 0.12696345298075326 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 408  cost function : 0.1269173578614152 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 411  cost function : 0.1268715108452176 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 414  cost function : 0.12682591897078124 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 417  cost function : 0.1267805906603824 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 420  cost function : 0.12673553594431514 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 423  cost function : 0.12669076671668195 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 426  cost function : 0.12664629703855937 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 429  cost function : 0.12660214348457785 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 432  cost function : 0.1265583255526937 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 435  cost function : 0.12651486613381746 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 438  cost function : 0.12647179206585993 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 441  cost function : 0.1264291347700591 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 444  cost function : 0.12638693100036844 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 447  cost function : 0.12634522370573745 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 450  cost function : 0.12630406304393424 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 453  cost function : 0.1262635075502069 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 456  cost function : 0.12622362550901642 step : 10.24 lambda : 0.0 mu : 0.0083
# iteration : 459  cost function : 0.12616448533634403 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 462  cost function : 0.1261215513661094 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 465  cost function : 0.12607882416275074 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 468  cost function : 0.1260363081645865 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 471  cost function : 0.12599400873920635 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 474  cost function : 0.12595193233133226 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 477  cost function : 0.12591008663998368 step : 20.48 lambda : 0.0 mu : 0.0083
# iteration : 480  cost function : 0.1258684808192262 step : 20.48 lambda : 0.0 mu : 0.0083
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 5
#       3 nitermax=500
#       4 step0 = 0.01
# ----> 5 ux,uy,CF,step,niter =RecalageDG(f,g,lamb,mu,nitermax,step0)
#
# Cell In[9], line 28, in RecalageDG(f, g, lamb, mu, nitermax, stepini)
#      26 obj,fu=objective_function(f,g,ux,uy,lamb,mu)
#      27 CF.append(obj)
# ---> 28 gradiE = gradE(dfx,dfy,g,fu,ux,uy)
#      29 gradiR = gradR(lamb,mu,ux,uy)
#      30 # raise ValueError('Compute gradxE and gradyE here')
#      31 # raise ValueError('Compute gradRx and gradRy here')
#      32 # raise ValueError('Compute gradx and grady here')
#
# Cell In[7], line 2, in gradE(dfx, dfy, g, fu, ux, uy)
#       1 def gradE(dfx,dfy,g,fu,ux,uy) :
# ----> 2     gradxE=(fu-g)*(interpol(dfx,ux,uy))
#       3     gradyE=(fu-g)*(interpol(dfy,ux,uy))
#       4     return gradxE,gradyE
#
# Cell In[4], line 8, in interpol(function, ux, uy)
#       6 X=X+ux
#       7 Y=Y+uy
# ----> 8 return np.reshape(ip.ev(X.ravel(),Y.ravel()),(nx,ny))
#
# File ~/.local/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:1252, in BivariateSpline.ev(self, xi, yi, dx, dy)
#    1192 def ev(self, xi, yi, dx=0, dy=0):
#    1193     """
#    1194     Evaluate the spline at points
#    1195
#    (...)
#    1250     >>> plt.show()
#    1251     """
# -> 1252     return self.__call__(xi, yi, dx=dx, dy=dy, grid=False)
#
# File ~/.local/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:1058, in _BivariateSplineBase.__call__(self, x, y, dx, dy, grid)
#    1056         raise ValueError("Error code returned by pardeu: %s" % ier)
#    1057 else:
# -> 1058     z, ier = dfitpack.bispeu(tx, ty, c, kx, ky, x, y)
#    1059     if not ier == 0:
#    1060         raise ValueError("Error code returned by bispeu: %s" % ier)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(2,3, figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - On remarque qu'on obtient bien notre target function. Il y a tout de même quelques différences comme sur le côté gauche notamment.
# - Le displacement field est correct également. L'axe n'est pas orienté dans le bon sens cependant.
# - On observe qu'avec peu de step on arrive à avoir à avoir une grande baisse de l'objective history. Mais pour avoir une valeur plus précise il nous faut plus d'itérations.
# - Pour finir, la valeur du step oscille entre 2 valeurs. Cela signifie qu'on est entre 2 niveaux.

# %% [markdown]
# # 4. Algorithme de moindres carrés.
#
# On souhaite maintenant implémenter un algorithme de second ordre pour résoudre le problème $$(P)\quad\min_u E(u)+R(u)$$ afin d'accélérer la convergence de l'algorithme. Pour cela, on va reformuler le problème $(P)$ en un problème de moindres carrés et appliquer l'algorithme de Levenberg-Marquardt.
#
# Soit:
# $$\Psi(u)=\begin{pmatrix}
# f\circ(Id+u)-g \\
# \sqrt{\mu}(\partial_xu_y+\partial_yu_x) \\
# \sqrt{\mu+\lambda}(\partial_xu_x+\partial_yu_y) \end{pmatrix},$$
# où $f\circ(id+u)$ est l'interpolation de $x\mapsto f(x+u(x))$ sur la grille. Minimiser $E(u)+R(u)$ est équivalent à résoudre le problème suivant:
#
# >$$\min_u \|\Psi(u)\|_2^2.$$
#
# Il s'agit maintenant d'un problème de moindres carrés que l'on va résoudre à l'aide de l'algorithme de Levenberg Marquardt :
#
# $$
# u_{k+1}=u_k- H_k^{-1} J_{\Psi}(u_k)^\top \Psi(u_k) \quad\mbox{ avec }\quad H_k=J_{\Psi}(u_k)^\top J_{\Psi}(u_k) +\varepsilon Id
# $$
#
# **Q6.** Calculer la matrice jacobienne de $\Psi$, notée $J_\Psi(u)$.
# <div style="background-color:rgba(255, 0,0, 0.1); padding:15px;">
# On cherche:
# $$J_{\psi}(u)=\begin{pmatrix}
# \nabla \psi_1(u)^T \\
# \nabla \psi_2(u)^T \\
# \nabla \psi_3(u)^T \
#  \end{pmatrix}$$
#
# Cherchons $\nabla \psi_1(u)$ :
# $$\begin{align}
# J_{\psi_1}(u)&=J_f(Id+u) \times J_{Id+u}(u) \\
# &=\nabla^Tf(Id+u) \times Id \\
# &=\nabla^Tf(Id+u)
# \end{align}$$
# Et $\nabla \psi_1(u)=(J_{\psi_1}(u))^T $
#
# Cherchons $\nabla \psi_2(u)$ :
# $$\begin{align}
# \nabla \psi_2(u)&=\sqrt{\mu} \nabla (\partial _x u_y + \partial _y u_x)\\
# &=\sqrt{\mu} \begin{pmatrix}
# \partial _y  \\
# \partial _x  \\
# \end{pmatrix}
# \end{align}$$
#
# Cherchons $\nabla \psi_3(u)$ :
# $$\begin{align}
# \nabla \psi_3(u)&=\sqrt{\lambda +\mu} \nabla (\partial _x u_x + \partial _y u_y)\\
# &=\sqrt{\lambda + \mu} \begin{pmatrix}
# \partial _x  \\
# \partial _y  \\
# \end{pmatrix}
# \end{align}$$
#
# Ainsi, on obtient:
# $$\begin{align}
# J_{\psi}(u) = \begin{pmatrix}
# df_x(Id+u) & df_y(Id+u) \\
# \sqrt{\mu}\partial _y   &\sqrt{\mu}\partial _x \\
# \sqrt{\lambda + \mu}\partial _x & \sqrt{\lambda +\mu}\partial _y \\
# \end{pmatrix}
# \end{align}$$
# </div>
#
# **Q7.** Implémenter les fonctions `Psi`,`JPsi`, `JTPsi` et `JTJ` qui calculent respectivement:
# - La valeur de $\Psi(u)$
# - le produit de $J_\Psi(u)$ par une direction $v=(v_x,v_y)\in V^2$,
#
# - le produit de $J_\Psi(u)^\top$ par $\phi=(\phi_1,\phi_2,\phi_3)\in V^3$,
#
# - le produit de $(J_\Psi(u)^\top J_\Psi(u)+\epsilon I)$ par une direction $v=(v_x,v_y)\in V^2$.
#
#
# Par convention `fu` représente $f\circ(Id+u)$ et `dfxu`et `dfyu` représentent les deux coordonnées de $(\nabla f)\circ(Id +u)$. On vous donne dans la cellulle suivante des tests de vérification.

# %%
def Psi(fu,g,ux,uy,lamb,mu) :
    Psi0 = fu - g
    Psi1 = np.sqrt(mu)*(dx(uy)+dy(ux))
    Psi2 = np.sqrt(mu+lamb)*(dx(ux)+dy(uy))
    return Psi0,Psi1,Psi2

def JPsi(vx,vy,dfxu,dfyu,lamb,mu) :
    JPsi0=dfxu*vx+dfyu*vy
    JPsi1=np.sqrt(mu)*dy(vx)+np.sqrt(mu)*dx(vy)
    JPsi2=np.sqrt(lamb+mu)*dx(vx)+np.sqrt(lamb+mu)*dy(vy)
    return JPsi0,JPsi1,JPsi2

def JTPsi(phi,dfxu,dfyu,lamb,mu) :
    ux=phi[0]*dfxu+np.sqrt(mu)*dyT(phi[1])+np.sqrt(lamb+mu)*dxT(phi[2])
    uy=phi[0]*dfyu+np.sqrt(mu)*dxT(phi[1])+np.sqrt(lamb+mu)*dyT(phi[2])
    return ux,uy
  
def JTJ(vx,vy,dfxu,dfyu,lamb,mu,epsilon) :
    uxs, uys = JTPsi(JPsi(vx,vy,dfxu,dfyu,lamb,mu),dfxu,dfyu,lamb,mu)
    uxs = uxs + epsilon*vx
    uys = uys + epsilon*vy
    return uxs,uys

# %%
n=50
np.random.seed(42)
fu=np.random.randn(n,n)
tmp_g=np.random.randn(n,n)
ux=np.random.randn(n,n)
uy=np.random.randn(n,n)
dfxu=np.random.randn(n,n)
dfyu=np.random.randn(n,n)
print('## TESTING PSI')
Psi0,Psi1,Psi2=Psi(fu,tmp_g,ux,uy,5,10)
print(Psi0.shape,Psi1.shape,Psi2.shape) #(50, 50) (50, 50) (50, 50)
print(np.linalg.norm(Psi0),np.linalg.norm(Psi1),np.linalg.norm(Psi2)) # 70.85046394690714 320.74675708932546 389.63146864883447
print('## TESTING JPSI')
Psi0,Psi1,Psi2=JPsi(ux,uy,dfxu,dfyu,5,10)
print(Psi0.shape,Psi1.shape,Psi2.shape) # (50, 50) (50, 50) (50, 50)
print(np.linalg.norm(Psi0),np.linalg.norm(Psi1),np.linalg.norm(Psi2)) #69.27576209907774 320.74675708932546 389.63146864883447
print('## TESTING JTPSI')
Psi0=np.random.randn(n,n)
Psi1=np.random.randn(n,n)
Psi2=np.random.randn(n,n)
vx,vy=JTPsi((Psi0,Psi1,Psi2),dfxu,dfyu,5,10)
print(vx.shape,vy.shape) # (50, 50) (50, 50)
print(np.linalg.norm(vx),np.linalg.norm(vy)) #355.08391793335545 352.46941362403214
print('## TESTING JTJ')
vx,vy=JTJ(ux,uy,dfxu,dfyu,5.,10.,1.)
print(vx.shape,vy.shape) # (50, 50) (50, 50)
print(np.linalg.norm(vx),np.linalg.norm(vy)) #3571.889912528785 3522.237528300008
# Out:
# ## TESTING PSI
# (50, 50) (50, 50) (50, 50)
# 70.85046394690714 320.74675708932546 389.63146864883436
# ## TESTING JPSI
# (50, 50) (50, 50) (50, 50)
# 69.27576209907774 320.74675708932546 389.63146864883436
# ## TESTING JTPSI
# (50, 50) (50, 50)
# 355.08391793335545 352.46941362403214
# ## TESTING JTJ
# (50, 50) (50, 50)
# 3571.889912528785 3522.2375283000083

# %% [markdown]
# Calculons maintenant la direction de recherche $d_k$ comme solution du système linéaire:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = -J_\Psi(u_k)^\top \Psi(u_k)$$
# Pour cela, on vous donne l'algorithme suivant qui par la méthode du gradient conjugué calcule une solution $d=(d_x,d_y)\in V^2$ du problème:
# $$(J_\Psi(u_k)^\top J_\Psi(u_k) +\epsilon I)\left(\begin{array}{c}
# d_x\\
# d_y
# \end{array}\right) = b$$

# %%
 def CGSolve(u0x,u0y,lamb,mu,b,epsilon,dfxu,dfyu) :
    nitmax=100
    ux,uy=u0x,u0y #point de départ de l'algorithme
    # Computes JTJu
    Ax,Ay=JTJ(ux,uy,dfxu,dfyu,lamb,mu,epsilon)
    rx=b[0]-Ax
    ry=b[1]-Ay
    px,py=np.copy(rx),np.copy(ry)
    rsold=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
    for i in range(nitmax) :
        Apx,Apy=JTJ(px,py,dfxu,dfyu,lamb,mu,epsilon);
        alpha=rsold/(np.vdot(rx[:],Apx[:])+np.vdot(ry[:],Apy[:]))
        ux=ux+alpha*px
        uy=uy+alpha*py
        rx=rx-alpha*Apx
        ry=ry-alpha*Apy
        rsnew=np.linalg.norm(rx)**2+np.linalg.norm(ry)**2
        if np.sqrt(rsnew)<1e-10 :
            return [ux,uy]
        px=rx+rsnew/rsold*px
        py=ry+rsnew/rsold*py
        rsold=rsnew
    return ux,uy

# %% [markdown]
# **Q8.** Compléter l'algorithme RecalageGN implémentant la méthode de Levenberg-Marquardt.

# %%
def RecalageGN(f,g,lamb,mu,nitermax,stepini,epsi) : 
    ux=np.zeros(f.shape)
    uy=np.zeros(f.shape)  
    descentx=np.zeros(f.shape)
    descenty=np.zeros(f.shape) 
    dfx = dx(f)
    dfy = dy(f)
    CF=[]
    step_list=[]
    niter=0
    step=stepini
    while niter < nitermax and step > 1.e-8 : 
        niter+=1
        obj,fu=objective_function(f,g,ux,uy,lamb,mu)
        CF.append(obj)
        dfxu = interpol(dfx,ux,uy)
        dfyu = interpol(dfy,ux,uy)
        b=JTPsi(Psi(fu,g,ux,uy,mu,lamb),dfxu,dfyu,lamb,mu)
        [descentx,descenty]=CGSolve(descentx,descenty,lamb,mu,b,epsi,dfxu,dfyu)
        ux,uy,step=linesearch(ux,uy,step,descentx,descenty,obj,f,g,lamb,mu)
        step_list.append(step)
        # Display
        if (niter % 3 ==0) :
            print('iteration :',niter,' cost function :',obj,'step :',step)
    return ux,uy,np.array(CF),np.array(step_list)

# %% [markdown]
# **Q9.** Tester le nouvel algorithme et comparer sa vitesse de convergence avec celle de l'algorithme de gradient.

# %%
lamb = 10
mu = 20
epsi=0.1
nitermax=1000

ux,uy,CF,step=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# On doit trouver comme première ligne
#iteration : 3  cost function : 18.9861786936971 step : 0.08
# Out:
# iteration : 3  cost function : 18.98617869369692 step : 0.08
# iteration : 6  cost function : 17.822725729073753 step : 0.64
# iteration : 9  cost function : 10.583907445957616 step : 5.12
# iteration : 12  cost function : 1.4813612203941995 step : 1.28
# iteration : 15  cost function : 0.8106833121779426 step : 1.28
# iteration : 18  cost function : 0.5186887353808454 step : 2.56
# iteration : 21  cost function : 0.38065345008343077 step : 2.56
# iteration : 24  cost function : 0.31475600884902993 step : 2.56
# iteration : 27  cost function : 0.28186752018946515 step : 2.56
# iteration : 30  cost function : 0.2656699500458225 step : 2.56
# iteration : 33  cost function : 0.25739516987549915 step : 2.56
# iteration : 36  cost function : 0.25333549704569375 step : 2.56
# iteration : 39  cost function : 0.25129636288556745 step : 2.56
# iteration : 42  cost function : 0.2503650166928586 step : 2.56
# iteration : 45  cost function : 0.24994822089511687 step : 2.56
# iteration : 48  cost function : 0.2498082789043714 step : 1.28

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# - algo plus rapide
# - test avec meme valeur/diff
# - displement field diff, step qui oscille entre 2 valeurs donc hesitations
# - objective history

# %% [markdown]
# # 5. Jeu des différences
# Maintenant que vous avez implémenté et testé les deux algorithmes sur l'image-jouet proposée, voyons que cela donne sur une image IRM d'un cerveau. Saurez-vous détecter les différences/déplacements entre les deux images ?

# %%
im1=Image.open('IRM1.png')
im2=Image.open("IRM2.png")
plt.imshow(plt.imread('IRM1.png'))
plt.show()
plt.imshow(plt.imread('IRM2.png'))
plt.show()

# %%
[n,m]=im1.size
sigma=0.1
[X,Y]=np.meshgrid(np.linspace(-1,1,n),np.linspace(-1,1,m), indexing='xy')
Z=np.sqrt(X*X+Y*Y)
G=np.fft.fftshift(np.exp(-(X**2+Y**2)/sigma**2))
f=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im1)))
g=np.real(np.fft.ifft2(np.fft.fft2(G)*np.fft.fft2(im2))) 
f=f/np.max(f)
g=g/np.max(g)

# %% [markdown]
# Pour illustrer, nous commencons par appliquer RecalageDG. Cette méthode est bien trop longue, donc pas optimale. Nous allons utiliser plutôt RecalageGN.

# %%
# %%time
lamb=10
mu=20
nitermax=500
step0 = 0.01
ux,uy,CF,step, niter = RecalageDG(f,g,lamb,mu,nitermax,step0)
# Out:
# iteration : 3  cost function : 0.14381076908556115 step : 0.08 lambda : 10 mu : 20
# iteration : 6  cost function : 0.1438096152752509 step : 0.01 lambda : 10 mu : 20
# iteration : 9  cost function : 0.1438092281331238 step : 0.02 lambda : 10 mu : 20
# iteration : 12  cost function : 0.14380902677406662 step : 0.04 lambda : 10 mu : 20
# iteration : 15  cost function : 0.14380887503431738 step : 0.005 lambda : 10 mu : 20
# iteration : 18  cost function : 0.14380883379757162 step : 0.005 lambda : 10 mu : 20
# iteration : 21  cost function : 0.14380879419074236 step : 0.005 lambda : 10 mu : 20
# iteration : 24  cost function : 0.14380875543386593 step : 0.005 lambda : 10 mu : 20
# iteration : 27  cost function : 0.14380871725169816 step : 0.005 lambda : 10 mu : 20
# iteration : 30  cost function : 0.14380867951277623 step : 0.005 lambda : 10 mu : 20
# iteration : 33  cost function : 0.1438086421448682 step : 0.01 lambda : 10 mu : 20
# iteration : 36  cost function : 0.14380861564441574 step : 0.005 lambda : 10 mu : 20
# iteration : 39  cost function : 0.1438085767481822 step : 0.005 lambda : 10 mu : 20
# iteration : 42  cost function : 0.14380853850622244 step : 0.005 lambda : 10 mu : 20
# iteration : 45  cost function : 0.14380850081364238 step : 0.005 lambda : 10 mu : 20
# iteration : 48  cost function : 0.14380846359506075 step : 0.005 lambda : 10 mu : 20
# iteration : 51  cost function : 0.14380842679444314 step : 0.005 lambda : 10 mu : 20
# iteration : 54  cost function : 0.1438083903689138 step : 0.005 lambda : 10 mu : 20
# iteration : 57  cost function : 0.1438083542848357 step : 0.005 lambda : 10 mu : 20
# iteration : 60  cost function : 0.143808318515246 step : 0.005 lambda : 10 mu : 20
# iteration : 285  cost function : 0.14380607464961728 step : 0.005 lambda : 10 mu : 20
# iteration : 288  cost function : 0.1438060484458268 step : 0.005 lambda : 10 mu : 20
# iteration : 291  cost function : 0.14380602231185718 step : 0.005 lambda : 10 mu : 20
# iteration : 294  cost function : 0.1438059962470529 step : 0.005 lambda : 10 mu : 20
# iteration : 297  cost function : 0.1438059702507703 step : 0.005 lambda : 10 mu : 20
# iteration : 300  cost function : 0.14380594432237723 step : 0.005 lambda : 10 mu : 20
# iteration : 303  cost function : 0.14380591846125157 step : 0.005 lambda : 10 mu : 20
# iteration : 306  cost function : 0.14380589266678218 step : 0.005 lambda : 10 mu : 20
# iteration : 309  cost function : 0.1438058669383671 step : 0.005 lambda : 10 mu : 20
# iteration : 312  cost function : 0.14380584127541673 step : 0.005 lambda : 10 mu : 20
# iteration : 315  cost function : 0.14380581567734718 step : 0.005 lambda : 10 mu : 20
# iteration : 318  cost function : 0.14380579014358866 step : 0.005 lambda : 10 mu : 20
# iteration : 321  cost function : 0.1438057646735769 step : 0.01 lambda : 10 mu : 20
# iteration : 324  cost function : 0.14380574763469472 step : 0.005 lambda : 10 mu : 20
# iteration : 327  cost function : 0.14380572215896822 step : 0.005 lambda : 10 mu : 20
# iteration : 330  cost function : 0.14380569674801144 step : 0.005 lambda : 10 mu : 20
# iteration : 333  cost function : 0.14380567140121925 step : 0.005 lambda : 10 mu : 20
# iteration : 336  cost function : 0.14380564611799743 step : 0.005 lambda : 10 mu : 20
# iteration : 339  cost function : 0.14380562089776172 step : 0.005 lambda : 10 mu : 20
# iteration : 342  cost function : 0.1438055957399403 step : 0.005 lambda : 10 mu : 20
# iteration : 345  cost function : 0.14380557064396987 step : 0.005 lambda : 10 mu : 20
# iteration : 348  cost function : 0.14380554560929648 step : 0.005 lambda : 10 mu : 20
# iteration : 351  cost function : 0.14380552063537833 step : 0.005 lambda : 10 mu : 20
# iteration : 354  cost function : 0.1438054957216808 step : 0.005 lambda : 10 mu : 20
# iteration : 357  cost function : 0.14380547086767953 step : 0.005 lambda : 10 mu : 20
# iteration : 360  cost function : 0.14380544607285767 step : 0.005 lambda : 10 mu : 20
# iteration : 363  cost function : 0.14380542133670832 step : 0.005 lambda : 10 mu : 20
# iteration : 366  cost function : 0.14380539665873254 step : 0.005 lambda : 10 mu : 20
# iteration : 369  cost function : 0.14380537203843965 step : 0.005 lambda : 10 mu : 20
# iteration : 372  cost function : 0.1438053474753463 step : 0.005 lambda : 10 mu : 20
# iteration : 375  cost function : 0.14380532296897713 step : 0.005 lambda : 10 mu : 20
# iteration : 378  cost function : 0.14380529851886564 step : 0.005 lambda : 10 mu : 20
# iteration : 381  cost function : 0.1438052741245499 step : 0.005 lambda : 10 mu : 20
# iteration : 384  cost function : 0.143805249785579 step : 0.005 lambda : 10 mu : 20
# iteration : 387  cost function : 0.14380522550150462 step : 0.005 lambda : 10 mu : 20
# iteration : 390  cost function : 0.1438052012718895 step : 0.005 lambda : 10 mu : 20
# iteration : 393  cost function : 0.14380517709629934 step : 0.005 lambda : 10 mu : 20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 6
#       3 nitermax=500
#       5 step0 = 0.01
# ----> 6 ux,uy,CF,step = RecalageDG(f,g,lamb,mu,nitermax,step0)
#
# ValueError: too many values to unpack (expected 4)

# %%
fig, ax = plt.subplots(2,3, figsize=(10,10))
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 8
#       6 ax[1,0].quiver(ux,uy)
#       7 ax[1,0].set_title('displacement field')
# ----> 8 ax[1,1].imshow(interpol(f,ux,uy))
#       9 ax[1,1].set_title('final function')
#      10 ax[0,2].plot(CF)
#
# Cell In[29], line 6, in interpol(function, ux, uy)
#       4 ip=interpolate.RectBivariateSpline(np.arange(nx),np.arange(ny),function)
#       5 [X,Y]=np.meshgrid(np.arange(nx),np.arange(ny), indexing='ij')
# ----> 6 X=X+ux
#       7 Y=Y+uy
#       8 return np.reshape(ip.ev(X.ravel(),Y.ravel()),(nx,ny))
#
# ValueError: operands could not be broadcast together with shapes (351,400) (21,21)

# %%
# %%time
epsi=0.1
lamb = 10
mu = 20
nitermax=1000
ux,uy,CF,step=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)

# %% [markdown]
# On remarque que pour des "grandes" valeurs de lambda et mu, l'algorithme prends du temps. On s'oriente vers de plus petite valeur.

# %%
# %%time
epsi=0.1
lamb = 0.01
mu = 0.01
nitermax=500
ux,uy,CF,step=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# Out:
# iteration : 3  cost function : 0.14380821133192517 step : 0.08
# iteration : 6  cost function : 0.14378184423583967 step : 0.64
# iteration : 9  cost function : 0.14357553046076788 step : 5.12
# iteration : 12  cost function : 0.1421673653705873 step : 40.96
# iteration : 15  cost function : 0.13861600981728836 step : 5.12
# iteration : 18  cost function : 0.1373795297436199 step : 2.56
# iteration : 21  cost function : 0.13726941986759256 step : 2.56
# iteration : 24  cost function : 0.13709543900108356 step : 2.56
# iteration : 27  cost function : 0.13697904876716838 step : 2.56
# iteration : 30  cost function : 0.1368209483738173 step : 2.56
# iteration : 33  cost function : 0.13670020301943459 step : 2.56
# iteration : 36  cost function : 0.13655488158241666 step : 5.12
# iteration : 39  cost function : 0.13643148784484785 step : 2.56
# iteration : 42  cost function : 0.1362965628993849 step : 5.12
# iteration : 45  cost function : 0.13617179446264432 step : 2.56
# iteration : 48  cost function : 0.1360832468868075 step : 2.56
# iteration : 51  cost function : 0.13592022587329117 step : 2.56
# iteration : 54  cost function : 0.1358236827739541 step : 2.56
# iteration : 57  cost function : 0.13567604527895638 step : 2.56
# iteration : 60  cost function : 0.1355738684747316 step : 2.56
# iteration : 63  cost function : 0.13543863934130768 step : 2.56
# iteration : 66  cost function : 0.1353326344312609 step : 2.56
# iteration : 69  cost function : 0.1352074912678501 step : 5.12
# iteration : 72  cost function : 0.1350990372967218 step : 2.56
# iteration : 75  cost function : 0.13498216065188004 step : 5.12
# iteration : 78  cost function : 0.13487230873157513 step : 2.56
# iteration : 240  cost function : 0.13022406425298302 step : 2.56
# iteration : 243  cost function : 0.13013454215969697 step : 2.56
# iteration : 246  cost function : 0.13008063769924103 step : 2.56
# iteration : 249  cost function : 0.12999856274874952 step : 2.56
# iteration : 252  cost function : 0.12994099620010965 step : 2.56
# iteration : 255  cost function : 0.12986495477242474 step : 2.56
# iteration : 258  cost function : 0.12980468939694131 step : 2.56
# iteration : 261  cost function : 0.12973356195708552 step : 5.12
# iteration : 264  cost function : 0.12967135404878544 step : 2.56
# iteration : 267  cost function : 0.12960425315932586 step : 5.12
# iteration : 270  cost function : 0.12954069585544983 step : 2.56
# iteration : 273  cost function : 0.12949437455040078 step : 2.56
# iteration : 276  cost function : 0.12941247512906884 step : 2.56
# iteration : 279  cost function : 0.12936178166595258 step : 2.56
# iteration : 282  cost function : 0.12928649550585294 step : 2.56
# iteration : 285  cost function : 0.12923251879896547 step : 2.56
# iteration : 288  cost function : 0.12916259503795466 step : 2.56
# iteration : 291  cost function : 0.12910619218340308 step : 2.56
# iteration : 294  cost function : 0.12904063916650108 step : 5.12
# iteration : 297  cost function : 0.1289824842536504 step : 2.56
# iteration : 300  cost function : 0.12892051516305184 step : 5.12
# iteration : 303  cost function : 0.1288611378005871 step : 2.56
# iteration : 306  cost function : 0.1288172448400775 step : 2.56
# iteration : 309  cost function : 0.1287419434723008 step : 2.56
# iteration : 312  cost function : 0.12869412045885378 step : 2.56
# iteration : 315  cost function : 0.12862472990455306 step : 2.56
# iteration : 318  cost function : 0.1285739500406887 step : 2.56
# iteration : 321  cost function : 0.12850935592491033 step : 2.56
# iteration : 324  cost function : 0.12845638631449463 step : 2.56
# iteration : 327  cost function : 0.12839570438853523 step : 5.12
# iteration : 330  cost function : 0.1283411492309064 step : 2.56
# iteration : 333  cost function : 0.12828367731387252 step : 5.12
# iteration : 336  cost function : 0.12822801203214002 step : 2.56
# iteration : 339  cost function : 0.1281863255748408 step : 2.56
# iteration : 342  cost function : 0.1281167902449982 step : 2.56
# iteration : 345  cost function : 0.12807155566180503 step : 2.56
# iteration : 348  cost function : 0.12800733298127867 step : 2.56
# iteration : 351  cost function : 0.12795942471333982 step : 2.56
# iteration : 354  cost function : 0.12789951605243824 step : 2.56
# iteration : 357  cost function : 0.12784962420896595 step : 2.56
# iteration : 360  cost function : 0.1277932365350649 step : 5.12
# iteration : 363  cost function : 0.1277419053605099 step : 2.56
# iteration : 366  cost function : 0.12768840846303103 step : 5.12
# iteration : 369  cost function : 0.12763606676617778 step : 2.56
# iteration : 372  cost function : 0.1275963988860779 step : 2.56
# iteration : 375  cost function : 0.12753194465647016 step : 2.56
# iteration : 378  cost function : 0.12748906095451135 step : 2.56
# iteration : 381  cost function : 0.1274294051538519 step : 2.56
# iteration : 384  cost function : 0.12738409504406512 step : 2.56
# iteration : 387  cost function : 0.12732833817166778 step : 2.56
# iteration : 390  cost function : 0.12728122532595418 step : 2.56
# iteration : 393  cost function : 0.12722865256894986 step : 5.12
# iteration : 396  cost function : 0.12718022937813545 step : 2.56
# iteration : 399  cost function : 0.12713027231509938 step : 5.12
# iteration : 402  cost function : 0.1270809271800204 step : 2.56
# iteration : 405  cost function : 0.12704311626507825 step : 2.56
# iteration : 408  cost function : 0.1269831723987618 step : 2.56
# iteration : 411  cost function : 0.12694243669074445 step : 2.56
# iteration : 414  cost function : 0.12688684547912754 step : 2.56
# iteration : 417  cost function : 0.12684390060391237 step : 2.56
# iteration : 420  cost function : 0.12679184818530828 step : 5.12
# iteration : 423  cost function : 0.1267472600497393 step : 2.56
# iteration : 426  cost function : 0.1266980992651329 step : 5.12
# iteration : 429  cost function : 0.12665231508507208 step : 2.56
# iteration : 432  cost function : 0.1266197111719276 step : 2.56
# iteration : 435  cost function : 0.12655890390804014 step : 2.56
# iteration : 438  cost function : 0.12652280927739565 step : 2.56
# iteration : 441  cost function : 0.12646689504071842 step : 2.56
# iteration : 444  cost function : 0.12642813201291636 step : 2.56
# iteration : 447  cost function : 0.12637618111179869 step : 2.56
# iteration : 450  cost function : 0.12633540082519357 step : 2.56
# iteration : 453  cost function : 0.12628667395802579 step : 5.12
# iteration : 456  cost function : 0.12624439174934704 step : 2.56
# iteration : 459  cost function : 0.1261983007181638 step : 5.12
# iteration : 462  cost function : 0.12615492418625168 step : 2.56
# iteration : 465  cost function : 0.12612361359459928 step : 2.56
# iteration : 468  cost function : 0.12606685200729065 step : 2.56
# iteration : 471  cost function : 0.12603234996459556 step : 2.56
# iteration : 474  cost function : 0.1259800565014661 step : 2.56
# iteration : 477  cost function : 0.12594311316709955 step : 2.56
# iteration : 480  cost function : 0.12589444077389197 step : 2.56
# iteration : 483  cost function : 0.12585565056390835 step : 2.56
# iteration : 486  cost function : 0.1258099252987227 step : 5.12
# iteration : 489  cost function : 0.12576975900607304 step : 2.56
# iteration : 492  cost function : 0.12572644440655192 step : 5.12
# iteration : 495  cost function : 0.1256852746795749 step : 2.56
# iteration : 498  cost function : 0.12565518111282892 step : 2.56
# CPU times: user 2min 3s, sys: 36.1 ms, total: 2min 3s
# Wall time: 2min 3s

# %%
# %%time
epsi=0.01
stepini=0.01
nitermax = 500
lamb = 0.0001
mu = 0.0001
ux,uy,CF,step=RecalageGN(f,g,lamb,mu,nitermax,step0,epsi)
# Out:
# iteration : 3  cost function : 0.1437826656882704 step : 0.08
# iteration : 6  cost function : 0.14351829663080015 step : 0.64
# iteration : 9  cost function : 0.14143531219764957 step : 5.12
# iteration : 12  cost function : 0.12664688791055626 step : 40.96
# iteration : 15  cost function : 0.07367524667918746 step : 327.68
# iteration : 18  cost function : 0.05449066085804063 step : 20.48
# iteration : 21  cost function : 0.05339961432983105 step : 20.48
# iteration : 24  cost function : 0.05303041099371342 step : 10.24
# iteration : 27  cost function : 0.0527560486354776 step : 10.24
# iteration : 30  cost function : 0.0525136342933111 step : 20.48
# iteration : 33  cost function : 0.05234375202394957 step : 10.24
# iteration : 36  cost function : 0.05220245551360542 step : 5.12
# iteration : 39  cost function : 0.05181652815847815 step : 10.24
# iteration : 42  cost function : 0.051596296494923824 step : 20.48
# iteration : 45  cost function : 0.05137316117248035 step : 10.24
# iteration : 48  cost function : 0.05121856272263752 step : 5.12
# iteration : 51  cost function : 0.05097849330835469 step : 10.24
# iteration : 54  cost function : 0.050786343220400335 step : 20.48
# iteration : 57  cost function : 0.05059221865840993 step : 10.24
# iteration : 60  cost function : 0.05040523558342849 step : 10.24
# iteration : 63  cost function : 0.05028723957017539 step : 5.12
# iteration : 66  cost function : 0.05008781358356654 step : 5.12
# iteration : 69  cost function : 0.04990299608029425 step : 10.24
# iteration : 72  cost function : 0.04974584333617403 step : 20.48
# iteration : 75  cost function : 0.049586203282009925 step : 20.48
# iteration : 78  cost function : 0.04943176189152239 step : 10.24
# iteration : 81  cost function : 0.049282185521077645 step : 10.24
# iteration : 84  cost function : 0.049137191603568664 step : 10.24
# iteration : 87  cost function : 0.048996533685310636 step : 10.24
# iteration : 90  cost function : 0.04892020170999914 step : 5.12
# iteration : 93  cost function : 0.04877980779877094 step : 5.12
# iteration : 96  cost function : 0.048645085260311964 step : 5.12
# iteration : 99  cost function : 0.04851527112140099 step : 5.12
# iteration : 102  cost function : 0.04838980571140633 step : 5.12
# iteration : 105  cost function : 0.048268268704464094 step : 5.12
# iteration : 108  cost function : 0.04815033601320326 step : 5.12
# iteration : 111  cost function : 0.04803575069444112 step : 5.12
# iteration : 114  cost function : 0.04792430423157108 step : 5.12
# iteration : 117  cost function : 0.04781582177209394 step : 5.12
# iteration : 120  cost function : 0.047710153334072 step : 5.12
# iteration : 123  cost function : 0.0476071674095999 step : 5.12
# iteration : 126  cost function : 0.047506746523272164 step : 5.12
# iteration : 129  cost function : 0.04740878411865111 step : 5.12
# iteration : 132  cost function : 0.047313182354108994 step : 5.12
# iteration : 135  cost function : 0.04721985053352164 step : 5.12
# iteration : 138  cost function : 0.04712870364606452 step : 5.12
# iteration : 141  cost function : 0.04703966234321587 step : 5.12
# iteration : 144  cost function : 0.046952651691179695 step : 5.12
# iteration : 147  cost function : 0.04686760067298033 step : 5.12
# iteration : 150  cost function : 0.04678444190408165 step : 5.12
# iteration : 153  cost function : 0.04670311131927188 step : 5.12
# iteration : 156  cost function : 0.04662354791184965 step : 5.12
# iteration : 159  cost function : 0.04654569351433602 step : 10.24
# iteration : 162  cost function : 0.04647110545711807 step : 20.48
# iteration : 165  cost function : 0.04639687112949992 step : 20.48
# iteration : 168  cost function : 0.04632416716240101 step : 20.48
# iteration : 171  cost function : 0.04625294586545592 step : 20.48
# iteration : 174  cost function : 0.046183161574274156 step : 20.48
# iteration : 177  cost function : 0.04611477053758696 step : 20.48
# iteration : 180  cost function : 0.04604773083535993 step : 20.48
# iteration : 183  cost function : 0.045982002172100855 step : 20.48
# iteration : 186  cost function : 0.04591754600040443 step : 20.48
# iteration : 189  cost function : 0.04585432538405493 step : 20.48
# iteration : 192  cost function : 0.04579230479681802 step : 20.48
# iteration : 195  cost function : 0.045731450105767533 step : 20.48
# iteration : 198  cost function : 0.04567172849210503 step : 20.48
# iteration : 201  cost function : 0.045613108431837315 step : 20.48
# iteration : 204  cost function : 0.0455555595931422 step : 20.48
# iteration : 207  cost function : 0.04549905278881249 step : 20.48
# iteration : 210  cost function : 0.04544355991088085 step : 20.48
# iteration : 213  cost function : 0.04538905391951605 step : 20.48
# iteration : 216  cost function : 0.04533550875305456 step : 20.48
# iteration : 219  cost function : 0.04528289929505924 step : 20.48
# iteration : 222  cost function : 0.04523120133093762 step : 20.48
# iteration : 225  cost function : 0.04518039150511301 step : 20.48
# iteration : 228  cost function : 0.04513044727522814 step : 20.48
# iteration : 231  cost function : 0.045081346906419274 step : 20.48
# iteration : 234  cost function : 0.045033069402662454 step : 20.48
# iteration : 237  cost function : 0.044985594484969096 step : 20.48
# iteration : 240  cost function : 0.044938902560292024 step : 20.48
# iteration : 243  cost function : 0.044892974691855526 step : 20.48
# iteration : 246  cost function : 0.0448477925702987 step : 10.24
# iteration : 249  cost function : 0.044803338490269205 step : 10.24
# iteration : 252  cost function : 0.04475959531958619 step : 10.24
# iteration : 255  cost function : 0.04471654647949237 step : 10.24
# iteration : 258  cost function : 0.04467417592022484 step : 10.24
# iteration : 261  cost function : 0.04463246809949922 step : 10.24
# iteration : 264  cost function : 0.04459140796254983 step : 10.24
# iteration : 267  cost function : 0.044550980921952255 step : 10.24
# iteration : 270  cost function : 0.044511172838850664 step : 10.24
# iteration : 273  cost function : 0.04447197000523325 step : 10.24
# iteration : 276  cost function : 0.04443335912725185 step : 10.24
# iteration : 279  cost function : 0.044395327309026636 step : 10.24
# iteration : 282  cost function : 0.044357862037450915 step : 10.24
# iteration : 285  cost function : 0.04432095116726299 step : 10.24
# iteration : 288  cost function : 0.04428458290717429 step : 10.24
# iteration : 291  cost function : 0.04424874580678614 step : 10.24
# iteration : 294  cost function : 0.04421342874378753 step : 10.24
# iteration : 297  cost function : 0.044178620780816816 step : 10.24
# iteration : 300  cost function : 0.04414431150610265 step : 10.24
# iteration : 303  cost function : 0.04411049074500495 step : 10.24
# iteration : 306  cost function : 0.04407714857205749 step : 10.24
# iteration : 309  cost function : 0.044044275334457234 step : 10.24
# iteration : 312  cost function : 0.044011861642420186 step : 10.24
# iteration : 315  cost function : 0.04397989836015103 step : 10.24
# iteration : 318  cost function : 0.04396220847823207 step : 5.12
# iteration : 321  cost function : 0.043930432982185824 step : 5.12
# iteration : 324  cost function : 0.043899111293989226 step : 5.12
# iteration : 327  cost function : 0.04386823398917449 step : 5.12
# iteration : 330  cost function : 0.043837791908309845 step : 5.12
# iteration : 333  cost function : 0.04380777614577002 step : 5.12
# iteration : 336  cost function : 0.04377817804137149 step : 5.12
# iteration : 339  cost function : 0.04374898917098945 step : 5.12
# iteration : 342  cost function : 0.04372020133967699 step : 5.12
# iteration : 345  cost function : 0.04369180657346764 step : 5.12
# iteration : 348  cost function : 0.04366379711193366 step : 5.12
# iteration : 351  cost function : 0.04363616540102287 step : 5.12
# iteration : 354  cost function : 0.04360890408627187 step : 5.12
# iteration : 357  cost function : 0.04358200600653249 step : 5.12
# iteration : 360  cost function : 0.04355546418611814 step : 5.12
# iteration : 363  cost function : 0.043529271830387656 step : 5.12
# iteration : 366  cost function : 0.043503422319293036 step : 5.12
# iteration : 369  cost function : 0.04347790918261685 step : 5.12
# iteration : 372  cost function : 0.04345272614843278 step : 5.12
# iteration : 375  cost function : 0.04342786708996399 step : 5.12
# iteration : 378  cost function : 0.043403326031501446 step : 5.12
# iteration : 381  cost function : 0.04337909714607979 step : 5.12
# iteration : 384  cost function : 0.04335517474948329 step : 5.12
# iteration : 387  cost function : 0.04333155313213921 step : 10.24
# iteration : 390  cost function : 0.04330885878651998 step : 20.48
# iteration : 393  cost function : 0.043285985905202544 step : 20.48
# iteration : 396  cost function : 0.043263389551463 step : 20.48
# iteration : 399  cost function : 0.04324106507249891 step : 20.48
# iteration : 402  cost function : 0.043219007919109445 step : 20.48
# iteration : 405  cost function : 0.04319721364279701 step : 20.48
# iteration : 408  cost function : 0.043175677893846576 step : 20.48
# iteration : 411  cost function : 0.04315439641564389 step : 20.48
# iteration : 414  cost function : 0.04313336504484102 step : 20.48
# iteration : 417  cost function : 0.043112579708781615 step : 20.48
# iteration : 420  cost function : 0.043092036421854704 step : 20.48
# iteration : 423  cost function : 0.04307173128355227 step : 20.48
# iteration : 426  cost function : 0.04305166046658708 step : 20.48
# iteration : 429  cost function : 0.043031820225397296 step : 20.48
# iteration : 432  cost function : 0.043012206918425805 step : 20.48
# iteration : 435  cost function : 0.042992816963363295 step : 20.48
# iteration : 438  cost function : 0.04297364685318775 step : 20.48
# iteration : 441  cost function : 0.04295469315147774 step : 20.48
# iteration : 444  cost function : 0.04293595249291459 step : 20.48
# iteration : 447  cost function : 0.042917421581022894 step : 20.48
# iteration : 450  cost function : 0.042899097186229036 step : 20.48
# iteration : 453  cost function : 0.04288097614371544 step : 10.24
# iteration : 456  cost function : 0.04286305535329427 step : 10.24
# iteration : 459  cost function : 0.04284533177578774 step : 10.24
# iteration : 462  cost function : 0.04282780243260412 step : 10.24
# iteration : 465  cost function : 0.042810464403999694 step : 10.24
# iteration : 468  cost function : 0.04279331482761639 step : 10.24
# iteration : 471  cost function : 0.04277635089716632 step : 10.24
# iteration : 474  cost function : 0.04275956973535562 step : 10.24
# iteration : 477  cost function : 0.042742968510238136 step : 10.24
# iteration : 480  cost function : 0.04272654483275873 step : 10.24
# iteration : 483  cost function : 0.04271029609056032 step : 10.24
# iteration : 486  cost function : 0.042694219741567584 step : 10.24
# iteration : 489  cost function : 0.04267831329968222 step : 10.24
# iteration : 492  cost function : 0.04266257431410087 step : 10.24
# iteration : 495  cost function : 0.04264700038000906 step : 10.24
# iteration : 498  cost function : 0.04263158913751375 step : 10.24
# CPU times: user 1min 53s, sys: 28.1 ms, total: 1min 53s
# Wall time: 1min 53s

# %%
fig, ax = plt.subplots(2,3)
ax[0,0].imshow(f)
ax[0,0].set_title('original function')
ax[0,1].imshow(g)
ax[0,1].set_title('target function')
ax[1,0].quiver(ux,uy)
ax[1,0].set_title('displacement field')
ax[1,1].imshow(interpol(f,ux,uy))
ax[1,1].set_title('final function')
ax[0,2].plot(CF)
ax[0,2].set_title('objective history')
ax[1,2].plot(np.log(step))
ax[1,2].set_title('step history (log scale)')

plt.tight_layout()
plt.show()
