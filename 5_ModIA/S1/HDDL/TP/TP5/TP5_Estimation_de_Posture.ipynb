# %% [markdown]
# <font size="+3">Estimation de posture dans une image</font>
#
# ---
#
# Pour ce TP, nous allons traiter le problème de la détection du "squelette" d'un humain dans une image, tel qu'illustré dans la figure ci-dessous.
#
# ![Texte alternatif…](https://drive.google.com/uc?id=1HpyLwzwkFdyQ6APoGZQJL7f837JCHNkh)
#
# Nous allons pour ce faire utiliser le [Leeds Sport Pose Dataset](https://sam.johnson.io/research/lspet.html) qui introduit 10000 images présentant des sportifs dans diverses situations, augmentées d'une annotation manuelle du squelette.
#
# À chaque image est associée une matrice de taille 3x14, correspondant aux coordonnées dans l'image des 14 joints du squelette de la personne décrite dans l'image. La 3e dimension désigne la visibilité du joint (1 s'il est visible, 0 s'il est occulté)
#
# Ces joints sont, dans l'ordre :
# *   Cheville droite
# *   Genou droit
# *   Hanche droite
# *   Hanche gauche
# *   Genou gauche
# *   Cheville gauche
# *   Poignet droit
# *   Coude droit
# *   Épaule droite
# *   Épaule gauche
# *   Coude gauche
# *   Poignet gauche
# *   Cou
# *   Sommet du crâne

# %% [markdown]
# # Méthodologie
#
# Pour résoudre ce problème, nous allons suivre une méthodologie similaire à celle présentée dans le cours d'introduction, et rappelée sur la figure suivante :
#
# ![Méthodologie de développement d'un algorithme d'apprentissage profond](https://drive.google.com/uc?id=195pkcjca4r_g86KDt2LCe0QdQsMC6iba)
#
# Ainsi nous allons commencer par une modélisation simple du problème, construire un modèle et l'améliorer pas à pas et évaluer sa performance.
# Dans un second temps, nous modifierons la modélisation du problème, et donc l'architecture utilisée, afin d'améliorer les résultats.
#
# Pour chacune de ces deux étapes, je vous suggère de suivre la démarche suivante :
#
# - Simplifier le problème en traitant 10 imagettes (par exemple de dimension $64 \times 64$) et construire un réseau qui surapprend parfaitement (qui diminue la perte jusqu'à quasiment 0)
# - Ajouter des images (~1000) et recalibrer le réseau pour à nouveau, obtenir un sur-apprentissage
# - Commencer à corriger le sur-apprentissage en ajoutant de la régularisation
# - Et enfin, utiliser l'ensemble de la base de données pour diminuer le sur-apprentissage au maximum
#
# ---
#
# Commencez par télécharger la base de données sur Github

# %%
# !git clone https://plmlab.math.cnrs.fr/chevallier-teaching/datasets/leeds-sport-pose.git
# Out:
# Cloning into 'leeds-sport-pose'...
# remote: Enumerating objects: 10019, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 10019 (delta 2), reused 2 (delta 2), pack-reused 10015 (from 1)
# Receiving objects: 100% (10019/10019), 162.39 MiB | 4.61 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %% [markdown]
# # **Approche n°1** : Régression de la position des joints
#
# Dans un premier temps, et comme vu en cours, nous allons nous inspirer de l'algorithme DeepPose (**[[Toshev et al.]](https://arxiv.org/abs/1312.4659)** _DeepPose : Human Pose Estimation via Deep Neural Networks_) et formuler le problème comme une régression de la position $(x,y)$ des joints dans l'espace de l'image.

# %% [markdown]
# ## Fonctions utiles
#
# Le bloc suivant contient une fonction qui permet de charger les images de la base de données dans les variables $x$ et $y$. Par défaut les images sont redimensionnées en taille 128$\times$128 et la base de données contient 1000 images. Pour commencer et vous permettre de travailler plus efficacement, **je vous suggère très fortement de diminuer la dimension des images** (par exemple 64$\times$64) **et de ne travailler que sur un ensemble réduit d'images** (par exemple, 10).
#
#
# N'oubliez pas également de diviser les données en images de test et/ou de validation pour obtenir des informations sur le sur-apprentissage éventuel.

# %%
import numpy as np
import PIL
from PIL import Image
import os, sys
from scipy.io import loadmat

# %%
# Cette fonction permettra plus tard de charger plus ou moins d'images (en modifiant le paramètre num_images)
# et de modifier la dimension d'entrée

def load_data(image_size=128, num_images=1000):

    path = "./leeds-sport-pose/images/"
    dirs = sorted(os.listdir(path))

    x = np.zeros((min(num_images,len(dirs)), image_size,image_size,3))
    y = np.zeros((min(num_images,len(dirs)), 3, 14))

    #Chargement des joints    
    mat_contents = loadmat('./leeds-sport-pose/joints.mat')
    joints = mat_contents['joints']

    # Chargement des images, qui sont rangées dans leeds-sport-pose/images
    for i in range(min(num_images,len(dirs))):
        item = dirs[i]
        if os.path.isfile(path+item):
            img = Image.open(path+item)
            # Redimensionnement et sauvegarde des joints
            y[i, 0] = joints[:,0,i]*image_size/img.size[0]
            y[i, 1] = joints[:,1,i]*image_size/img.size[1]
            y[i, 2] = joints[:,2,i]
            # Redimensionnement et sauvegarde des images        
            img = img.resize((image_size,image_size))
            x[i] = np.asarray(img)

    return x, y

# Chargement de seulement 10 images, de taille 64x64
x, y = load_data(image_size=64, num_images=10)           
x.shape, y.shape
# Out:
# ((10, 64, 64, 3), (10, 3, 14))

# %%
labels= {0: 'Cheville droite',
         1: 'Genou droit',
         2: 'Hanche droite',
         3: 'Hanche gauche',
         4: 'Genou gauche',
         5: 'Cheville gauche',
         6: 'Poignet droit',
         7: 'Coude droit',
         8: 'Épaule droite',
         9: 'Épaule gauche',
         10: 'Coude gauche',
         11: 'Poignet gauche',
         12: 'Cou',
         13: 'Sommet du crâne'}

# %% [markdown]
# La fonction suivante vous permet de visualiser les données. Vous vous rendrez compte que certaines données sont manquantes ! En effet quand des joints sont occultés dans les images, des valeurs de position aberrantes (négatives) sont indiquées. Dans ce cas, nous n'afficherons pas les articulations.

# %%
import matplotlib.pyplot as plt

# %%
# Fonction d'affichage d'une image et de son label associé

def print_data(x,y,i):

    if y.shape[1] < 3:
        y_new = np.ones((y.shape[0], 3, y.shape[2]))
        y_new[:,0:2,:] = y
        y = y_new

    plt.figure(figsize=(5, 5))
    plt.imshow(x[i]/255)
    for j in range(0,14):
        if y[i, 2, j] == 1:
            plt.scatter(y[i,0,j],y[i,1,j],label=labels.get(j))

    # Jambe droite      
    if (y[i, 2, 0] + y[i, 2, 1] == 2):
        plt.plot(y[i,0,0:2],y[i,1,0:2],'b')
    # Cuisse droite      
    if (y[i, 2, 1] + y[i, 2, 2] == 2):
        plt.plot(y[i,0,1:3],y[i,1,1:3],'b')
    # Bassin     
    if (y[i, 2, 2] + y[i, 2, 3] == 2):
        plt.plot(y[i,0,2:4],y[i,1,2:4],'b')
    # Cuisse gauche      
    if (y[i, 2, 3] + y[i, 2, 4] == 2):
        plt.plot(y[i,0,3:5],y[i,1,3:5],'b')
    # Jambe gauche      
    if (y[i, 2, 4] + y[i, 2, 5] == 2):
        plt.plot(y[i,0,4:6],y[i,1,4:6],'b')
    # Avant-bras droit      
    if (y[i, 2, 6] + y[i, 2, 7] == 2):
        plt.plot(y[i,0,6:8],y[i,1,6:8],'b')
    # Bras droit      
    if (y[i, 2, 7] + y[i, 2, 8] == 2):
        plt.plot(y[i,0,7:9],y[i,1,7:9],'b')
    # Bras gauche     
    if (y[i, 2, 9] + y[i, 2, 10] == 2):
        plt.plot(y[i,0,9:11],y[i,1,9:11],'b')
    # Avant-bras gauche      
    if (y[i, 2, 10] + y[i, 2, 11] == 2):
        plt.plot(y[i,0,10:12],y[i,1,10:12],'b') 
    # Buste droit
    x1=[y[i,0,2],y[i,0,12]]
    y1=[y[i,1,2],y[i,1,12]]
    if (y[i, 2, 2] + y[i, 2, 12] == 2):
        plt.plot(x1, y1,'b')
    # Buste gauche
    x1=[y[i,0,3],y[i,0,12]]
    y1=[y[i,1,3],y[i,1,12]]
    if (y[i, 2, 3] + y[i, 2, 12] == 2):
        plt.plot(x1, y1,'b')
    # Omoplate droite
    x1=[y[i,0,8],y[i,0,12]]
    y1=[y[i,1,8],y[i,1,12]]
    if (y[i, 2, 8] + y[i, 2, 12] == 2):
        plt.plot(x1, y1,'b')
    # Omoplate gauche
    x1=[y[i,0,9],y[i,0,12]]
    y1=[y[i,1,9],y[i,1,12]]
    if (y[i, 2, 9] + y[i, 2, 12] == 2):
        plt.plot(x1, y1,'b')
    # Tete     
    if (y[i, 2, 12] + y[i, 2, 13] == 2):
        plt.plot(y[i,0,12:14],y[i,1,12:14],'b')

    plt.axis([0, x.shape[1], x.shape[2], 0])
    plt.show()
    #plt.legend()

# Affichage aléatoire d'une image
print_data(x,y,np.random.randint(x.shape[0]-1))

# %% [markdown]
# Si nous formulons ce problème comme une régression, nous allons utiliser pour évaluer nos réseaux de neurones l'erreur quadratique moyenne (fonction *MSE*). Cette fonction sera parfaite comme fonction de perte, mais elle ne permet pas d'appréhender les résultats de manière satisfaisante.
#
# Une métrique commune en estimation de posture est le **PCK0.5**, pour *Percentage of Correct Keypoints*. *0.5* correspond à un seuil en-deça duquel on considère qu'un joint est correctement estimé. Cette question du seuil est particulièrement sensible car il faut utiliser une valeur qui soit valable pour n'importe quelle image. La personne considérée peut apparaître plus ou moins largement sur l'image, de face ou de profil, ce qui fait qu'une erreur de prédiction sur un joint peut avoir une importance très grande ou très faible selon les cas.
#
# Pour résoudre cette ambiguïté, on considère dans la métrique du **PCK0.5** que la référence est la taille de la tête, définie par la distance entre le joint du cou et le joint de la tête sur la vérité terrain. Un joint prédit par le réseau sera considéré correct s'il est situé à une distance inférieure à la moitié (*0.5*) de la taille de la tête par rapport au joint réel. (**[[Andriluka et al.]](https://openaccess.thecvf.com/content_cvpr_2014/html/Andriluka_2D_Human_Pose_2014_CVPR_paper.html)** _2D Human Pose Estimation: New Benchmark and State of the Art Analysis_)

# %%
import numpy.matlib

# %%
# Calcul du "Percentage of Correct Keypoint" avec seuil alpha :
# On compte corrects les joints pour lesquels la distance entre valeurs réelle et prédite 
# est inférieure à alpha fois la dimension de la tête (c'est un peu arbitraire...)
# On ne comptera pas les joints invisibles.
# y_true est de dimension Nx3x14 et y_pred Nx2x14 (le réseau ne prédit pas la visibilité)

def compute_PCK_alpha(y_true, y_pred, alpha=0.5):
    # Calcul des seuils ; la taille de la tête est la distance entre joints 12 et 13
    head_sizes = np.sqrt( np.square(y_true[:,0,13]-y_true[:,0,12]) + np.square(y_true[:,1,13]-y_true[:,1,12]) )
    thresholds = alpha * head_sizes
    thresholds = np.matlib.repmat(np.expand_dims(thresholds, 1), 1, 14)

    # Calcul des distances inter-joints
    joints_distances = np.sqrt( np.square(y_true[:,0,:]-y_pred[:,0,:]) + np.square(y_true[:,1,:]-y_pred[:,1,:]) )

    # Visibilité des joints de la vérité terrain
    visibility = y_true[:,2,:]
    
    total_joints = np.count_nonzero(visibility==1)
    correctly_predicted_joints = np.count_nonzero( np.logical_and(joints_distances<thresholds, visibility == 1) )
    
    return correctly_predicted_joints/total_joints

# %% [markdown]
# Comme dit précédemment, on va utiliser l'erreur quadratique moyenne (*[MSE](https://en.wikipedia.org/wiki/Mean_squared_error)*) comme fonction de coût pour entraîner notre réseau de neurones, et on peut également utiliser l'erreur absolue moyenne (*[MAE](https://en.wikipedia.org/wiki/Mean_absolute_error)*) pour obtenir une estimation plus fine des performances de notre réseau pendant l'entraînement (on obtient une erreur moyenne en pixels, ce qui est plus simple à interpréter).
#
# Il y a cependant une subtilité importante évoquée un peu plus haut : certains joints sont invisibles, et ont des coordonnées négatives (pour, il faut l'avouer, une raison un peu inexplicable). Il est important de ne pas affecter l'apprentissage en faisant prédire ces valeurs négatives, insensées, au réseau.
#
# On doit donc implanter nous-même notre propre fonction de coût, qui ne va pas prendre en compte les joints invisibles. Pour cela, il faut savoir que la vérité-terrain contient en fait 3 valeurs pour chaque joint : les 2 premières sont ses coordonnées sur l'image, la 3e représente la visibilité du joint (1 s'il est visible, 0 sinon).
#
# La fonction *custom_mse*, définie juste en-dessous, réalise cette opération. Prenez le temps de comprendre ce qu'il s'y passe.
#
# **Remarque importante** : Ce code fait appel à des fonctions particulières du Backend de `Keras`, dont vous trouverez les détails sur [cette page](https://keras.rstudio.com/articles/backend.html). Ces fonctions doivent traiter des tenseurs, de type _tensor_ (et pas des tableaux _numpy_), car elles seront appelées pendant l'entraînement sur des variables internes à `Tensorflow`. Les fonctions utilisables sont également limitées car il faut pouvoir dériver la fonction *custom_mse* pour la rétropropagation des gradients.

# %%
import tensorflow.keras.backend as K
import keras

# %%
# y_true : vérité terrain de dimension B x 3 x 14
# y_pred : une prédiction de dimension B x 2 x 14 (on ne prédit pas la visibilité)
# B est le nombre d'images considérées (par exemple, pourra être la taille d'un mini-batch)

def custom_mse(y_true, y_pred):
    # Changement de dimension : Bx3x14 -> Bx14x3
    y_true = K.permute_dimensions(y_true, (0, 2, 1))
    # Changement de dimension : Bx14x3 -> (B*14)x3
    y_true = K.reshape(y_true, shape=(-1, 3))
  
    # Changement de dimension : Bx2x14 -> Bx14x2
    y_pred = K.permute_dimensions(y_pred, (0, 2, 1))
    # Changement de dimension : Bx14x2 -> (B*14)x2
    y_pred = K.reshape(y_pred, shape=(-1, 2))
    
    # Détermination de l'indices des joints visibles
    visible = K.greater_equal(y_true[:, 2], 1)  
    indices = K.arange(0, K.shape(y_true)[0])
    indices_visible = indices[visible]
    
    # Sélection des vérité-terrains et prédictions des joints visibles
    y_true_visible = K.gather(y_true[:,0:2], indices_visible)
    y_pred_visible = K.gather(y_pred, indices_visible)
    
    # Calcul de la MSE
    return K.mean( K.square(y_pred_visible[:,0]-y_true_visible[:,0]) + K.square(y_pred_visible[:,1]-y_true_visible[:,1]) )

# %% [markdown]
# Si vous avez bien compris le code de *custom_mse*, vous devriez pouvoir sans trop de problèmes écrire le code pour la fonction *custom_mae* ci-dessous :

# %%
# y_true : vérité terrain de dimension B x 3 x 14
# y_pred : une prédiction de dimension B x 2 x 14 (on ne prédit pas la visibilité)
# B est le nombre d'images considérées (par exemple, pourra être la taille d'un mini-batch)

def custom_mae(y_true, y_pred):
    # Changement de dimension : Bx3x14 -> Bx14x3
    y_true = K.permute_dimensions(y_true, (0, 2, 1))
    # Changement de dimension : Bx14x3 -> (B*14)x3
    y_true = K.reshape(y_true, shape=(-1, 3))
  
    # Changement de dimension : Bx2x14 -> Bx14x2
    y_pred = K.permute_dimensions(y_pred, (0, 2, 1))
    # Changement de dimension : Bx14x2 -> (B*14)x2
    y_pred = K.reshape(y_pred, shape=(-1, 2))
    
    # Détermination de l'indices des joints visibles
    visible = K.greater_equal(y_true[:, 2], 1)  
    indices = K.arange(0, K.shape(y_true)[0])
    indices_visible = indices[visible]
    
    # Sélection des vérité-terrains et prédictions des joints visibles
    y_true_visible = K.gather(y_true[:,0:2], indices_visible)
    y_pred_visible = K.gather(y_pred, indices_visible)
    
    # Calcul de la MSE
    return K.mean( K.abs(y_pred_visible[:,0]-y_true_visible[:,0]) + K.abs(y_pred_visible[:,1]-y_true_visible[:,1]) )

# %%
# %load solutions/custom_mae.py

# %% [markdown]
# Comme d'habitude, on peut monitorer l'entraînement grâce à la fonction suivante (adaptée à nos fonctions *custom_mse* et *custom_mae* définies juste avant) :

# %%
def plot_training_analysis(history):
    mae = history.history['custom_mae']
    val_mae = history.history['val_custom_mae']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.subplot(1,2,1)
    plt.plot(epochs, mae, 'b', linestyle="--",label='Training MAE')
    plt.plot(epochs, val_mae, 'g', label='Validation MAE')
    plt.title('Training and validation MAE')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
    plt.plot(epochs, val_loss,'g', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## À vous de jouer

# %% [markdown]
# Pour tenter de résoudre le problème, vous pouvez suivre les étapes suivantes :
#
# - Simplifier le problème en traitant 10 imagettes (par exemple de dimension $64 \times 64$) et construire un réseau qui surapprend parfaitement (qui diminue la perte jusqu'à quasiment 0 $\leadsto$ `simple_CNN.py`)
# - Ajouter des images (~1000) et éventuellement recalibrer votre réseau pour à nouveau, obtenir un sur-apprentissage
# - Commencer à corriger le sur-apprentissage en ajoutant de la régularisation (notamment sur les couches denses)
# - Et enfin, utiliser l'ensemble de la base de données pour diminuer le sur-apprentissage au maximum

# %%
def simple_CNN(image_size=64):
    # Définition du modèle simple, de type "LeNet" (§ 4.1.1)
    
    model = keras.Sequential()
    
    model.add(keras.layers.Conv2D(32,(3,3), padding='same', input_shape=(image_size,image_size,3), activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Conv2D(64,(3,3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Conv2D(96,(3,3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Conv2D(128,(3,3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(512, activation='relu'))
    model.add(keras.layers.Dense(28, activation='linear'))
    model.add(keras.layers.Reshape((2,14)))

    return model

# %%
model = simple_CNN()
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 16, 16, 96)     │        55,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 8, 8, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 8, 8, 128)      │       110,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 28)             │        14,364 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_4 (Reshape)             │ (None, 2, 14)          │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,248,956 (4.76 MB)
#  Trainable params: 1,248,956 (4.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers

# %%
model.compile(
    loss = custom_mse,
    optimizer = optimizers.Adam(learning_rate=3e-4),
    metrics = [custom_mae])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - custom_mae: 62.7362 - loss: 2433.6672 - val_custom_mae: 26.7217 - val_loss: 499.6564
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - custom_mae: 39.6083 - loss: 1038.5863 - val_custom_mae: 15.8280 - val_loss: 182.3532
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - custom_mae: 22.3706 - loss: 404.9793 - val_custom_mae: 24.7240 - val_loss: 449.5412
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 24.0380 - loss: 414.5000 - val_custom_mae: 30.0851 - val_loss: 591.9957
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - custom_mae: 25.4941 - loss: 462.7214 - val_custom_mae: 24.2469 - val_loss: 410.6801
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - custom_mae: 20.0353 - loss: 308.6322 - val_custom_mae: 17.1252 - val_loss: 231.4195
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 16.9066 - loss: 215.2850 - val_custom_mae: 14.6630 - val_loss: 157.4897
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 17.1389 - loss: 225.0812 - val_custom_mae: 14.1350 - val_loss: 141.2292
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 18.4501 - loss: 258.0329 - val_custom_mae: 13.8668 - val_loss: 136.1900
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - custom_mae: 18.6311 - loss: 260.1419 - val_custom_mae: 13.6795 - val_loss: 136.9198
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 17.5305 - loss: 231.7362 - val_custom_mae: 14.2086 - val_loss: 155.9636
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 15.8850 - loss: 193.7755 - val_custom_mae: 16.3600 - val_loss: 199.9150
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 14.4772 - loss: 166.9291 - val_custom_mae: 19.0431 - val_loss: 260.4609
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 13.8188 - loss: 157.7771 - val_custom_mae: 20.7199 - val_loss: 308.3609
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - custom_mae: 13.8814 - loss: 155.3751 - val_custom_mae: 21.0002 - val_loss: 317.0411
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 13.5965 - loss: 144.9189 - val_custom_mae: 19.7275 - val_loss: 288.4609
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - custom_mae: 12.8579 - loss: 126.8807 - val_custom_mae: 18.0208 - val_loss: 246.2405
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 11.9747 - loss: 110.9777 - val_custom_mae: 16.4514 - val_loss: 210.9634
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - custom_mae: 11.4372 - loss: 102.7406 - val_custom_mae: 15.4723 - val_loss: 191.6730
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 11.2019 - loss: 97.8586 - val_custom_mae: 15.5308 - val_loss: 191.7312
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 10.7631 - loss: 90.5834 - val_custom_mae: 16.6776 - val_loss: 211.9078
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 10.1129 - loss: 80.9415 - val_custom_mae: 18.6523 - val_loss: 250.2078
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - custom_mae: 9.5079 - loss: 72.3911 - val_custom_mae: 20.2481 - val_loss: 289.3996
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - custom_mae: 9.0877 - loss: 66.0579 - val_custom_mae: 20.9196 - val_loss: 306.9912
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - custom_mae: 8.5598 - loss: 58.6135 - val_custom_mae: 20.3655 - val_loss: 299.5901
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 7.9089 - loss: 51.0210 - val_custom_mae: 19.2608 - val_loss: 283.8949
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 7.5881 - loss: 47.4232 - val_custom_mae: 18.5896 - val_loss: 273.6234
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 7.4166 - loss: 45.2011 - val_custom_mae: 18.6223 - val_loss: 273.4042
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - custom_mae: 7.0549 - loss: 40.3989 - val_custom_mae: 19.2651 - val_loss: 282.5880
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 6.5911 - loss: 35.1587 - val_custom_mae: 20.0809 - val_loss: 290.0660
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - custom_mae: 6.2426 - loss: 32.1549 - val_custom_mae: 20.1974 - val_loss: 283.7528
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - custom_mae: 5.9295 - loss: 29.0227 - val_custom_mae: 19.5070 - val_loss: 265.2560
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - custom_mae: 5.6009 - loss: 25.6320 - val_custom_mae: 18.6589 - val_loss: 250.9577
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - custom_mae: 5.4081 - loss: 23.6108 - val_custom_mae: 18.2514 - val_loss: 249.4053
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 5.1446 - loss: 21.4928 - val_custom_mae: 18.4748 - val_loss: 259.1071
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 4.7081 - loss: 18.3933 - val_custom_mae: 18.9293 - val_loss: 272.2805
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 4.4141 - loss: 16.0075 - val_custom_mae: 19.1864 - val_loss: 278.1903
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - custom_mae: 4.2452 - loss: 14.7423 - val_custom_mae: 18.9963 - val_loss: 270.7238
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - custom_mae: 3.9718 - loss: 13.1191 - val_custom_mae: 18.4198 - val_loss: 256.8366
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - custom_mae: 3.6914 - loss: 11.6598 - val_custom_mae: 17.9598 - val_loss: 247.4524
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 3.4591 - loss: 10.5315 - val_custom_mae: 17.9740 - val_loss: 246.2386
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - custom_mae: 3.1755 - loss: 8.9395 - val_custom_mae: 18.2773 - val_loss: 251.4599
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 2.9150 - loss: 7.6528 - val_custom_mae: 18.5069 - val_loss: 256.1624
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - custom_mae: 2.9105 - loss: 7.2809 - val_custom_mae: 18.3500 - val_loss: 253.7903
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 2.8153 - loss: 6.7618 - val_custom_mae: 17.9211 - val_loss: 246.1474
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 2.6188 - loss: 5.7649 - val_custom_mae: 17.6397 - val_loss: 240.9266
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 2.4784 - loss: 4.9001 - val_custom_mae: 17.7906 - val_loss: 243.8120
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - custom_mae: 2.3240 - loss: 4.2408 - val_custom_mae: 18.3046 - val_loss: 254.9003
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 2.1543 - loss: 3.7960 - val_custom_mae: 18.7788 - val_loss: 266.5324
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 2.1270 - loss: 3.6719 - val_custom_mae: 18.7918 - val_loss: 268.4331
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - custom_mae: 2.0025 - loss: 3.2210 - val_custom_mae: 18.4412 - val_loss: 261.8978
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - custom_mae: 1.7796 - loss: 2.5808 - val_custom_mae: 17.9427 - val_loss: 252.6396
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - custom_mae: 1.6911 - loss: 2.3344 - val_custom_mae: 17.6886 - val_loss: 246.9467
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 1.6429 - loss: 2.1822 - val_custom_mae: 17.7817 - val_loss: 246.2868
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 1.5172 - loss: 1.8375 - val_custom_mae: 18.0382 - val_loss: 248.7282
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - custom_mae: 1.3896 - loss: 1.5410 - val_custom_mae: 18.1921 - val_loss: 250.0598
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 1.3612 - loss: 1.4130 - val_custom_mae: 18.1384 - val_loss: 249.1232
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - custom_mae: 1.2764 - loss: 1.2419 - val_custom_mae: 18.0137 - val_loss: 248.5241
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 1.1760 - loss: 1.0687 - val_custom_mae: 18.0128 - val_loss: 250.3484
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 1.0926 - loss: 0.9328 - val_custom_mae: 18.1431 - val_loss: 254.2098
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - custom_mae: 1.0270 - loss: 0.8117 - val_custom_mae: 18.2262 - val_loss: 256.3602
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 0.9546 - loss: 0.7029 - val_custom_mae: 18.1727 - val_loss: 254.6153
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - custom_mae: 0.8641 - loss: 0.6000 - val_custom_mae: 18.0727 - val_loss: 251.4950
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 0.7798 - loss: 0.4989 - val_custom_mae: 17.9514 - val_loss: 248.0735
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 0.7789 - loss: 0.4859 - val_custom_mae: 17.8878 - val_loss: 245.9932
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 0.7735 - loss: 0.4679 - val_custom_mae: 17.9142 - val_loss: 245.9299
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - custom_mae: 0.6875 - loss: 0.3738 - val_custom_mae: 17.9847 - val_loss: 247.2770
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - custom_mae: 0.6192 - loss: 0.3142 - val_custom_mae: 18.0310 - val_loss: 248.6713
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - custom_mae: 0.6190 - loss: 0.3087 - val_custom_mae: 18.0156 - val_loss: 249.2071
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 0.5913 - loss: 0.2775 - val_custom_mae: 18.0077 - val_loss: 249.5700
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 0.5417 - loss: 0.2318 - val_custom_mae: 17.9687 - val_loss: 249.5207
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 0.5178 - loss: 0.2062 - val_custom_mae: 17.9682 - val_loss: 249.7513
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - custom_mae: 0.5013 - loss: 0.1912 - val_custom_mae: 17.9679 - val_loss: 249.6242
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 0.4716 - loss: 0.1747 - val_custom_mae: 17.8916 - val_loss: 248.3037
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 0.4591 - loss: 0.1677 - val_custom_mae: 17.8302 - val_loss: 246.8805
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 0.4262 - loss: 0.1425 - val_custom_mae: 17.7932 - val_loss: 245.9537
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - custom_mae: 0.4326 - loss: 0.1419 - val_custom_mae: 17.8135 - val_loss: 246.2366
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - custom_mae: 0.3958 - loss: 0.1198 - val_custom_mae: 17.8559 - val_loss: 247.1095
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - custom_mae: 0.3672 - loss: 0.1014 - val_custom_mae: 17.8814 - val_loss: 247.4718
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 0.3736 - loss: 0.1017 - val_custom_mae: 17.8799 - val_loss: 247.2947
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - custom_mae: 0.3501 - loss: 0.0913 - val_custom_mae: 17.8482 - val_loss: 246.5454
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - custom_mae: 0.3216 - loss: 0.0808 - val_custom_mae: 17.8394 - val_loss: 246.2123
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - custom_mae: 0.3030 - loss: 0.0737 - val_custom_mae: 17.8648 - val_loss: 246.4916
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - custom_mae: 0.2850 - loss: 0.0652 - val_custom_mae: 17.8891 - val_loss: 246.7823
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 0.2732 - loss: 0.0575 - val_custom_mae: 17.8741 - val_loss: 246.4650
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - custom_mae: 0.2575 - loss: 0.0510 - val_custom_mae: 17.8233 - val_loss: 245.6521
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 0.2475 - loss: 0.0460 - val_custom_mae: 17.7771 - val_loss: 245.0307
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - custom_mae: 0.2330 - loss: 0.0417 - val_custom_mae: 17.7634 - val_loss: 244.9041
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - custom_mae: 0.2153 - loss: 0.0364 - val_custom_mae: 17.7765 - val_loss: 245.0628
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - custom_mae: 0.2030 - loss: 0.0334 - val_custom_mae: 17.7925 - val_loss: 245.1317
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - custom_mae: 0.1986 - loss: 0.0314 - val_custom_mae: 17.7950 - val_loss: 244.8527
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 0.1878 - loss: 0.0276 - val_custom_mae: 17.7938 - val_loss: 244.4936
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 0.1835 - loss: 0.0248 - val_custom_mae: 17.8017 - val_loss: 244.3654
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 0.1712 - loss: 0.0232 - val_custom_mae: 17.8167 - val_loss: 244.5382
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - custom_mae: 0.1574 - loss: 0.0213 - val_custom_mae: 17.8203 - val_loss: 244.6984
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - custom_mae: 0.1517 - loss: 0.0188 - val_custom_mae: 17.8040 - val_loss: 244.6195
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - custom_mae: 0.1439 - loss: 0.0163 - val_custom_mae: 17.7838 - val_loss: 244.5039
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 0.1385 - loss: 0.0154 - val_custom_mae: 17.7804 - val_loss: 244.6344
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - custom_mae: 0.1340 - loss: 0.0145 - val_custom_mae: 17.7940 - val_loss: 244.9216
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - custom_mae: 0.1282 - loss: 0.0131 - val_custom_mae: 17.8058 - val_loss: 244.9727

# %%
plot_training_analysis(history)

# %%
new_x, new_y = load_data(image_size=64, num_images=1000)

# %%
x_train, x_test, y_train, y_test = train_test_split(new_x, new_y, test_size = 0.2)

# %%
def simple_CNN_modif(image_size=64):
    # Définition du modèle simple, de type "LeNet" (§ 4.1.1)
    
    model = keras.Sequential()
    
    model.add(keras.layers.Conv2D(32,(3,3), padding='same', input_shape=(image_size,image_size,3), activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Conv2D(64,(3,3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Conv2D(96,(3,3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Conv2D(128,(3,3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(512, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
    model.add(keras.layers.Dense(28, activation='linear'))
    model.add(keras.layers.Reshape((2,14)))

    return model

# %%
model = simple_CNN_modif()

# %%
model = simple_CNN_modif()
model.compile(
    loss = custom_mse,
    optimizer = optimizers.Adam(learning_rate=3e-4),
    metrics = [custom_mae])
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))

# %%
import tensorflow as tf
devices = tf.config.list_physical_devices()
print(devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - custom_mae: 36.2095 - loss: 1301.2408 - val_custom_mae: 20.0645 - val_loss: 315.4645
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - custom_mae: 19.6682 - loss: 310.2335 - val_custom_mae: 20.0517 - val_loss: 311.6869
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - custom_mae: 19.2505 - loss: 298.5856 - val_custom_mae: 19.6087 - val_loss: 300.5839
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - custom_mae: 18.8505 - loss: 284.2275 - val_custom_mae: 19.2270 - val_loss: 287.7064
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 18.7367 - loss: 280.7512 - val_custom_mae: 19.1036 - val_loss: 282.9389
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 18.3055 - loss: 271.0279 - val_custom_mae: 19.1427 - val_loss: 280.5625
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 17.7054 - loss: 253.5019 - val_custom_mae: 18.8358 - val_loss: 274.4898
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 17.1940 - loss: 240.4457 - val_custom_mae: 19.1692 - val_loss: 284.8986
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - custom_mae: 16.9276 - loss: 237.0808 - val_custom_mae: 18.8088 - val_loss: 272.4256
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - custom_mae: 15.5317 - loss: 198.8807 - val_custom_mae: 18.6430 - val_loss: 269.3601
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 14.7839 - loss: 183.6905 - val_custom_mae: 19.4507 - val_loss: 288.8351
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - custom_mae: 14.5517 - loss: 178.7222 - val_custom_mae: 18.5662 - val_loss: 266.7693
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - custom_mae: 13.4988 - loss: 154.7106 - val_custom_mae: 18.7237 - val_loss: 271.4980
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - custom_mae: 13.0204 - loss: 145.4806 - val_custom_mae: 18.7039 - val_loss: 271.3669
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 12.2858 - loss: 132.8394 - val_custom_mae: 18.6877 - val_loss: 272.7454
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 11.6569 - loss: 120.2523 - val_custom_mae: 19.8809 - val_loss: 308.3442
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 11.0079 - loss: 106.7322 - val_custom_mae: 19.2234 - val_loss: 288.8489
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 10.3789 - loss: 96.3464 - val_custom_mae: 19.4422 - val_loss: 296.8437
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 9.4400 - loss: 81.7552 - val_custom_mae: 19.4253 - val_loss: 294.9139
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 8.9729 - loss: 74.7075 - val_custom_mae: 19.5380 - val_loss: 298.4288
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 8.3923 - loss: 66.3357 - val_custom_mae: 19.3707 - val_loss: 295.7746
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 8.1207 - loss: 62.5860 - val_custom_mae: 19.5625 - val_loss: 303.7782
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 7.2769 - loss: 51.7957 - val_custom_mae: 19.6909 - val_loss: 307.2322
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - custom_mae: 6.7258 - loss: 45.3354 - val_custom_mae: 19.8665 - val_loss: 310.7624
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 6.1892 - loss: 39.9079 - val_custom_mae: 19.9758 - val_loss: 314.7902
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 5.7120 - loss: 34.4775 - val_custom_mae: 19.9281 - val_loss: 312.4779
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - custom_mae: 5.4630 - loss: 32.3440 - val_custom_mae: 20.3911 - val_loss: 326.7131
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 5.1375 - loss: 29.0979 - val_custom_mae: 19.9466 - val_loss: 315.7737
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 4.7916 - loss: 26.0564 - val_custom_mae: 20.2390 - val_loss: 324.1126
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 4.5435 - loss: 23.9501 - val_custom_mae: 20.0857 - val_loss: 319.4373
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - custom_mae: 4.5050 - loss: 23.4096 - val_custom_mae: 19.9181 - val_loss: 314.8843
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 4.1030 - loss: 20.7314 - val_custom_mae: 20.2568 - val_loss: 324.9638
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 3.9703 - loss: 19.7429 - val_custom_mae: 20.1224 - val_loss: 321.0438
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 3.6346 - loss: 17.4430 - val_custom_mae: 20.1932 - val_loss: 322.5454
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 3.4093 - loss: 16.2706 - val_custom_mae: 20.3283 - val_loss: 327.8434
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 3.2361 - loss: 15.1350 - val_custom_mae: 20.1316 - val_loss: 322.1114
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 3.0624 - loss: 14.1706 - val_custom_mae: 20.1557 - val_loss: 321.3570
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 2.9142 - loss: 13.3369 - val_custom_mae: 20.2139 - val_loss: 323.7008
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 2.7980 - loss: 12.7879 - val_custom_mae: 20.2439 - val_loss: 326.3935
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - custom_mae: 2.6176 - loss: 12.0499 - val_custom_mae: 20.4047 - val_loss: 329.9917
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 2.4812 - loss: 11.5367 - val_custom_mae: 20.3802 - val_loss: 329.7571
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 2.3298 - loss: 10.7430 - val_custom_mae: 20.4119 - val_loss: 330.6364
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.2804 - loss: 10.6149 - val_custom_mae: 20.3632 - val_loss: 328.5399
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.2158 - loss: 10.2052 - val_custom_mae: 20.4448 - val_loss: 330.2853
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 2.2533 - loss: 10.2909 - val_custom_mae: 20.3796 - val_loss: 330.6136
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.4423 - loss: 11.1155 - val_custom_mae: 20.2768 - val_loss: 325.1923
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 2.4546 - loss: 11.2588 - val_custom_mae: 20.6703 - val_loss: 338.9825
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - custom_mae: 2.8093 - loss: 12.6245 - val_custom_mae: 20.6239 - val_loss: 335.6741
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 2.5793 - loss: 11.6086 - val_custom_mae: 20.2464 - val_loss: 324.5215
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - custom_mae: 2.6467 - loss: 11.9383 - val_custom_mae: 20.3982 - val_loss: 329.8531
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 2.4269 - loss: 10.8611 - val_custom_mae: 20.3199 - val_loss: 328.5460
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.2828 - loss: 10.3167 - val_custom_mae: 20.3649 - val_loss: 330.3955
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 2.2196 - loss: 10.1233 - val_custom_mae: 20.3987 - val_loss: 330.8500
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 2.1907 - loss: 9.8865 - val_custom_mae: 20.1509 - val_loss: 322.2067
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.2214 - loss: 9.9713 - val_custom_mae: 20.2872 - val_loss: 327.4146
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - custom_mae: 2.0014 - loss: 9.2093 - val_custom_mae: 20.2690 - val_loss: 324.1974
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 1.9785 - loss: 9.1617 - val_custom_mae: 20.2994 - val_loss: 327.6666
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - custom_mae: 1.9841 - loss: 9.1774 - val_custom_mae: 20.6462 - val_loss: 335.4937
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 3.0635 - loss: 13.3384 - val_custom_mae: 20.9037 - val_loss: 347.2240
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 3.5643 - loss: 15.9635 - val_custom_mae: 20.2684 - val_loss: 325.6883
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 3.4160 - loss: 15.1306 - val_custom_mae: 20.3001 - val_loss: 328.1758
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 2.7465 - loss: 12.0103 - val_custom_mae: 20.1557 - val_loss: 322.7489
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - custom_mae: 2.3262 - loss: 10.2247 - val_custom_mae: 20.2040 - val_loss: 322.5652
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 1.9559 - loss: 8.9196 - val_custom_mae: 20.3838 - val_loss: 330.2955
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 1.8608 - loss: 8.6055 - val_custom_mae: 20.1483 - val_loss: 321.2815
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - custom_mae: 1.6036 - loss: 7.8833 - val_custom_mae: 20.1797 - val_loss: 322.6356
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 1.4118 - loss: 7.3788 - val_custom_mae: 20.2473 - val_loss: 324.0360
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 1.2781 - loss: 7.0716 - val_custom_mae: 20.3113 - val_loss: 326.6571
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 1.2054 - loss: 6.9331 - val_custom_mae: 20.2576 - val_loss: 324.9685
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - custom_mae: 1.0641 - loss: 6.6468 - val_custom_mae: 20.2724 - val_loss: 325.3383
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 1.0464 - loss: 6.5928 - val_custom_mae: 20.2854 - val_loss: 325.2260
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 0.9973 - loss: 6.5013 - val_custom_mae: 20.1792 - val_loss: 322.1653
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - custom_mae: 1.0517 - loss: 6.5802 - val_custom_mae: 20.1750 - val_loss: 322.1272
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 1.0857 - loss: 6.6190 - val_custom_mae: 20.2887 - val_loss: 325.6117
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 1.0740 - loss: 6.5835 - val_custom_mae: 20.2743 - val_loss: 324.7305
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - custom_mae: 1.0471 - loss: 6.5381 - val_custom_mae: 20.2728 - val_loss: 325.2490
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 1.0381 - loss: 6.5018 - val_custom_mae: 20.2891 - val_loss: 325.0620
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - custom_mae: 1.0383 - loss: 6.4768 - val_custom_mae: 20.3055 - val_loss: 326.1933
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 1.0178 - loss: 6.4320 - val_custom_mae: 20.3628 - val_loss: 327.7635
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 1.2935 - loss: 6.9268 - val_custom_mae: 20.2452 - val_loss: 323.9229
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 1.3643 - loss: 7.0830 - val_custom_mae: 20.1803 - val_loss: 322.0923
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 1.3710 - loss: 7.1537 - val_custom_mae: 20.2178 - val_loss: 322.9482
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 1.5556 - loss: 7.5283 - val_custom_mae: 20.2689 - val_loss: 324.4128
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 1.6831 - loss: 7.8781 - val_custom_mae: 20.3556 - val_loss: 326.0954
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 1.8403 - loss: 8.3079 - val_custom_mae: 20.3236 - val_loss: 327.7275
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 2.0238 - loss: 8.8614 - val_custom_mae: 20.2151 - val_loss: 321.9549
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - custom_mae: 2.3467 - loss: 9.9779 - val_custom_mae: 20.4694 - val_loss: 330.1414
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.5268 - loss: 10.6313 - val_custom_mae: 20.2684 - val_loss: 325.0260
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.5678 - loss: 10.9351 - val_custom_mae: 20.2743 - val_loss: 324.8298
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 2.3462 - loss: 10.0513 - val_custom_mae: 20.1920 - val_loss: 321.2790
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 2.1304 - loss: 9.1554 - val_custom_mae: 20.3250 - val_loss: 324.4539
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - custom_mae: 2.1134 - loss: 9.1000 - val_custom_mae: 20.2247 - val_loss: 323.3250
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 2.0731 - loss: 8.9458 - val_custom_mae: 20.0288 - val_loss: 317.6703
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 2.0984 - loss: 9.0805 - val_custom_mae: 20.3178 - val_loss: 325.5220
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - custom_mae: 2.0022 - loss: 8.6854 - val_custom_mae: 20.3216 - val_loss: 326.1809
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 1.9876 - loss: 8.6411 - val_custom_mae: 20.1462 - val_loss: 320.2319
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - custom_mae: 1.8675 - loss: 8.1695 - val_custom_mae: 20.1774 - val_loss: 320.7661
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 2.1021 - loss: 8.9232 - val_custom_mae: 20.0148 - val_loss: 316.4361
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - custom_mae: 2.3850 - loss: 9.9468 - val_custom_mae: 20.0365 - val_loss: 316.1706
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - custom_mae: 2.3017 - loss: 9.6740 - val_custom_mae: 20.1936 - val_loss: 320.8079

# %%
plot_training_analysis(history)

# %%
from tensorflow.keras import layers, regularizers

# %% [markdown]
# ---
#
# ## Petit retour sur la 1ère partie (avant de passer à la suite !)
#
# Si vous n'êtes pas allés jusqu'au bout de la partie 1, sachez que même avec un réseau bien construit, de capacité suffisante, en utilisant les 10000 images de la base d'apprentissage, de la régularisation et de l'augmentation de données (non demandé dans le TP), vous ne seriez pas arrivé à limiter le sur-apprentissage suffisamment pour obtenir des résultats satisfaisants sur l'ensemble de test. On plafonne à un pourcentage de joints correctement prédits (PCK&#64;0.5) aux alentours de 20\%.
#
# Cela est principalement dû à la formulation du problème, plus difficile à résoudre, et aux architectures mises en place. En effet, les couches de sous-échantillonnage (*pooling*) successives entraînent une perte de précision irrémédiable qui ne peut pas être compensée par les couches denses.

# %% [markdown]
# # **Approche n°2** : Prédiction de cartes de chaleur
#
# Dans cette partie, nous allons utiliser une autre formulation du problème, présentée pendant le cours. Plutôt que de prédire directement la position pixellique des joints, nous allons prédire des cartes de probabilité de la position des joints, comme illustré ci-dessous. Pour ce faire, il nous faudra tester des architectures de réseau de neurones différentes, s'inspirant de celles utilisées en segmentation d'image.
#
# ![Texte alternatif…](https://drive.google.com/uc?id=1B8BCwQ0Szg_T_H05mnfpXFemUT5xhfxX)

# %% [markdown]
# ## Fonctions utiles
#
# La fonction suivante permet de créer une carte de chaleur de la dimension voulue, avec une gaussienne centrée en un point donné.

# %%
from scipy.ndimage import gaussian_filter

# %%
def heat_point(ind_x, ind_y, heatmap_size):
    heat_point=np.zeros((heatmap_size,heatmap_size))
    heat_point[ind_x][ind_y] = 1
    
    return gaussian_filter(heat_point, round(heatmap_size/20))


h_m = heat_point(14, 44, 64)
plt.imshow(h_m)
plt.show()

# %% [markdown]
# On peut ensuite retrouver la position du point le plus "chaud", en utilisant la commande suivante :

# %%
np.unravel_index(np.argmax(h_m), h_m.shape)
# Out:
# (14, 44)

# %% [markdown]
# On peut donc définir les 2 fonctions suivantes permettant de générer les cartes de chaleur à partir des coordonnées de joints, et vice-versa.

# %%
def coord2heatmap(y, heatmap_size):
    heatmap = np.zeros((y.shape[0], 14, heatmap_size, heatmap_size))
    for img in range(y.shape[0]):
        for j in range(14):
            ind_x = int(y[img][1][j])
            ind_y = int(y[img][0][j])
            #print(ind_x, ind_y)
            if ind_x >= 0 and ind_y >= 0 and ind_x < heatmap_size and ind_y < heatmap_size:
                heatmap[img][j] = heat_point(ind_x, ind_y, heatmap_size)
    heatmap = np.transpose(heatmap, (0, 2, 3, 1))
    heatmap = heatmap / np.max(heatmap)
    return heatmap


def heatmap2coord(heatmap):
    y = np.ones((heatmap.shape[0], 3, 14))

    heatmap = np.transpose(heatmap, (0, 3, 1, 2))
    for img in range(y.shape[0]):
        for j in range(14): 
            max_heat = np.unravel_index(np.argmax(heatmap[img][j]), heatmap[img][j].shape)  
            y[img][0][j] = max_heat[1]
            y[img][1][j] = max_heat[0]
            if max_heat[0] == 0 and max_heat[1] == 0:
                y[img][2][j] = 0 # Le joint est invisible
    return y

# %% [markdown]
# **Todo** : Ecrivez une fonction permettant d'affichager des cartes de
#
# On affichera pour `rows` images $x$ et carte de chaleur $y$ associée : (i) l'image, (ii) tous les joints simultanément, (iii) seulement la tête, (iv) seulement le coude droit, (v) seulement le genou gauche.
#
# La cellule ci-dessous donne un exemple de résultat attendu.

# %%
img = Image.open('img/print_heatmap.png')
plt.imshow(img)
plt.show()

# %%
def print_heatmap(x, y, rows=3):
    hm = np.transpose(y, (0,3,1,2))

    for i in range(rows):
        j = np.random.randint(1,x.shape[0])
        plt.figure(figsize=(12, 12))
        
        # Affichage de l'image
        plt.subplot(rows,5,5*i+1)
        plt.imshow(x[j])
        plt.title('Image originale')
        
        # Affichage simultané de tous les joints
        plt.subplot(rows,5,5*i+2)
        joints = np.zeros((y.shape[1], y.shape[2]))
        for k in range(14):
            joints += hm[j][k]
        plt.imshow(joints)
        plt.title('Tous les joints')

        plt.subplot(rows, 5, 5*i+3)
        plt.imshow(hm[j][13])
        plt.title('Tête')
        
        plt.subplot(rows, 5, 5*i+4)
        plt.imshow(hm[j][7])
        plt.title('Coude droit')
        
        plt.subplot(rows, 5, 5*i+5)
        plt.imshow(hm[j][4])
        plt.title('Genou gauche')
        
        plt.show()

# %%
# %load solutions/print_heatmap.py

# %% [markdown]
# Les lignes suivantes vous permettront de démarrer simplement :

# %%
from sklearn.model_selection import train_test_split

# %%
# Chargement des données : on choisit une dimension d'image et de carte de chaleur de 64x64
image_size = 64
heatmap_size = 64

# Chargement de seulement 1000 images
x, y = load_data(image_size=image_size, num_images=1000) 

# Normalisation des données
x = x/255

# Chargement des données : 1000 images d'apprentissage, 100 de validation, 100 de test    
x_train, x_gen, y_train, y_gen = train_test_split(x, y, test_size=1/10, random_state=2)
x_val, x_test, y_val, y_test = train_test_split(x_gen, y_gen, test_size=1/2, random_state=1)

# Calcul des cartes de chaleur (prend un peu de temps)
y_hm_train = coord2heatmap(y_train, heatmap_size)
y_hm_val = coord2heatmap(y_val, heatmap_size)
y_hm_test = coord2heatmap(y_test, heatmap_size)

# Affichage de quelques exemples
print_heatmap(x_train, y_hm_train)

# %% [markdown]
# Pour vous aider pour la suite, voici ci-dessous une implémentation du réseau UNet, vu en cours sur la segmentation.
#
# ![Texte alternatif…](https://raw.githubusercontent.com/zhixuhao/unet/master/img/u-net-architecture.png)
#
# A vous de l'**adapter** afin qu'il soit pertinent pour le problème courant.

# %%
import keras
from keras.layers import *
from keras import *

# %%
# def create_unet(image_size=572):
#     input_layer=Input((image_size, image_size, 1))

#     conv1 = keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
#     conv1 = keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
#     pool1 = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)

#     conv2 = keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
#     conv2 = keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
#     pool2 = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)

#     conv3 = keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
#     conv3 = keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
#     pool3 = keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3)

#     conv4 = keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
#     conv4 = keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
#     drop4 = keras.layers.Dropout(0.5)(conv4)
#     pool4 = keras.layers.MaxPooling2D(pool_size=(2, 2))(drop4)

#     conv5 = keras.layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
#     conv5 = keras.layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
#     drop5 = keras.layers.Dropout(0.5)(conv5)

#     up6 = keras.layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
#     merge6 = keras.layers.concatenate([drop4,up6], axis = 3)
#     conv6 = keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
#     conv6 = keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

#     up7 = keras.layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
#     merge7 = keras.layers.concatenate([conv3,up7], axis = 3)
#     conv7 = keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
#     conv7 = keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

#     up8 = keras.layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
#     merge8 = keras.layers.concatenate([conv2,up8], axis = 3)
#     conv8 = keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
#     conv8 = keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

#     up9 = keras.layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
#     merge9 = keras.layers.concatenate([conv1,up9], axis = 3)
#     conv9 = keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
#     conv9 = keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
#     conv10 = keras.layers.Conv2D(14, 1, activation = 'sigmoid')(conv9)

#     model = Model(input_layer, conv10)

#     return model

# %%
def create_unet(image_size=64):
    input_layer=Input((image_size, image_size, 3))

    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv10 = Conv2D(14, 1, activation = 'sigmoid')(conv9)

    model = Model(input_layer, conv10)

    return model

# %%
model = create_unet(image_size=64)
model.summary()
# Out:
# Model: "functional_114"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_128 (Conv2D) │ (None, 64, 64,    │        896 │ input_layer_13[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_129 (Conv2D) │ (None, 64, 64,    │      9,248 │ conv2d_128[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_52    │ (None, 32, 32,    │          0 │ conv2d_129[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_130 (Conv2D) │ (None, 32, 32,    │     18,496 │ max_pooling2d_52… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_131 (Conv2D) │ (None, 32, 32,    │     36,928 │ conv2d_130[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_53    │ (None, 16, 16,    │          0 │ conv2d_131[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_132 (Conv2D) │ (None, 16, 16,    │     73,856 │ max_pooling2d_53… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_133 (Conv2D) │ (None, 16, 16,    │    147,584 │ conv2d_132[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_54    │ (None, 8, 8, 128) │          0 │ conv2d_133[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_134 (Conv2D) │ (None, 8, 8, 128) │    147,584 │ max_pooling2d_54… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_135 (Conv2D) │ (None, 8, 8, 128) │    147,584 │ conv2d_134[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 8, 8, 128) │          0 │ conv2d_135[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_55    │ (None, 4, 4, 128) │          0 │ dropout_8[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_136 (Conv2D) │ (None, 4, 4, 128) │    147,584 │ max_pooling2d_55… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_137 (Conv2D) │ (None, 4, 4, 128) │    147,584 │ conv2d_136[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 4, 4, 128) │          0 │ conv2d_137[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_16    │ (None, 8, 8, 128) │          0 │ dropout_9[0][0]   │
# │ (UpSampling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_138 (Conv2D) │ (None, 8, 8, 128) │     65,664 │ up_sampling2d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 8, 8, 256) │          0 │ dropout_8[0][0],  │
# │ (Concatenate)       │                   │            │ conv2d_138[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_139 (Conv2D) │ (None, 8, 8, 128) │    295,040 │ concatenate_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_140 (Conv2D) │ (None, 8, 8, 128) │    147,584 │ conv2d_139[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_17    │ (None, 16, 16,    │          0 │ conv2d_140[0][0]  │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_141 (Conv2D) │ (None, 16, 16,    │     65,664 │ up_sampling2d_17… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 16, 16,    │          0 │ conv2d_133[0][0], │
# │ (Concatenate)       │ 256)              │            │ conv2d_141[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_142 (Conv2D) │ (None, 16, 16,    │    295,040 │ concatenate_17[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_143 (Conv2D) │ (None, 16, 16,    │    147,584 │ conv2d_142[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_18    │ (None, 32, 32,    │          0 │ conv2d_143[0][0]  │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_144 (Conv2D) │ (None, 32, 32,    │     32,832 │ up_sampling2d_18… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 32, 32,    │          0 │ conv2d_131[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_144[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_145 (Conv2D) │ (None, 32, 32,    │     73,792 │ concatenate_18[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_146 (Conv2D) │ (None, 32, 32,    │     36,928 │ conv2d_145[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 64, 64,    │          0 │ conv2d_146[0][0]  │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_147 (Conv2D) │ (None, 64, 64,    │      8,224 │ up_sampling2d_19… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 64, 64,    │          0 │ conv2d_129[0][0], │
# │ (Concatenate)       │ 64)               │            │ conv2d_147[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_148 (Conv2D) │ (None, 64, 64,    │     18,464 │ concatenate_19[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_149 (Conv2D) │ (None, 64, 64,    │      9,248 │ conv2d_148[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_150 (Conv2D) │ (None, 64, 64,    │        462 │ conv2d_149[0][0]  │
# │                     │ 14)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,073,870 (7.91 MB)
#  Trainable params: 2,073,870 (7.91 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss = 'binary_crossentropy',
    optimizer = optimizers.Adam(learning_rate=1e-3),
)

# %%
history = model.fit(x_train, y_hm_train, epochs=50, validation_data=(x_val, y_hm_val))
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 219ms/step - loss: 0.5081 - val_loss: 0.0488
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 213ms/step - loss: 0.0243 - val_loss: 0.0407
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - loss: 0.0205 - val_loss: 0.0367
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - loss: 0.0195 - val_loss: 0.0359
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 266ms/step - loss: 0.0189 - val_loss: 0.0359
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - loss: 0.0188 - val_loss: 0.0354
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - loss: 0.0186 - val_loss: 0.0353
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step - loss: 0.0184 - val_loss: 0.0350
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - loss: 0.0185 - val_loss: 0.0350
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step - loss: 0.0185 - val_loss: 0.0352
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step - loss: 0.0182 - val_loss: 0.0362
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - loss: 0.0182 - val_loss: 0.0350
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - loss: 0.0181 - val_loss: 0.0347
# Epoch 14/50
# 18/29 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - loss: 0.0179

# %%
# mae = history.history['binary_crossentropy']
# val_mae = history.history['val_binary_crossentropy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

# plt.subplot(1,2,1)
# plt.plot(epochs, mae, 'b', linestyle="--",label='Training MAE')
# plt.plot(epochs, val_mae, 'g', label='Validation MAE')
# plt.title('Training and validation MAE')
# plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
plt.plot(epochs, val_loss,'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## À vous de jouer
#
# Essayez d'adapter le réseau Unet ($\leadsto$ `modif_unet.py`) à votre problème, puis de l'entraîner sur le petit ensemble de données x_train.
#
# Plusieurs remarques (**à lire attentivement**) :
#
#
#
# *  Vous devriez observer beaucoup moins de sur-apprentissage ! Si vos prédictions sur l'ensemble de validation sont aberrantes, c'est que vous avez un bug !!
# *   Se pose la question de la formulation du problème : dans la mesure où
# les cartes de chaleur sont assimilables à des cartes de probabilité (entre 0 et 1), on peut certes choisir de conserver une formaulation du problème basée sur la régression, mais il est probablement beaucoup plus optimal de formuler le problème comme de la classification binaire.
# *   Il y a cependant toujours du sur-apprentissage. Vous pouvez donc augmenter la taille de la base de données à 10000, puis tester différentes possibilités pour diminuer ce sous-apprentissage, notamment l'augmentation de données. Les cellules suivantes vous fournissent des éléments permettant de mettre en place cette augmentation.

# %% [markdown]
# ## Code fourni pour l'augmentation de données
#
# Vous trouverez ici quelques éléments qui vous permettront de mettre en place de l'augmentation de données.
# Attention l'augmentation rend l'apprentissage plus difficile et en fait plus lent, et vous devrez peut-être augmenter un peu la capacité de votre UNet et le nombre d'epochs pour éviter le sous-apprentissage.

# %% [markdown]
# [`Albumentation`](https://albumentations.ai/) est une librairie implémentant un grand nombre d'opérations d'augmentation de données. Dans le code suivant, deux types d'augmentation sont définies : des transformations spatiales (`ShiftScaleRotate`), et des transformations colorimétriques.

# %%
# !pip install -q -U albumentations
# !echo "$(pip freeze | grep albumentations) is successfully installed"

# %%
import cv2 as cv
from albumentations import (Compose, RandomBrightnessContrast, RandomGamma, ShiftScaleRotate)

# %%
AUGMENTATIONS_TRAIN = Compose([
    ShiftScaleRotate(p=0.5),
    RandomBrightnessContrast(contrast_limit=0.2, brightness_limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
])

# %% [markdown]
# La classe `Sequence` permet de définir l'accès aux données d'entraînement de manière personnalisée, afin par exemple d'implanter des augmentations particulières (c'est le cas ici).
# Prenez le temps de comprendre la synthaxe utilisée.

# %%
from tensorflow.keras.utils import Sequence

# %%
class LSPDSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_set, y_set, batch_size,augmentations):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(x_set.shape[0]) 
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder aux données 
        # et sont randomisés à chaque epoch pour varier la composition des batches au cours de l'entraînement

        
    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int( np.ceil(len(self.x) / float(self.batch_size)) )

    
    # Application de l'augmentation de données à chaque image du batch et aux cartes de probabilités associées
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros(bx.shape)
        batch_y = np.zeros(by.shape)
        # Pour chaque image du batch
        for i in range(len(bx)):
            masks = []
            # Les 14 masques associés à l'image sont rangés dans une liste pour 
            # pourvoir être traités par la librairie Albumentation
            for n in range(by.shape[3]):
                masks.append(by[i,:,:,n])

            img = bx[i]
            # Application de l'augmentation à l'image et aux masques
            transformed = self.augment(image=img, masks=masks)
            batch_x[i] = transformed['image']
            batch_y_list = transformed['masks']

            # Reconstitution d'un tenseur à partir des masques augmentés
            for k in range(by.shape[3]):
                batch_y[i,:,:,k] = batch_y_list[k]

        return batch_x, batch_y

    
    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    def __getitem__(self, idx):
        batch_x = self.x[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)

        return np.array(batch_x), np.array(batch_y)

    
    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %%
x_train = x_train.astype(np.float32)
y_hm_train = y_hm_train.astype(np.float32)

# Instanciation d'une Sequence
train_gen = LSPDSequence(x_train, y_hm_train, 16, augmentations=AUGMENTATIONS_TRAIN)

# Pour tester la séquence, nous sélectionnons les éléments du premier batch et les affichons
batch_x, batch_y = train_gen.__getitem__(0)

print_heatmap(batch_x, batch_y)

# %% [markdown]
# Pour utiliser cette séquence il vous suffit d'appeler la fonction `fit` de la manière suivante :
# ```python
# model.fit(train_gen, ...)
# ```
