# %%
# %matplotlib inline

# %% [markdown]
# # Preliminaries

# %%
import os
import pandas as pd
from ase.io import read
import torch
import time
import numpy as np
from sklearn import preprocessing, linear_model, pipeline, model_selection
from tqdm import tqdm

# %%
from sklearn import (linear_model, model_selection, preprocessing,
                     pipeline)
from scipy.spatial.distance import pdist

# %%
from kymatio.torch import HarmonicScattering3D

# %%
from kymatio.scattering3d.backend.torch_backend \
    import TorchBackend3D

# %%
from kymatio.scattering3d.utils \
    import generate_weighted_sum_of_gaussians

# %%
from kymatio.datasets import fetch_qm7
from kymatio.caching import get_cache_dir

# %% [markdown]
# # Energies dataframe

# %%
# Path setup
data_dir = "./"  # <-- Change this to your actual data path
atoms_train_dir = os.path.join(data_dir, "atoms", "train")
energies_csv = os.path.join(data_dir, "energies", "train.csv")

# %%
# Read energies CSV
energies_df = pd.read_csv(energies_csv)
energies_df["id"] = energies_df["id"].astype(str)
energies_df = energies_df.sort_values("id")
print("Loaded energy data:\n", energies_df.head().to_string(index=False))
# Out:
# Loaded energy data:
#    id     energy
#    1 -90.107880
#   10 -69.210846
#  100 -64.983899
# 1000 -76.559740
# 1001 -62.270961

# %% [markdown]
# # Positions and charges

# %%
def extract_features(xyz_path):
    atoms = read(xyz_path)
    positions = atoms.get_positions()
    charges = atoms.get_atomic_numbers()
    return positions, charges

def load_all_xyz(folder_path, max_atoms=23):
    positions_list = []
    charges_list = []
    
    xyz_files = sorted([
        os.path.join(folder_path, f)
        for f in os.listdir(folder_path)
        if f.endswith('.xyz')
    ])

    for xyz_path in xyz_files:
        pos, chg = extract_features(xyz_path)
        
        pos_padded = np.zeros((max_atoms, 3))
        chg_padded = np.zeros((max_atoms,))
        
        n_atoms = pos.shape[0]
        pos_padded[:n_atoms, :] = pos
        chg_padded[:n_atoms] = chg

        positions_list.append(pos_padded)
        charges_list.append(chg_padded)

    positions_array = np.stack(positions_list)  # shape (N, max_atoms, 3)
    charges_array = np.stack(charges_list)      # shape (N, max_atoms)
    
    return positions_array, charges_array

# %%
pos_train, full_charges_train = load_all_xyz("./atoms/train/", max_atoms=23)
n_molecules_train = pos_train.shape[0]
print(n_molecules_train)
# Out:
# 6591

# %% [markdown]
# # Add additional features into scattering coefficients

# %%
def compute_additional_features(pos_batch, full_batch, val_batch):
    batch_size = pos_batch.shape[0]
    features = []
    for i in range(batch_size):
        n_atoms = np.sum(full_batch[i] != 0)
        atom_types = full_batch[i][:n_atoms]

        num_atoms = n_atoms
        mean_valence = np.mean(val_batch[i][:n_atoms])
        sum_charge = np.sum(full_batch[i][:n_atoms])
        sum_valence = np.sum(val_batch[i][:n_atoms])

        feat_i = [num_atoms, mean_valence, sum_charge, sum_valence]
        features.append(feat_i)

    return torch.tensor(features, dtype=torch.float32).to(device)

# %% [markdown]
# # Data preparation

# %%
mask = full_charges_train <= 2
valence_charges = full_charges_train* mask

mask = np.logical_and(full_charges_train > 2, full_charges_train <= 10)
valence_charges += (full_charges_train - 2) * mask

mask = np.logical_and(full_charges_train > 10, full_charges_train <= 18)
valence_charges += (full_charges_train - 10) * mask

# %%
overlapping_precision = 1e-1
sigma = 2.0
min_dist = np.inf

for i in range(n_molecules_train):
    n_atoms = np.sum(full_charges_train[i] != 0)
    pos_i = pos_train[i, :n_atoms, :]
    min_dist = min(min_dist, pdist(pos_i).min())

delta = sigma * np.sqrt(-8 * np.log(overlapping_precision))
pos = pos_train * delta / min_dist

# %% [markdown]
# ## Scattering Transform

# %%
M, N, O = 96, 64, 48

grid = np.mgrid[-M//2:-M//2+M, -N//2:-N//2+N, -O//2:-O//2+O]
grid = np.fft.ifftshift(grid)

# %%
J = 2
L = 3
integral_powers = [0.5, 1.0, 2.0, 3.0]

scattering_train = HarmonicScattering3D(J=J, shape=(M, N, O),
                                  L=L, sigma_0=sigma,
                                  integral_powers=integral_powers)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
scattering_train.to(device)
print("Using", device)
# Out:
# Using cuda

# %% [markdown]
# The maps computed for each molecule are quite large, so the computation has
# to be done by batches. Here we select a small batch size to ensure that we
# have enough memory when running on the GPU. Dividing the number of molecules
# by the batch size then gives us the number of batches.

# %%
batch_size = 8
n_batches = int(np.ceil(n_molecules_train/ batch_size))
print(n_batches)
# Out:
# 824

# %% [markdown]
# We are now ready to compute the scattering transforms. In the following
# loop, each batch of molecules is transformed into three maps using Gaussians
# centered at the atomic positions, one for the nuclear charges, one for the
# valence charges, and one with their difference (called the “core” charges).
# For each map, we compute its scattering transform up to order two and store
# the results.

# %%
order_0, orders_1_and_2 = [], []
print('Computing solid harmonic scattering coefficients of '
      '{} molecules from the QM7 database on {}'.format(
        n_molecules_train,   "GPU" if use_cuda else "CPU"))
print('sigma: {}, L: {}, J: {}, integral powers: {}'.format(
        sigma, L, J, integral_powers))

this_time = None
last_time = None
for i in tqdm(range(n_batches)):
    this_time = time.time()
    if last_time is not None:
        dt = this_time - last_time
        print("Iteration {} ETA: [{:02}:{:02}:{:02}]".format(
                    i + 1, int(((n_batches - i - 1) * dt) // 3600),
                    int((((n_batches - i - 1) * dt) // 60) % 60),
                    int(((n_batches - i - 1) * dt) % 60)))
    else:
        print("Iteration {} ETA: {}".format(i + 1, '-'))
    last_time = this_time
    time.sleep(1)

    # Extract the current batch.
    start = i * batch_size
    end = min(start + batch_size, n_molecules_train)

    pos_batch = pos[start:end]
    full_batch = full_charges_train[start:end]
    val_batch = valence_charges[start:end]

    # Calculate the density map for the nuclear charges and transfer
    # to PyTorch.
    full_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, full_batch, sigma)
    full_density_batch = torch.from_numpy(full_density_batch)
    full_density_batch = full_density_batch.to(device).float()

    # Compute zeroth-order, first-order, and second-order scattering
    # coefficients of the nuclear charges.
    full_order_0 = TorchBackend3D.compute_integrals(full_density_batch,
                                     integral_powers)
    full_scattering = scattering_train(full_density_batch)

    # Compute the map for valence charges.
    val_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, val_batch, sigma)
    val_density_batch = torch.from_numpy(val_density_batch)
    val_density_batch = val_density_batch.to(device).float()

    # Compute scattering coefficients for the valence charges.
    val_order_0 = TorchBackend3D.compute_integrals(val_density_batch,
                                    integral_powers)
    val_scattering = scattering_train(val_density_batch)

    # Take the difference between nuclear and valence charges, then
    # compute the corresponding scattering coefficients.
    core_density_batch = full_density_batch - val_density_batch

    core_order_0 = TorchBackend3D.compute_integrals(core_density_batch,
                                     integral_powers)
    core_scattering = scattering_train(core_density_batch)

    # Add features 
    additional_feats = compute_additional_features(pos_batch, full_batch, val_batch)


    # === Stack et flatten ===
    batch_order_0 = torch.stack((full_order_0, val_order_0, core_order_0), dim=-1)  # shape (B, P, 3)
    batch_orders_1_and_2 = torch.stack((full_scattering, val_scattering, core_scattering), dim=-1)  # shape (B, C, 3)

    batch_order_0_flat = batch_order_0.view(batch_order_0.size(0), -1)
    batch_orders_1_and_2_flat = batch_orders_1_and_2.view(batch_orders_1_and_2.size(0), -1)
    
    # === Concatenation des features ===
    batch_order_0_enriched = torch.cat([batch_order_0_flat, additional_feats], dim=1)
    batch_orders_enriched = torch.cat([batch_orders_1_and_2_flat, additional_feats], dim=1)

    order_0.append(batch_order_0_enriched)
    orders_1_and_2.append(batch_orders_enriched)
# Out:
# Computing solid harmonic scattering coefficients of 6591 molecules from the QM7 database on GPU
# sigma: 2.0, L: 3, J: 2, integral powers: [0.5, 1.0, 2.0, 3.0]
# Iteration 1 ETA: -
# Iteration 2 ETA: [00:47:16]
# Iteration 3 ETA: [00:41:48]
# Iteration 4 ETA: [00:41:35]
# Iteration 5 ETA: [00:41:54]
# Iteration 6 ETA: [00:41:32]
# Iteration 7 ETA: [00:42:02]
# Iteration 8 ETA: [00:42:21]
# Iteration 9 ETA: [00:42:43]
# Iteration 10 ETA: [00:42:19]
# Iteration 11 ETA: [00:41:18]
# Iteration 12 ETA: [00:42:20]
# Iteration 13 ETA: [00:42:12]
# Iteration 14 ETA: [00:41:38]
# Iteration 15 ETA: [00:42:13]
# Iteration 16 ETA: [00:41:21]
# Iteration 17 ETA: [00:41:49]
# Iteration 18 ETA: [00:41:58]
# Iteration 19 ETA: [00:41:07]
# Iteration 20 ETA: [00:41:37]
# Iteration 21 ETA: [00:42:13]
# Iteration 22 ETA: [00:42:07]
# Iteration 23 ETA: [00:40:33]
# Iteration 24 ETA: [00:41:19]
# Iteration 25 ETA: [00:41:46]
# Iteration 26 ETA: [00:42:16]
# Iteration 27 ETA: [00:41:42]
# Iteration 28 ETA: [00:41:01]
# Iteration 29 ETA: [00:40:28]
# Iteration 30 ETA: [00:41:57]
# Iteration 31 ETA: [00:41:23]
# Iteration 32 ETA: [00:41:21]
# Iteration 33 ETA: [00:40:58]
# Iteration 34 ETA: [00:41:06]
# Iteration 35 ETA: [00:40:57]
# Iteration 36 ETA: [00:40:55]
# Iteration 37 ETA: [00:41:35]
# Iteration 38 ETA: [00:41:25]
# Iteration 39 ETA: [00:40:24]
# Iteration 40 ETA: [00:41:27]
# Iteration 41 ETA: [00:40:23]
# Iteration 42 ETA: [00:39:59]
# Iteration 43 ETA: [00:40:58]
# Iteration 44 ETA: [00:40:26]
# Iteration 45 ETA: [00:40:19]
# Iteration 46 ETA: [00:40:44]
# Iteration 47 ETA: [00:39:45]
# Iteration 48 ETA: [00:39:46]
# Iteration 49 ETA: [00:39:30]
# Iteration 50 ETA: [00:40:06]
# Iteration 51 ETA: [00:39:25]
# Iteration 52 ETA: [00:39:03]
# Iteration 53 ETA: [00:39:57]
# Iteration 54 ETA: [00:40:07]
# Iteration 55 ETA: [00:39:10]
# Iteration 56 ETA: [00:38:49]
# Iteration 57 ETA: [00:40:06]
# Iteration 58 ETA: [00:39:02]
# Iteration 59 ETA: [00:39:43]
# Iteration 60 ETA: [00:40:16]
# Iteration 61 ETA: [00:39:52]
# Iteration 62 ETA: [00:38:40]
# Iteration 63 ETA: [00:39:29]
# Iteration 64 ETA: [00:38:29]
# Iteration 65 ETA: [00:38:32]
# Iteration 66 ETA: [00:39:41]
# Iteration 67 ETA: [00:38:32]
# Iteration 68 ETA: [00:37:58]
# Iteration 69 ETA: [00:38:57]
# Iteration 70 ETA: [00:38:46]
# Iteration 71 ETA: [00:38:07]
# Iteration 72 ETA: [00:39:19]
# Iteration 73 ETA: [00:38:32]
# Iteration 74 ETA: [00:38:39]
# Iteration 75 ETA: [00:38:41]
# Iteration 76 ETA: [00:38:26]
# Iteration 77 ETA: [00:38:34]
# Iteration 78 ETA: [00:38:42]
# Iteration 79 ETA: [00:37:47]
# Iteration 80 ETA: [00:38:55]
# Iteration 81 ETA: [00:38:07]
# Iteration 82 ETA: [00:38:50]
# Iteration 83 ETA: [00:37:34]
# Iteration 84 ETA: [00:38:57]
# Iteration 85 ETA: [00:37:31]
# Iteration 86 ETA: [00:38:26]
# Iteration 87 ETA: [00:37:38]
# Iteration 88 ETA: [00:37:17]
# Iteration 89 ETA: [00:37:19]
# Iteration 90 ETA: [00:38:00]
# Iteration 91 ETA: [00:37:53]
# Iteration 92 ETA: [00:37:31]
# Iteration 93 ETA: [00:38:15]
# Iteration 94 ETA: [00:37:06]
# Iteration 95 ETA: [00:37:13]
# Iteration 96 ETA: [00:37:18]
# Iteration 97 ETA: [00:37:06]
# Iteration 98 ETA: [00:37:30]
# Iteration 99 ETA: [00:37:58]
# Iteration 100 ETA: [00:38:21]
# Iteration 101 ETA: [00:37:09]
# Iteration 102 ETA: [00:37:00]
# Iteration 103 ETA: [00:36:43]
# Iteration 104 ETA: [00:37:54]
# Iteration 105 ETA: [00:36:51]
# Iteration 106 ETA: [00:36:42]
# Iteration 107 ETA: [00:36:33]
# Iteration 108 ETA: [00:36:50]
# Iteration 109 ETA: [00:36:21]
# Iteration 110 ETA: [00:37:44]
# Iteration 111 ETA: [00:36:35]
# Iteration 112 ETA: [00:37:00]
# Iteration 113 ETA: [00:36:07]
# Iteration 114 ETA: [00:36:20]
# Iteration 115 ETA: [00:36:37]
# Iteration 116 ETA: [00:37:09]
# Iteration 117 ETA: [00:36:42]
# Iteration 118 ETA: [00:37:37]
# Iteration 119 ETA: [00:36:41]
# Iteration 120 ETA: [00:35:54]
# Iteration 121 ETA: [00:35:50]
# Iteration 122 ETA: [00:36:59]
# Iteration 123 ETA: [00:35:24]
# Iteration 124 ETA: [00:37:11]
# Iteration 125 ETA: [00:36:24]
# Iteration 126 ETA: [00:36:14]
# Iteration 127 ETA: [00:35:52]
# Iteration 128 ETA: [00:36:47]
# Iteration 129 ETA: [00:36:16]
# Iteration 130 ETA: [00:35:01]
# Iteration 131 ETA: [00:35:49]
# Iteration 132 ETA: [00:35:26]
# Iteration 133 ETA: [00:34:52]
# Iteration 134 ETA: [00:36:28]
# Iteration 135 ETA: [00:35:14]
# Iteration 136 ETA: [00:35:07]
# Iteration 137 ETA: [00:36:05]
# Iteration 138 ETA: [00:35:10]
# Iteration 139 ETA: [00:35:23]
# Iteration 140 ETA: [00:35:19]
# Iteration 141 ETA: [00:35:46]
# Iteration 142 ETA: [00:35:27]
# Iteration 143 ETA: [00:35:50]
# Iteration 144 ETA: [00:35:11]
# Iteration 145 ETA: [00:35:39]
# Iteration 146 ETA: [00:35:09]
# Iteration 147 ETA: [00:35:12]
# Iteration 148 ETA: [00:35:09]
# Iteration 149 ETA: [00:35:44]
# Iteration 150 ETA: [00:34:19]
# Iteration 151 ETA: [00:34:17]
# Iteration 152 ETA: [00:34:37]
# Iteration 153 ETA: [00:34:20]
# Iteration 154 ETA: [00:34:27]
# Iteration 155 ETA: [00:34:45]
# Iteration 156 ETA: [00:35:31]
# Iteration 157 ETA: [00:34:20]
# Iteration 158 ETA: [00:34:56]
# Iteration 159 ETA: [00:34:16]
# Iteration 160 ETA: [00:34:14]
# Iteration 161 ETA: [00:33:58]
# Iteration 162 ETA: [00:34:15]
# Iteration 163 ETA: [00:33:49]
# Iteration 164 ETA: [00:33:49]
# Iteration 165 ETA: [00:34:03]
# Iteration 166 ETA: [00:34:48]
# Iteration 167 ETA: [00:34:02]
# Iteration 168 ETA: [00:33:56]
# Iteration 169 ETA: [00:34:57]
# Iteration 170 ETA: [00:33:13]
# Iteration 171 ETA: [00:34:08]
# Iteration 172 ETA: [00:33:28]
# Iteration 173 ETA: [00:33:50]
# Iteration 174 ETA: [00:33:20]
# Iteration 175 ETA: [00:32:41]
# Iteration 176 ETA: [00:33:25]
# Iteration 177 ETA: [00:33:13]
# Iteration 178 ETA: [00:32:44]
# Iteration 179 ETA: [00:32:41]
# Iteration 180 ETA: [00:33:41]
# Iteration 181 ETA: [00:32:56]
# Iteration 182 ETA: [00:32:36]
# Iteration 183 ETA: [00:32:24]
# Iteration 184 ETA: [00:32:21]
# Iteration 185 ETA: [00:32:14]
# Iteration 186 ETA: [00:32:29]
# Iteration 187 ETA: [00:32:50]
# Iteration 188 ETA: [00:32:29]
# Iteration 189 ETA: [00:33:14]
# Iteration 190 ETA: [00:33:02]
# Iteration 191 ETA: [00:32:52]
# Iteration 192 ETA: [00:32:18]
# Iteration 193 ETA: [00:32:25]
# Iteration 194 ETA: [00:33:16]
# Iteration 195 ETA: [00:32:23]
# Iteration 196 ETA: [00:33:16]
# Iteration 197 ETA: [00:31:48]
# Iteration 198 ETA: [00:31:52]
# Iteration 199 ETA: [00:32:36]
# Iteration 200 ETA: [00:32:52]
# Iteration 201 ETA: [00:32:46]
# Iteration 202 ETA: [00:32:25]
# Iteration 203 ETA: [00:32:31]
# Iteration 204 ETA: [00:32:09]
# Iteration 205 ETA: [00:32:31]
# Iteration 206 ETA: [00:32:12]
# Iteration 207 ETA: [00:31:52]
# Iteration 208 ETA: [00:31:23]
# Iteration 209 ETA: [00:32:13]
# Iteration 210 ETA: [00:31:14]
# Iteration 211 ETA: [00:31:50]
# Iteration 212 ETA: [00:32:18]
# Iteration 213 ETA: [00:31:41]
# Iteration 214 ETA: [00:31:39]
# Iteration 215 ETA: [00:31:33]
# Iteration 216 ETA: [00:31:47]
# Iteration 217 ETA: [00:31:35]
# Iteration 218 ETA: [00:31:06]
# Iteration 219 ETA: [00:32:02]
# Iteration 220 ETA: [00:31:51]
# Iteration 221 ETA: [00:31:49]
# Iteration 222 ETA: [00:31:50]
# Iteration 223 ETA: [00:31:10]
# Iteration 224 ETA: [00:30:55]
# Iteration 225 ETA: [00:30:40]
# Iteration 226 ETA: [00:30:44]
# Iteration 227 ETA: [00:31:26]
# Iteration 228 ETA: [00:31:13]
# Iteration 229 ETA: [00:30:11]
# Iteration 230 ETA: [00:30:52]
# Iteration 231 ETA: [00:31:01]
# Iteration 232 ETA: [00:30:57]
# Iteration 233 ETA: [00:30:46]
# Iteration 234 ETA: [00:31:00]
# Iteration 235 ETA: [00:29:55]
# Iteration 236 ETA: [00:29:53]
# Iteration 237 ETA: [00:29:44]
# Iteration 238 ETA: [00:30:11]
# Iteration 239 ETA: [00:31:06]
# Iteration 240 ETA: [00:29:56]
# Iteration 241 ETA: [00:30:10]
# Iteration 242 ETA: [00:30:22]
# Iteration 243 ETA: [00:30:12]
# Iteration 244 ETA: [00:29:22]
# Iteration 245 ETA: [00:29:33]
# Iteration 246 ETA: [00:29:45]
# Iteration 247 ETA: [00:29:17]
# Iteration 248 ETA: [00:29:38]
# Iteration 249 ETA: [00:29:17]
# Iteration 250 ETA: [00:29:27]
# Iteration 251 ETA: [00:29:34]
# Iteration 252 ETA: [00:29:47]
# Iteration 253 ETA: [00:30:30]
# Iteration 254 ETA: [00:29:36]
# Iteration 255 ETA: [00:29:31]
# Iteration 256 ETA: [00:29:36]
# Iteration 257 ETA: [00:29:07]
# Iteration 258 ETA: [00:29:42]
# Iteration 259 ETA: [00:29:54]
# Iteration 260 ETA: [00:28:38]
# Iteration 261 ETA: [00:28:42]
# Iteration 262 ETA: [00:29:22]
# Iteration 263 ETA: [00:28:49]
# Iteration 264 ETA: [00:29:01]
# Iteration 265 ETA: [00:28:32]
# Iteration 266 ETA: [00:29:07]
# Iteration 267 ETA: [00:28:47]
# Iteration 268 ETA: [00:29:04]
# Iteration 269 ETA: [00:29:01]
# Iteration 270 ETA: [00:28:44]
# Iteration 271 ETA: [00:28:10]
# Iteration 272 ETA: [00:28:40]
# Iteration 273 ETA: [00:28:46]
# Iteration 274 ETA: [00:28:52]
# Iteration 275 ETA: [00:28:50]
# Iteration 276 ETA: [00:28:35]
# Iteration 277 ETA: [00:28:29]
# Iteration 278 ETA: [00:28:08]
# Iteration 279 ETA: [00:28:24]
# Iteration 280 ETA: [00:28:09]
# Iteration 281 ETA: [00:27:56]
# Iteration 282 ETA: [00:28:08]
# Iteration 283 ETA: [00:28:07]
# Iteration 284 ETA: [00:27:55]
# Iteration 285 ETA: [00:28:04]
# Iteration 286 ETA: [00:28:06]
# Iteration 287 ETA: [00:27:37]
# Iteration 288 ETA: [00:27:40]
# Iteration 289 ETA: [00:27:53]
# Iteration 290 ETA: [00:28:00]
# Iteration 291 ETA: [00:27:29]
# Iteration 292 ETA: [00:26:59]
# Iteration 293 ETA: [00:27:02]
# Iteration 294 ETA: [00:26:56]
# Iteration 295 ETA: [00:26:57]
# Iteration 296 ETA: [00:27:05]
# Iteration 297 ETA: [00:26:52]
# Iteration 298 ETA: [00:26:35]
# Iteration 299 ETA: [00:26:50]
# Iteration 300 ETA: [00:26:38]
# Iteration 301 ETA: [00:27:01]
# Iteration 302 ETA: [00:27:09]
# Iteration 303 ETA: [00:27:00]
# Iteration 304 ETA: [00:26:45]
# Iteration 305 ETA: [00:27:05]
# Iteration 306 ETA: [00:27:18]
# Iteration 307 ETA: [00:27:12]
# Iteration 308 ETA: [00:26:12]
# Iteration 309 ETA: [00:26:48]
# Iteration 310 ETA: [00:26:57]
# Iteration 311 ETA: [00:26:57]
# Iteration 312 ETA: [00:26:47]
# Iteration 313 ETA: [00:26:23]
# Iteration 314 ETA: [00:26:07]
# Iteration 315 ETA: [00:26:37]
# Iteration 316 ETA: [00:26:53]
# Iteration 317 ETA: [00:26:20]
# Iteration 318 ETA: [00:26:11]
# Iteration 319 ETA: [00:25:33]
# Iteration 320 ETA: [00:26:20]
# Iteration 321 ETA: [00:26:13]
# Iteration 322 ETA: [00:25:43]
# Iteration 323 ETA: [00:26:25]
# Iteration 324 ETA: [00:25:24]
# Iteration 325 ETA: [00:25:58]
# Iteration 326 ETA: [00:25:56]
# Iteration 327 ETA: [00:25:47]
# Iteration 328 ETA: [00:25:30]
# Iteration 329 ETA: [00:25:08]
# Iteration 330 ETA: [00:26:17]
# Iteration 331 ETA: [00:26:05]
# Iteration 332 ETA: [00:25:46]
# Iteration 333 ETA: [00:24:58]
# Iteration 334 ETA: [00:25:45]
# Iteration 335 ETA: [00:25:03]
# Iteration 336 ETA: [00:24:39]
# Iteration 337 ETA: [00:25:22]
# Iteration 338 ETA: [00:25:14]
# Iteration 339 ETA: [00:24:41]
# Iteration 340 ETA: [00:25:00]
# Iteration 341 ETA: [00:25:00]
# Iteration 342 ETA: [00:25:32]
# Iteration 343 ETA: [00:24:52]
# Iteration 344 ETA: [00:24:28]
# Iteration 345 ETA: [00:24:51]
# Iteration 346 ETA: [00:24:14]
# Iteration 347 ETA: [00:24:39]
# Iteration 348 ETA: [00:24:14]
# Iteration 349 ETA: [00:24:11]
# Iteration 350 ETA: [00:24:23]
# Iteration 351 ETA: [00:24:33]
# Iteration 352 ETA: [00:24:17]
# Iteration 353 ETA: [00:24:53]
# Iteration 354 ETA: [00:23:56]
# Iteration 355 ETA: [00:24:25]
# Iteration 356 ETA: [00:24:48]
# Iteration 357 ETA: [00:24:44]
# Iteration 358 ETA: [00:23:39]
# Iteration 359 ETA: [00:24:03]
# Iteration 360 ETA: [00:23:40]
# Iteration 361 ETA: [00:24:03]
# Iteration 362 ETA: [00:24:47]
# Iteration 363 ETA: [00:24:00]
# Iteration 364 ETA: [00:24:34]
# Iteration 365 ETA: [00:24:13]
# Iteration 366 ETA: [00:24:34]
# Iteration 367 ETA: [00:23:39]
# Iteration 368 ETA: [00:24:16]
# Iteration 369 ETA: [00:23:40]
# Iteration 370 ETA: [00:23:23]
# Iteration 371 ETA: [00:23:32]
# Iteration 372 ETA: [00:23:27]
# Iteration 373 ETA: [00:23:19]
# Iteration 374 ETA: [00:23:51]
# Iteration 375 ETA: [00:23:19]
# Iteration 376 ETA: [00:23:31]
# Iteration 377 ETA: [00:23:36]
# Iteration 378 ETA: [00:23:06]
# Iteration 379 ETA: [00:23:33]
# Iteration 380 ETA: [00:23:05]
# Iteration 381 ETA: [00:23:03]
# Iteration 382 ETA: [00:22:28]
# Iteration 383 ETA: [00:22:54]
# Iteration 384 ETA: [00:22:58]
# Iteration 385 ETA: [00:23:03]
# Iteration 386 ETA: [00:22:35]
# Iteration 387 ETA: [00:22:21]
# Iteration 388 ETA: [00:23:07]
# Iteration 389 ETA: [00:22:19]
# Iteration 390 ETA: [00:22:27]
# Iteration 391 ETA: [00:22:45]
# Iteration 392 ETA: [00:21:56]
# Iteration 393 ETA: [00:22:54]
# Iteration 394 ETA: [00:21:58]
# Iteration 395 ETA: [00:22:25]
# Iteration 396 ETA: [00:21:42]
# Iteration 397 ETA: [00:22:33]
# Iteration 398 ETA: [00:22:14]
# Iteration 399 ETA: [00:21:41]
# Iteration 400 ETA: [00:22:12]
# Iteration 401 ETA: [00:21:27]
# Iteration 402 ETA: [00:21:59]
# Iteration 403 ETA: [00:22:08]
# Iteration 404 ETA: [00:21:47]
# Iteration 405 ETA: [00:21:32]
# Iteration 406 ETA: [00:22:00]
# Iteration 407 ETA: [00:21:07]
# Iteration 408 ETA: [00:21:09]
# Iteration 409 ETA: [00:21:35]
# Iteration 410 ETA: [00:21:14]
# Iteration 411 ETA: [00:20:59]
# Iteration 412 ETA: [00:21:28]
# Iteration 413 ETA: [00:21:06]
# Iteration 414 ETA: [00:21:02]
# Iteration 415 ETA: [00:21:06]
# Iteration 416 ETA: [00:21:30]
# Iteration 417 ETA: [00:21:11]
# Iteration 418 ETA: [00:20:40]
# Iteration 419 ETA: [00:20:44]
# Iteration 420 ETA: [00:20:31]
# Iteration 421 ETA: [00:21:06]
# Iteration 422 ETA: [00:20:38]
# Iteration 423 ETA: [00:20:49]
# Iteration 424 ETA: [00:20:37]
# Iteration 425 ETA: [00:20:32]
# Iteration 426 ETA: [00:21:12]
# Iteration 427 ETA: [00:21:16]
# Iteration 428 ETA: [00:20:54]
# Iteration 429 ETA: [00:20:55]
# Iteration 430 ETA: [00:20:29]
# Iteration 431 ETA: [00:20:51]
# Iteration 432 ETA: [00:20:17]
# Iteration 433 ETA: [00:20:51]
# Iteration 434 ETA: [00:20:08]
# Iteration 435 ETA: [00:20:35]
# Iteration 436 ETA: [00:20:05]
# Iteration 437 ETA: [00:20:20]
# Iteration 438 ETA: [00:19:36]
# Iteration 439 ETA: [00:19:40]
# Iteration 440 ETA: [00:19:53]
# Iteration 441 ETA: [00:19:39]
# Iteration 442 ETA: [00:19:59]
# Iteration 443 ETA: [00:19:35]
# Iteration 444 ETA: [00:19:25]
# Iteration 445 ETA: [00:19:41]
# Iteration 446 ETA: [00:20:03]
# Iteration 447 ETA: [00:19:22]
# Iteration 448 ETA: [00:19:46]
# Iteration 449 ETA: [00:19:50]
# Iteration 450 ETA: [00:19:16]
# Iteration 451 ETA: [00:19:39]
# Iteration 452 ETA: [00:19:05]
# Iteration 453 ETA: [00:18:45]
# Iteration 454 ETA: [00:18:58]
# Iteration 455 ETA: [00:18:53]
# Iteration 456 ETA: [00:19:07]
# Iteration 457 ETA: [00:18:53]
# Iteration 458 ETA: [00:19:10]
# Iteration 459 ETA: [00:18:33]
# Iteration 460 ETA: [00:18:39]
# Iteration 461 ETA: [00:19:03]
# Iteration 462 ETA: [00:19:04]
# Iteration 463 ETA: [00:18:35]
# Iteration 464 ETA: [00:18:41]
# Iteration 465 ETA: [00:18:11]
# Iteration 466 ETA: [00:18:08]
# Iteration 467 ETA: [00:18:40]
# Iteration 468 ETA: [00:18:27]
# Iteration 469 ETA: [00:17:56]
# Iteration 470 ETA: [00:18:19]
# Iteration 471 ETA: [00:18:30]
# Iteration 472 ETA: [00:18:37]
# Iteration 473 ETA: [00:18:14]
# Iteration 474 ETA: [00:18:04]
# Iteration 475 ETA: [00:18:02]
# Iteration 476 ETA: [00:17:59]
# Iteration 477 ETA: [00:17:46]
# Iteration 478 ETA: [00:17:52]
# Iteration 479 ETA: [00:17:50]
# Iteration 480 ETA: [00:17:43]
# Iteration 481 ETA: [00:17:17]
# Iteration 482 ETA: [00:17:30]
# Iteration 483 ETA: [00:17:10]
# Iteration 484 ETA: [00:17:24]
# Iteration 485 ETA: [00:17:00]
# Iteration 486 ETA: [00:17:47]
# Iteration 487 ETA: [00:17:25]
# Iteration 488 ETA: [00:17:31]
# Iteration 489 ETA: [00:16:59]
# Iteration 490 ETA: [00:17:14]
# Iteration 491 ETA: [00:17:19]
# Iteration 492 ETA: [00:17:25]
# Iteration 493 ETA: [00:16:48]
# Iteration 494 ETA: [00:16:59]
# Iteration 495 ETA: [00:16:44]
# Iteration 496 ETA: [00:16:49]
# Iteration 497 ETA: [00:16:47]
# Iteration 498 ETA: [00:16:29]
# Iteration 499 ETA: [00:16:40]
# Iteration 500 ETA: [00:16:45]
# Iteration 501 ETA: [00:16:19]
# Iteration 502 ETA: [00:16:20]
# Iteration 503 ETA: [00:16:20]
# Iteration 504 ETA: [00:16:31]
# Iteration 505 ETA: [00:16:10]
# Iteration 506 ETA: [00:16:25]
# Iteration 507 ETA: [00:16:29]
# Iteration 508 ETA: [00:16:10]
# Iteration 509 ETA: [00:16:25]
# Iteration 510 ETA: [00:16:00]
# Iteration 511 ETA: [00:15:49]
# Iteration 512 ETA: [00:15:42]
# Iteration 513 ETA: [00:15:50]
# Iteration 514 ETA: [00:15:42]
# Iteration 515 ETA: [00:15:50]
# Iteration 516 ETA: [00:15:35]
# Iteration 517 ETA: [00:15:48]
# Iteration 518 ETA: [00:15:21]
# Iteration 519 ETA: [00:15:45]
# Iteration 520 ETA: [00:15:22]
# Iteration 521 ETA: [00:15:51]
# Iteration 522 ETA: [00:15:39]
# Iteration 523 ETA: [00:15:18]
# Iteration 524 ETA: [00:15:10]
# Iteration 525 ETA: [00:15:22]
# Iteration 526 ETA: [00:15:08]
# Iteration 527 ETA: [00:14:59]
# Iteration 528 ETA: [00:15:20]
# Iteration 529 ETA: [00:15:23]
# Iteration 530 ETA: [00:15:15]
# Iteration 531 ETA: [00:14:57]
# Iteration 532 ETA: [00:14:50]
# Iteration 533 ETA: [00:14:40]
# Iteration 534 ETA: [00:14:48]
# Iteration 535 ETA: [00:14:36]
# Iteration 536 ETA: [00:14:45]
# Iteration 537 ETA: [00:14:40]
# Iteration 538 ETA: [00:14:53]
# Iteration 539 ETA: [00:14:33]
# Iteration 540 ETA: [00:14:22]
# Iteration 541 ETA: [00:14:38]
# Iteration 542 ETA: [00:14:18]
# Iteration 543 ETA: [00:14:26]
# Iteration 544 ETA: [00:14:10]
# Iteration 545 ETA: [00:14:12]
# Iteration 546 ETA: [00:14:32]
# Iteration 547 ETA: [00:14:15]
# Iteration 548 ETA: [00:14:19]
# Iteration 549 ETA: [00:14:13]
# Iteration 550 ETA: [00:13:53]
# Iteration 551 ETA: [00:13:59]
# Iteration 552 ETA: [00:13:48]
# Iteration 553 ETA: [00:14:11]
# Iteration 554 ETA: [00:14:00]
# Iteration 555 ETA: [00:14:01]
# Iteration 556 ETA: [00:13:46]
# Iteration 557 ETA: [00:13:46]
# Iteration 558 ETA: [00:13:49]
# Iteration 559 ETA: [00:13:21]
# Iteration 560 ETA: [00:13:33]
# Iteration 561 ETA: [00:13:24]
# Iteration 562 ETA: [00:13:32]
# Iteration 563 ETA: [00:13:10]
# Iteration 564 ETA: [00:13:24]
# Iteration 565 ETA: [00:13:17]
# Iteration 566 ETA: [00:13:07]
# Iteration 567 ETA: [00:13:20]
# Iteration 568 ETA: [00:12:52]
# Iteration 569 ETA: [00:13:07]
# Iteration 570 ETA: [00:13:07]
# Iteration 571 ETA: [00:12:50]
# Iteration 572 ETA: [00:12:53]
# Iteration 573 ETA: [00:13:04]
# Iteration 574 ETA: [00:12:50]
# Iteration 575 ETA: [00:12:54]
# Iteration 576 ETA: [00:12:51]
# Iteration 577 ETA: [00:12:30]
# Iteration 578 ETA: [00:12:28]
# Iteration 579 ETA: [00:12:35]
# Iteration 580 ETA: [00:12:38]
# Iteration 581 ETA: [00:12:25]
# Iteration 582 ETA: [00:12:15]
# Iteration 583 ETA: [00:12:20]
# Iteration 584 ETA: [00:12:06]
# Iteration 585 ETA: [00:12:04]
# Iteration 586 ETA: [00:12:28]
# Iteration 587 ETA: [00:12:05]
# Iteration 588 ETA: [00:12:02]
# Iteration 589 ETA: [00:12:11]
# Iteration 590 ETA: [00:11:58]
# Iteration 591 ETA: [00:12:06]
# Iteration 592 ETA: [00:11:57]
# Iteration 593 ETA: [00:11:59]
# Iteration 594 ETA: [00:11:54]
# Iteration 595 ETA: [00:11:36]
# Iteration 596 ETA: [00:11:45]
# Iteration 597 ETA: [00:11:34]
# Iteration 598 ETA: [00:11:41]
# Iteration 599 ETA: [00:11:33]
# Iteration 600 ETA: [00:11:25]
# Iteration 601 ETA: [00:11:16]
# Iteration 602 ETA: [00:11:16]
# Iteration 603 ETA: [00:11:07]
# Iteration 604 ETA: [00:11:20]
# Iteration 605 ETA: [00:11:15]
# Iteration 606 ETA: [00:11:16]
# Iteration 607 ETA: [00:11:02]
# Iteration 608 ETA: [00:11:07]
# Iteration 609 ETA: [00:10:52]
# Iteration 610 ETA: [00:10:51]
# Iteration 611 ETA: [00:10:48]
# Iteration 612 ETA: [00:10:48]
# Iteration 613 ETA: [00:10:49]
# Iteration 614 ETA: [00:10:46]
# Iteration 615 ETA: [00:10:35]
# Iteration 616 ETA: [00:10:36]
# Iteration 617 ETA: [00:10:31]
# Iteration 618 ETA: [00:10:22]
# Iteration 619 ETA: [00:10:35]
# Iteration 620 ETA: [00:10:27]
# Iteration 621 ETA: [00:10:28]
# Iteration 622 ETA: [00:10:09]
# Iteration 623 ETA: [00:10:14]
# Iteration 624 ETA: [00:10:20]
# Iteration 625 ETA: [00:10:15]
# Iteration 626 ETA: [00:10:11]
# Iteration 627 ETA: [00:09:59]
# Iteration 628 ETA: [00:09:58]
# Iteration 629 ETA: [00:10:06]
# Iteration 630 ETA: [00:10:05]
# Iteration 631 ETA: [00:09:53]
# Iteration 632 ETA: [00:09:53]
# Iteration 633 ETA: [00:09:49]
# Iteration 634 ETA: [00:09:46]
# Iteration 635 ETA: [00:09:44]
# Iteration 636 ETA: [00:09:38]
# Iteration 637 ETA: [00:09:28]
# Iteration 638 ETA: [00:09:26]
# Iteration 639 ETA: [00:09:26]
# Iteration 640 ETA: [00:09:25]
# Iteration 641 ETA: [00:09:24]
# Iteration 642 ETA: [00:09:17]
# Iteration 643 ETA: [00:09:18]
# Iteration 644 ETA: [00:09:13]
# Iteration 645 ETA: [00:09:05]
# Iteration 646 ETA: [00:09:08]
# Iteration 647 ETA: [00:09:08]
# Iteration 648 ETA: [00:08:53]
# Iteration 649 ETA: [00:08:54]
# Iteration 650 ETA: [00:08:54]
# Iteration 651 ETA: [00:08:45]
# Iteration 652 ETA: [00:08:54]
# Iteration 653 ETA: [00:08:46]
# Iteration 654 ETA: [00:08:36]
# Iteration 655 ETA: [00:08:49]
# Iteration 656 ETA: [00:08:47]
# Iteration 657 ETA: [00:08:35]
# Iteration 658 ETA: [00:08:34]
# Iteration 659 ETA: [00:08:24]
# Iteration 660 ETA: [00:08:27]
# Iteration 661 ETA: [00:08:19]
# Iteration 662 ETA: [00:08:18]
# Iteration 663 ETA: [00:08:16]
# Iteration 664 ETA: [00:08:12]
# Iteration 665 ETA: [00:08:06]
# Iteration 666 ETA: [00:08:06]
# Iteration 667 ETA: [00:07:55]
# Iteration 668 ETA: [00:08:11]
# Iteration 669 ETA: [00:07:59]
# Iteration 670 ETA: [00:07:51]
# Iteration 671 ETA: [00:07:46]
# Iteration 672 ETA: [00:07:49]
# Iteration 673 ETA: [00:07:49]
# Iteration 674 ETA: [00:07:44]
# Iteration 675 ETA: [00:07:45]
# Iteration 676 ETA: [00:07:35]
# Iteration 677 ETA: [00:07:35]
# Iteration 678 ETA: [00:07:29]
# Iteration 679 ETA: [00:07:25]
# Iteration 680 ETA: [00:07:17]
# Iteration 681 ETA: [00:07:22]
# Iteration 682 ETA: [00:07:09]
# Iteration 683 ETA: [00:07:10]
# Iteration 684 ETA: [00:07:11]
# Iteration 685 ETA: [00:07:03]
# Iteration 686 ETA: [00:06:59]
# Iteration 687 ETA: [00:07:01]
# Iteration 688 ETA: [00:06:56]
# Iteration 689 ETA: [00:06:53]
# Iteration 690 ETA: [00:06:49]
# Iteration 691 ETA: [00:06:55]
# Iteration 692 ETA: [00:06:47]
# Iteration 693 ETA: [00:06:39]
# Iteration 694 ETA: [00:06:43]
# Iteration 695 ETA: [00:06:42]
# Iteration 696 ETA: [00:06:42]
# Iteration 697 ETA: [00:06:32]
# Iteration 698 ETA: [00:06:23]
# Iteration 699 ETA: [00:06:21]
# Iteration 700 ETA: [00:06:22]
# Iteration 701 ETA: [00:06:20]
# Iteration 702 ETA: [00:06:10]
# Iteration 703 ETA: [00:06:09]
# Iteration 704 ETA: [00:06:06]
# Iteration 705 ETA: [00:06:01]
# Iteration 706 ETA: [00:06:04]
# Iteration 707 ETA: [00:05:58]
# Iteration 708 ETA: [00:06:02]
# Iteration 709 ETA: [00:05:50]
# Iteration 710 ETA: [00:05:48]
# Iteration 711 ETA: [00:05:44]
# Iteration 712 ETA: [00:05:43]
# Iteration 713 ETA: [00:05:38]
# Iteration 714 ETA: [00:05:44]
# Iteration 715 ETA: [00:05:38]
# Iteration 716 ETA: [00:05:36]
# Iteration 717 ETA: [00:05:32]
# Iteration 718 ETA: [00:05:31]
# Iteration 719 ETA: [00:05:30]
# Iteration 720 ETA: [00:05:27]
# Iteration 721 ETA: [00:05:17]
# Iteration 722 ETA: [00:05:16]
# Iteration 723 ETA: [00:05:07]
# Iteration 724 ETA: [00:05:08]
# Iteration 725 ETA: [00:05:05]
# Iteration 726 ETA: [00:04:58]
# Iteration 727 ETA: [00:04:58]
# Iteration 728 ETA: [00:04:48]
# Iteration 729 ETA: [00:04:48]
# Iteration 730 ETA: [00:04:46]
# Iteration 731 ETA: [00:04:43]
# Iteration 732 ETA: [00:04:43]
# Iteration 733 ETA: [00:04:39]
# Iteration 734 ETA: [00:04:34]
# Iteration 735 ETA: [00:04:34]
# Iteration 736 ETA: [00:04:31]
# Iteration 737 ETA: [00:04:27]
# Iteration 738 ETA: [00:04:22]
# Iteration 739 ETA: [00:04:18]
# Iteration 740 ETA: [00:04:20]
# Iteration 741 ETA: [00:04:15]
# Iteration 742 ETA: [00:04:09]
# Iteration 743 ETA: [00:04:07]
# Iteration 744 ETA: [00:04:07]
# Iteration 745 ETA: [00:04:01]
# Iteration 746 ETA: [00:04:02]
# Iteration 747 ETA: [00:03:55]
# Iteration 748 ETA: [00:03:55]
# Iteration 749 ETA: [00:03:47]
# Iteration 750 ETA: [00:03:45]
# Iteration 751 ETA: [00:03:44]
# Iteration 752 ETA: [00:03:43]
# Iteration 753 ETA: [00:03:35]
# Iteration 754 ETA: [00:03:34]
# Iteration 755 ETA: [00:03:28]
# Iteration 756 ETA: [00:03:30]
# Iteration 757 ETA: [00:03:24]
# Iteration 758 ETA: [00:03:22]
# Iteration 759 ETA: [00:03:18]
# Iteration 760 ETA: [00:03:17]
# Iteration 761 ETA: [00:03:14]
# Iteration 762 ETA: [00:03:08]
# Iteration 763 ETA: [00:03:09]
# Iteration 764 ETA: [00:03:04]
# Iteration 765 ETA: [00:02:59]
# Iteration 766 ETA: [00:02:54]
# Iteration 767 ETA: [00:02:54]
# Iteration 768 ETA: [00:02:50]
# Iteration 769 ETA: [00:02:51]
# Iteration 770 ETA: [00:02:48]
# Iteration 771 ETA: [00:02:43]
# Iteration 772 ETA: [00:02:38]
# Iteration 773 ETA: [00:02:35]
# Iteration 774 ETA: [00:02:35]
# Iteration 775 ETA: [00:02:30]
# Iteration 776 ETA: [00:02:31]
# Iteration 777 ETA: [00:02:24]
# Iteration 778 ETA: [00:02:22]
# Iteration 779 ETA: [00:02:18]
# Iteration 780 ETA: [00:02:14]
# Iteration 781 ETA: [00:02:12]
# Iteration 782 ETA: [00:02:08]
# Iteration 783 ETA: [00:02:09]
# Iteration 784 ETA: [00:02:03]
# Iteration 785 ETA: [00:01:59]
# Iteration 786 ETA: [00:01:57]
# Iteration 787 ETA: [00:01:56]
# Iteration 788 ETA: [00:01:49]
# Iteration 789 ETA: [00:01:49]
# Iteration 790 ETA: [00:01:43]
# Iteration 791 ETA: [00:01:40]
# Iteration 792 ETA: [00:01:37]
# Iteration 793 ETA: [00:01:35]
# Iteration 794 ETA: [00:01:32]
# Iteration 795 ETA: [00:01:30]
# Iteration 796 ETA: [00:01:26]
# Iteration 797 ETA: [00:01:23]
# Iteration 798 ETA: [00:01:20]
# Iteration 799 ETA: [00:01:15]
# Iteration 800 ETA: [00:01:12]
# Iteration 801 ETA: [00:01:11]
# Iteration 802 ETA: [00:01:07]
# Iteration 803 ETA: [00:01:04]
# Iteration 804 ETA: [00:01:01]
# Iteration 805 ETA: [00:00:58]
# Iteration 806 ETA: [00:00:55]
# Iteration 807 ETA: [00:00:51]
# Iteration 808 ETA: [00:00:49]
# Iteration 809 ETA: [00:00:45]
# Iteration 810 ETA: [00:00:43]
# Iteration 811 ETA: [00:00:39]
# Iteration 812 ETA: [00:00:36]
# Iteration 813 ETA: [00:00:33]
# Iteration 814 ETA: [00:00:30]
# Iteration 815 ETA: [00:00:27]
# Iteration 816 ETA: [00:00:24]
# Iteration 817 ETA: [00:00:21]
# Iteration 818 ETA: [00:00:18]
# Iteration 819 ETA: [00:00:15]
# Iteration 820 ETA: [00:00:12]
# Iteration 821 ETA: [00:00:09]
# Iteration 822 ETA: [00:00:06]
# Iteration 823 ETA: [00:00:03]
# Iteration 824 ETA: [00:00:00]

# %%
order_0_train = torch.cat(order_0, dim=0)
orders_1_and_2_train = torch.cat(orders_1_and_2, dim=0)

order_0_train = order_0_train.cpu().numpy()
orders_1_and_2_train = orders_1_and_2_train.cpu().numpy()

# %%
order_0_train = order_0_train.reshape((n_molecules_train, -1))
orders_1_and_2_train = orders_1_and_2_train.reshape((n_molecules_train, -1))

# %%
basename = 'scattering_w_features_molecule_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)

cache_dir = get_cache_dir("results/train/")

filename = os.path.join(cache_dir, 'order_0_' + basename)
np.save(filename, order_0_train)

filename = os.path.join(cache_dir, 'orders_1_and_2' + basename)
np.save(filename, orders_1_and_2_train)

# %% [markdown]
# # Test

# %%
pos_test, full_charges_test = load_all_xyz("./atoms/test/", max_atoms=23)
n_molecules_test = pos_test.shape[0]

# %%
mask = full_charges_test <= 2
valence_charges = full_charges_test * mask

mask = np.logical_and(full_charges_test > 2, full_charges_test <= 10)
valence_charges += (full_charges_test - 2) * mask

mask = np.logical_and(full_charges_test > 10, full_charges_test <= 18)
valence_charges += (full_charges_test - 10) * mask

# %%
overlapping_precision = 1e-1
sigma = 2.0
min_dist = np.inf

for i in range(n_molecules_test):
    n_atoms = np.sum(full_charges_test[i] != 0)
    pos_i = pos_test[i, :n_atoms, :]
    min_dist = min(min_dist, pdist(pos_i).min())

delta = sigma * np.sqrt(-8 * np.log(overlapping_precision))
pos = pos_test * delta / min_dist

# %%
M, N, O = 96, 64, 48

grid = np.mgrid[-M//2:-M//2+M, -N//2:-N//2+N, -O//2:-O//2+O]
grid = np.fft.ifftshift(grid)

# %%
J = 2
L = 3
integral_powers = [0.5, 1.0, 2.0, 3.0]

scattering = HarmonicScattering3D(J=J, shape=(M, N, O),
                                  L=L, sigma_0=sigma,
                                  integral_powers=integral_powers)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
scattering.to(device)
# Out:
# HarmonicScattering3D()

# %%
batch_size = 8
n_batches = int(np.ceil(n_molecules_test / batch_size))
print(n_batches)
# Out:
# 206

# %%
order_0, orders_1_and_2 = [], []
print('Computing solid harmonic scattering coefficients of '
      '{} molecules from the QM7 database on {}'.format(
        n_molecules_test,   "GPU" if use_cuda else "CPU"))
print('sigma: {}, L: {}, J: {}, integral powers: {}'.format(
        sigma, L, J, integral_powers))

this_time = None
last_time = None
for i in range(n_batches):
    this_time = time.time()
    if last_time is not None:
        dt = this_time - last_time
        print("Iteration {} ETA: [{:02}:{:02}:{:02}]".format(
                    i + 1, int(((n_batches - i - 1) * dt) // 3600),
                    int((((n_batches - i - 1) * dt) // 60) % 60),
                    int(((n_batches - i - 1) * dt) % 60)))
    else:
        print("Iteration {} ETA: {}".format(i + 1, '-'))
    last_time = this_time
    time.sleep(1)

    # Extract the current batch.
    start = i * batch_size
    end = min(start + batch_size, n_molecules_test)

    pos_batch = pos[start:end]
    full_batch = full_charges_test[start:end]
    val_batch = valence_charges[start:end]

    # Calculate the density map for the nuclear charges and transfer
    # to PyTorch.
    full_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, full_batch, sigma)
    full_density_batch = torch.from_numpy(full_density_batch)
    full_density_batch = full_density_batch.to(device).float()

    # Compute zeroth-order, first-order, and second-order scattering
    # coefficients of the nuclear charges.
    full_order_0 = TorchBackend3D.compute_integrals(full_density_batch,
                                     integral_powers)
    full_scattering = scattering(full_density_batch)

    # Compute the map for valence charges.
    val_density_batch = generate_weighted_sum_of_gaussians(grid,
            pos_batch, val_batch, sigma)
    val_density_batch = torch.from_numpy(val_density_batch)
    val_density_batch = val_density_batch.to(device).float()

    # Compute scattering coefficients for the valence charges.
    val_order_0 = TorchBackend3D.compute_integrals(val_density_batch,
                                    integral_powers)
    val_scattering = scattering(val_density_batch)

    # Take the difference between nuclear and valence charges, then
    # compute the corresponding scattering coefficients.
    core_density_batch = full_density_batch - val_density_batch

    core_order_0 = TorchBackend3D.compute_integrals(core_density_batch,
                                     integral_powers)
    core_scattering = scattering(core_density_batch)

    # Add features 
    additional_feats = compute_additional_features(pos_batch, full_batch, val_batch)

    # === Stack et flatten ===
    batch_order_0 = torch.stack((full_order_0, val_order_0, core_order_0), dim=-1)  # shape (B, P, 3)
    batch_orders_1_and_2 = torch.stack((full_scattering, val_scattering, core_scattering), dim=-1)  # shape (B, C, 3)

    batch_order_0_flat = batch_order_0.view(batch_order_0.size(0), -1)
    batch_orders_1_and_2_flat = batch_orders_1_and_2.view(batch_orders_1_and_2.size(0), -1)
    
    # === Concatenation des features ===
    batch_order_0_enriched = torch.cat([batch_order_0_flat, additional_feats], dim=1)
    batch_orders_enriched = torch.cat([batch_orders_1_and_2_flat, additional_feats], dim=1)

    order_0.append(batch_order_0_enriched)
    orders_1_and_2.append(batch_orders_enriched)
# Out:
# Computing solid harmonic scattering coefficients of 1647 molecules from the QM7 database on GPU
# sigma: 2.0, L: 3, J: 2, integral powers: [0.5, 1.0, 2.0, 3.0]
# Iteration 1 ETA: -
# Iteration 2 ETA: [00:10:40]
# Iteration 3 ETA: [00:10:30]
# Iteration 4 ETA: [00:10:38]
# Iteration 5 ETA: [00:10:16]
# Iteration 6 ETA: [00:10:15]
# Iteration 7 ETA: [00:10:11]
# Iteration 8 ETA: [00:10:13]
# Iteration 9 ETA: [00:10:04]
# Iteration 10 ETA: [00:10:13]
# Iteration 11 ETA: [00:10:03]
# Iteration 12 ETA: [00:09:52]
# Iteration 13 ETA: [00:09:48]
# Iteration 14 ETA: [00:09:46]
# Iteration 15 ETA: [00:09:47]
# Iteration 16 ETA: [00:09:55]
# Iteration 17 ETA: [00:10:14]
# Iteration 18 ETA: [00:09:50]
# Iteration 19 ETA: [00:09:39]
# Iteration 20 ETA: [00:09:44]
# Iteration 21 ETA: [00:09:26]
# Iteration 22 ETA: [00:09:25]
# Iteration 23 ETA: [00:09:24]
# Iteration 24 ETA: [00:09:27]
# Iteration 25 ETA: [00:09:29]
# Iteration 26 ETA: [00:09:32]
# Iteration 27 ETA: [00:09:17]
# Iteration 28 ETA: [00:09:05]
# Iteration 29 ETA: [00:09:03]
# Iteration 30 ETA: [00:09:18]
# Iteration 31 ETA: [00:08:56]
# Iteration 32 ETA: [00:09:03]
# Iteration 33 ETA: [00:09:08]
# Iteration 34 ETA: [00:08:48]
# Iteration 35 ETA: [00:08:39]
# Iteration 36 ETA: [00:08:51]
# Iteration 37 ETA: [00:08:49]
# Iteration 38 ETA: [00:08:40]
# Iteration 39 ETA: [00:08:40]
# Iteration 40 ETA: [00:08:33]
# Iteration 41 ETA: [00:08:25]
# Iteration 42 ETA: [00:08:38]
# Iteration 43 ETA: [00:08:30]
# Iteration 44 ETA: [00:08:20]
# Iteration 45 ETA: [00:08:11]
# Iteration 46 ETA: [00:08:08]
# Iteration 47 ETA: [00:08:20]
# Iteration 48 ETA: [00:08:01]
# Iteration 49 ETA: [00:08:14]
# Iteration 50 ETA: [00:08:06]
# Iteration 51 ETA: [00:08:00]
# Iteration 52 ETA: [00:07:50]
# Iteration 53 ETA: [00:07:56]
# Iteration 54 ETA: [00:07:40]
# Iteration 55 ETA: [00:07:46]
# Iteration 56 ETA: [00:07:44]
# Iteration 57 ETA: [00:07:55]
# Iteration 58 ETA: [00:07:37]
# Iteration 59 ETA: [00:07:33]
# Iteration 60 ETA: [00:07:58]
# Iteration 61 ETA: [00:07:37]
# Iteration 62 ETA: [00:07:31]
# Iteration 63 ETA: [00:07:24]
# Iteration 64 ETA: [00:07:16]
# Iteration 65 ETA: [00:07:17]
# Iteration 66 ETA: [00:07:21]
# Iteration 67 ETA: [00:07:18]
# Iteration 68 ETA: [00:07:02]
# Iteration 69 ETA: [00:07:07]
# Iteration 70 ETA: [00:07:07]
# Iteration 71 ETA: [00:06:58]
# Iteration 72 ETA: [00:06:50]
# Iteration 73 ETA: [00:06:45]
# Iteration 74 ETA: [00:06:56]
# Iteration 75 ETA: [00:06:49]
# Iteration 76 ETA: [00:06:44]
# Iteration 77 ETA: [00:06:52]
# Iteration 78 ETA: [00:06:45]
# Iteration 79 ETA: [00:06:36]
# Iteration 80 ETA: [00:06:46]
# Iteration 81 ETA: [00:06:20]
# Iteration 82 ETA: [00:06:25]
# Iteration 83 ETA: [00:06:23]
# Iteration 84 ETA: [00:06:22]
# Iteration 85 ETA: [00:06:19]
# Iteration 86 ETA: [00:06:18]
# Iteration 87 ETA: [00:06:05]
# Iteration 88 ETA: [00:06:16]
# Iteration 89 ETA: [00:06:02]
# Iteration 90 ETA: [00:06:11]
# Iteration 91 ETA: [00:05:58]
# Iteration 92 ETA: [00:05:52]
# Iteration 93 ETA: [00:05:49]
# Iteration 94 ETA: [00:05:50]
# Iteration 95 ETA: [00:05:42]
# Iteration 96 ETA: [00:05:50]
# Iteration 97 ETA: [00:05:36]
# Iteration 98 ETA: [00:05:41]
# Iteration 99 ETA: [00:05:28]
# Iteration 100 ETA: [00:05:38]
# Iteration 101 ETA: [00:05:24]
# Iteration 102 ETA: [00:05:28]
# Iteration 103 ETA: [00:05:23]
# Iteration 104 ETA: [00:05:20]
# Iteration 105 ETA: [00:05:13]
# Iteration 106 ETA: [00:05:04]
# Iteration 107 ETA: [00:05:10]
# Iteration 108 ETA: [00:04:56]
# Iteration 109 ETA: [00:05:02]
# Iteration 110 ETA: [00:05:00]
# Iteration 111 ETA: [00:04:51]
# Iteration 112 ETA: [00:04:50]
# Iteration 113 ETA: [00:04:48]
# Iteration 114 ETA: [00:04:46]
# Iteration 115 ETA: [00:04:40]
# Iteration 116 ETA: [00:04:38]
# Iteration 117 ETA: [00:04:48]
# Iteration 118 ETA: [00:04:37]
# Iteration 119 ETA: [00:04:32]
# Iteration 120 ETA: [00:04:26]
# Iteration 121 ETA: [00:04:24]
# Iteration 122 ETA: [00:04:21]
# Iteration 123 ETA: [00:04:21]
# Iteration 124 ETA: [00:04:17]
# Iteration 125 ETA: [00:04:14]
# Iteration 126 ETA: [00:04:08]
# Iteration 127 ETA: [00:04:13]
# Iteration 128 ETA: [00:04:00]
# Iteration 129 ETA: [00:04:01]
# Iteration 130 ETA: [00:03:55]
# Iteration 131 ETA: [00:03:55]
# Iteration 132 ETA: [00:03:47]
# Iteration 133 ETA: [00:03:45]
# Iteration 134 ETA: [00:03:40]
# Iteration 135 ETA: [00:03:43]
# Iteration 136 ETA: [00:03:40]
# Iteration 137 ETA: [00:03:32]
# Iteration 138 ETA: [00:03:34]
# Iteration 139 ETA: [00:03:30]
# Iteration 140 ETA: [00:03:23]
# Iteration 141 ETA: [00:03:23]
# Iteration 142 ETA: [00:03:17]
# Iteration 143 ETA: [00:03:14]
# Iteration 144 ETA: [00:03:10]
# Iteration 145 ETA: [00:03:12]
# Iteration 146 ETA: [00:03:05]
# Iteration 147 ETA: [00:03:01]
# Iteration 148 ETA: [00:02:59]
# Iteration 149 ETA: [00:02:53]
# Iteration 150 ETA: [00:02:51]
# Iteration 151 ETA: [00:02:51]
# Iteration 152 ETA: [00:02:47]
# Iteration 153 ETA: [00:02:42]
# Iteration 154 ETA: [00:02:41]
# Iteration 155 ETA: [00:02:38]
# Iteration 156 ETA: [00:02:41]
# Iteration 157 ETA: [00:02:35]
# Iteration 158 ETA: [00:02:35]
# Iteration 159 ETA: [00:02:32]
# Iteration 160 ETA: [00:02:26]
# Iteration 161 ETA: [00:02:22]
# Iteration 162 ETA: [00:02:13]
# Iteration 163 ETA: [00:02:15]
# Iteration 164 ETA: [00:02:11]
# Iteration 165 ETA: [00:02:06]
# Iteration 166 ETA: [00:02:03]
# Iteration 167 ETA: [00:02:01]
# Iteration 168 ETA: [00:01:56]
# Iteration 169 ETA: [00:01:54]
# Iteration 170 ETA: [00:01:51]
# Iteration 171 ETA: [00:01:50]
# Iteration 172 ETA: [00:01:45]
# Iteration 173 ETA: [00:01:43]
# Iteration 174 ETA: [00:01:41]
# Iteration 175 ETA: [00:01:36]
# Iteration 176 ETA: [00:01:33]
# Iteration 177 ETA: [00:01:31]
# Iteration 178 ETA: [00:01:28]
# Iteration 179 ETA: [00:01:25]
# Iteration 180 ETA: [00:01:21]
# Iteration 181 ETA: [00:01:16]
# Iteration 182 ETA: [00:01:13]
# Iteration 183 ETA: [00:01:10]
# Iteration 184 ETA: [00:01:09]
# Iteration 185 ETA: [00:01:05]
# Iteration 186 ETA: [00:01:02]
# Iteration 187 ETA: [00:00:59]
# Iteration 188 ETA: [00:00:55]
# Iteration 189 ETA: [00:00:52]
# Iteration 190 ETA: [00:00:51]
# Iteration 191 ETA: [00:00:47]
# Iteration 192 ETA: [00:00:43]
# Iteration 193 ETA: [00:00:40]
# Iteration 194 ETA: [00:00:37]
# Iteration 195 ETA: [00:00:33]
# Iteration 196 ETA: [00:00:31]
# Iteration 197 ETA: [00:00:28]
# Iteration 198 ETA: [00:00:25]
# Iteration 199 ETA: [00:00:22]
# Iteration 200 ETA: [00:00:18]
# Iteration 201 ETA: [00:00:15]
# Iteration 202 ETA: [00:00:12]
# Iteration 203 ETA: [00:00:09]
# Iteration 204 ETA: [00:00:06]
# Iteration 205 ETA: [00:00:03]
# Iteration 206 ETA: [00:00:00]

# %%
order_0_test = torch.cat(order_0, dim=0)
orders_1_and_2_test = torch.cat(orders_1_and_2, dim=0)

order_0_test = order_0_test.cpu().numpy()
orders_1_and_2_test = orders_1_and_2_test.cpu().numpy()

# %%
order_0_test = order_0_test.reshape((n_molecules_test, -1))
orders_1_and_2_test = orders_1_and_2_test.reshape((n_molecules_test, -1))

# %%
basename = 'scattering_w_features_molecule_L_{}_J_{}_sigma_{}_MNO_{}_powers_{}.npy'.format(
        L, J, sigma, (M, N, O), integral_powers)

cache_dir = get_cache_dir("results/test/")

filename = os.path.join(cache_dir, 'order_0_' + basename)
np.save(filename, order_0_test)

filename = os.path.join(cache_dir, 'orders_1_and_2' + basename)
np.save(filename, orders_1_and_2_test)
